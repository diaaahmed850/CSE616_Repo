# %% [markdown]
# # Load Libraries

# %%
#Load Libraries
import os
import matplotlib
import matplotlib.pyplot as plt
import skimage.data
import cv2
import numpy as np
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
import random
import pandas as pd
from pandas import DataFrame
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import skimage
import seaborn as sns
import glob
from sklearn.metrics import precision_score,recall_score, confusion_matrix
from sklearn.metrics import classification_report,accuracy_score, f1_score

# %% [markdown]
# ### Train and Test data Set Definition

# %%
Train_dir = "Images_Train"
Test_dir = "Images_Test"
directories =os.listdir(Train_dir)
directories_test = os.listdir(Test_dir)

# %% [markdown]
# ### Function to read Train and Test Images

# %%
def read_data(Root_dir,directories):
    images=[]
    labels=[]
    print (Root_dir)
    for directory in directories:
        label_dir = os.path.join(Root_dir, directory)
        print (label_dir)
        file_names = [os.path.join(label_dir,f) for f in os.listdir(label_dir) if f.endswith(".ppm")]
        for file_name in file_names:
            print(file_name)
            images.append(skimage.io.imread(file_name))
            if (directory[-2]=='0'):
                labels.append(int(directory[-1:]))
                print(int(directory[-1:]))
            else:
                labels.append(int(directory[-2:]))
                print(int(directory[-2:]))
    return (images, labels)

# %% [markdown]
# ## Load Train Data

# %%
def read_data_test(Root_dir,directories):
    images=[]
    labels=[]
    print (Root_dir)
    file_names = [os.path.join(Root_dir,f) for f in os.listdir(Root_dir) if f.endswith(".ppm")]
    for file_name in file_names:
        print(file_name)
        images.append(skimage.io.imread(file_name))
        directory = file_name.split('\\')[1].split('.')[0]
        if (directory[-2]=='0'):
            labels.append(int(directory[-1:]))
            print(int(directory[-1:]))
        else:
            labels.append(int(directory[-2:]))
            print(int(directory[-2:]))
    return (images, labels)

# %%
X_train_list, y_train_list = read_data(Train_dir,directories)
# Out:
# Images_Train
# Images_Train\00000
# Images_Train\00000\00000_00000.ppm
# 0
# Images_Train\00000\00000_00001.ppm
# 0
# Images_Train\00000\00000_00002.ppm
# 0
# Images_Train\00000\00000_00003.ppm
# 0
# Images_Train\00000\00000_00004.ppm
# 0
# Images_Train\00000\00000_00005.ppm
# 0
# Images_Train\00000\00000_00006.ppm
# 0
# Images_Train\00000\00000_00007.ppm
# 0
# Images_Train\00000\00000_00008.ppm
# 0
# Images_Train\00000\00000_00009.ppm
# 0
# Images_Train\00000\00000_00010.ppm
# 0
# Images_Train\00000\00000_00011.ppm
# 0
# Images_Train\00000\00000_00012.ppm
# 0
# Images_Train\00000\00000_00013.ppm
# 0
# Images_Train\00000\00000_00014.ppm
# 0
# Images_Train\00000\00000_00015.ppm
# 0
# Images_Train\00000\00000_00016.ppm
# 0
# Images_Train\00000\00000_00017.ppm
# 0
# Images_Train\00000\00000_00018.ppm
# 0
# Images_Train\00000\00000_00019.ppm
# 0
# Images_Train\00000\00000_00020.ppm
# 0
# Images_Train\00000\00000_00021.ppm
# 0
# Images_Train\00000\00000_00022.ppm
# 0
# Images_Train\00000\00000_00023.ppm
# 0
# Images_Train\00000\00000_00024.ppm
# 0
# Images_Train\00000\00000_00025.ppm
# 0
# Images_Train\00000\00000_00026.ppm
# 0
# Images_Train\00000\00000_00027.ppm
# 0
# Images_Train\00000\00000_00028.ppm
# 0
# Images_Train\00000\00000_00029.ppm
# 0
# Images_Train\00000\00001_00000.ppm
# 0
# Images_Train\00000\00001_00001.ppm
# 0
# Images_Train\00000\00001_00002.ppm
# 0
# Images_Train\00000\00001_00003.ppm
# 0
# Images_Train\00000\00001_00004.ppm
# 0
# Images_Train\00000\00001_00005.ppm
# 0
# Images_Train\00000\00001_00006.ppm
# 0
# Images_Train\00000\00001_00007.ppm
# 0
# Images_Train\00000\00001_00008.ppm
# 0
# Images_Train\00000\00001_00009.ppm
# 0
# Images_Train\00000\00001_00010.ppm
# 0
# Images_Train\00000\00001_00011.ppm
# 0
# Images_Train\00000\00001_00012.ppm
# 0
# Images_Train\00000\00001_00013.ppm
# 0
# Images_Train\00000\00001_00014.ppm
# 0
# Images_Train\00000\00001_00015.ppm
# 0
# Images_Train\00000\00001_00016.ppm
# 0
# Images_Train\00000\00001_00017.ppm
# 0
# Images_Train\00000\00001_00018.ppm
# 0
# Images_Train\00000\00001_00019.ppm
# 0
# Images_Train\00000\00001_00020.ppm
# 0
# Images_Train\00000\00001_00021.ppm
# 0
# Images_Train\00000\00001_00022.ppm
# 0
# Images_Train\00000\00001_00023.ppm
# 0
# Images_Train\00000\00001_00024.ppm
# 0
# Images_Train\00000\00001_00025.ppm
# 0
# Images_Train\00000\00001_00026.ppm
# 0
# Images_Train\00000\00001_00027.ppm
# 0
# Images_Train\00000\00001_00028.ppm
# 0
# Images_Train\00000\00001_00029.ppm
# 0
# Images_Train\00000\00002_00000.ppm
# 0
# Images_Train\00000\00002_00001.ppm
# 0
# Images_Train\00000\00002_00002.ppm
# 0
# Images_Train\00000\00002_00003.ppm
# 0
# Images_Train\00000\00002_00004.ppm
# 0
# Images_Train\00000\00002_00005.ppm
# 0
# Images_Train\00000\00002_00006.ppm
# 0
# Images_Train\00000\00002_00007.ppm
# 0
# Images_Train\00000\00002_00008.ppm
# 0
# Images_Train\00000\00002_00009.ppm
# 0
# Images_Train\00000\00002_00010.ppm
# 0
# Images_Train\00000\00002_00011.ppm
# 0
# Images_Train\00000\00002_00012.ppm
# 0
# Images_Train\00000\00002_00013.ppm
# 0
# Images_Train\00000\00002_00014.ppm
# 0
# Images_Train\00000\00002_00015.ppm
# 0
# Images_Train\00000\00002_00016.ppm
# 0
# Images_Train\00000\00002_00017.ppm
# 0
# Images_Train\00000\00002_00018.ppm
# 0
# Images_Train\00000\00002_00019.ppm
# 0
# Images_Train\00000\00002_00020.ppm
# 0
# Images_Train\00000\00002_00021.ppm
# 0
# Images_Train\00000\00002_00022.ppm
# 0
# Images_Train\00000\00002_00023.ppm
# 0
# Images_Train\00000\00002_00024.ppm
# 0
# Images_Train\00000\00002_00025.ppm
# 0
# Images_Train\00000\00002_00026.ppm
# 0
# Images_Train\00000\00002_00027.ppm
# 0
# Images_Train\00000\00002_00028.ppm
# 0
# Images_Train\00000\00002_00029.ppm
# 0
# Images_Train\00000\00003_00000.ppm
# 0
# Images_Train\00000\00003_00001.ppm
# 0
# Images_Train\00000\00003_00002.ppm
# 0
# Images_Train\00000\00003_00003.ppm
# 0
# Images_Train\00000\00003_00004.ppm
# 0
# Images_Train\00000\00003_00005.ppm
# 0
# Images_Train\00000\00003_00006.ppm
# 0
# Images_Train\00000\00003_00007.ppm
# 0
# Images_Train\00000\00003_00008.ppm
# 0
# Images_Train\00000\00003_00009.ppm
# 0
# Images_Train\00000\00003_00010.ppm
# 0
# Images_Train\00000\00003_00011.ppm
# 0
# Images_Train\00000\00003_00012.ppm
# 0
# Images_Train\00000\00003_00013.ppm
# 0
# Images_Train\00000\00003_00014.ppm
# 0
# Images_Train\00000\00003_00015.ppm
# 0
# Images_Train\00000\00003_00016.ppm
# 0
# Images_Train\00000\00003_00017.ppm
# 0
# Images_Train\00000\00003_00018.ppm
# 0
# Images_Train\00000\00003_00019.ppm
# 0
# Images_Train\00000\00003_00020.ppm
# 0
# Images_Train\00000\00003_00021.ppm
# 0
# Images_Train\00000\00003_00022.ppm
# 0
# Images_Train\00000\00003_00023.ppm
# 0
# Images_Train\00000\00003_00024.ppm
# 0
# Images_Train\00000\00003_00025.ppm
# 0
# Images_Train\00000\00003_00026.ppm
# 0
# Images_Train\00000\00003_00027.ppm
# 0
# Images_Train\00000\00003_00028.ppm
# 0
# Images_Train\00000\00003_00029.ppm
# 0
# Images_Train\00000\00004_00000.ppm
# 0
# Images_Train\00000\00004_00001.ppm
# 0
# Images_Train\00000\00004_00002.ppm
# 0
# Images_Train\00000\00004_00003.ppm
# 0
# Images_Train\00000\00004_00004.ppm
# 0
# Images_Train\00000\00004_00005.ppm
# 0
# Images_Train\00000\00004_00006.ppm
# 0
# Images_Train\00000\00004_00007.ppm
# 0
# Images_Train\00000\00004_00008.ppm
# 0
# Images_Train\00000\00004_00009.ppm
# 0
# Images_Train\00000\00004_00010.ppm
# 0
# Images_Train\00000\00004_00011.ppm
# 0
# Images_Train\00000\00004_00012.ppm
# 0
# Images_Train\00000\00004_00013.ppm
# 0
# Images_Train\00000\00004_00014.ppm
# 0
# Images_Train\00000\00004_00015.ppm
# 0
# Images_Train\00000\00004_00016.ppm
# 0
# Images_Train\00000\00004_00017.ppm
# 0
# Images_Train\00000\00004_00018.ppm
# 0
# Images_Train\00000\00004_00019.ppm
# 0
# Images_Train\00000\00004_00020.ppm
# 0
# Images_Train\00000\00004_00021.ppm
# 0
# Images_Train\00000\00004_00022.ppm
# 0
# Images_Train\00000\00004_00023.ppm
# 0
# Images_Train\00000\00004_00024.ppm
# 0
# Images_Train\00000\00004_00025.ppm
# 0
# Images_Train\00000\00004_00026.ppm
# 0
# Images_Train\00000\00004_00027.ppm
# 0
# Images_Train\00000\00004_00028.ppm
# 0
# Images_Train\00000\00004_00029.ppm
# 0
# Images_Train\00000\00005_00000.ppm
# 0
# Images_Train\00000\00005_00001.ppm
# 0
# Images_Train\00000\00005_00002.ppm
# 0
# Images_Train\00000\00005_00003.ppm
# 0
# Images_Train\00000\00005_00004.ppm
# 0
# Images_Train\00000\00005_00005.ppm
# 0
# Images_Train\00000\00005_00006.ppm
# 0
# Images_Train\00000\00005_00007.ppm
# 0
# Images_Train\00000\00005_00008.ppm
# 0
# Images_Train\00000\00005_00009.ppm
# 0
# Images_Train\00000\00005_00010.ppm
# 0
# Images_Train\00000\00005_00011.ppm
# 0
# Images_Train\00000\00005_00012.ppm
# 0
# Images_Train\00000\00005_00013.ppm
# 0
# Images_Train\00000\00005_00014.ppm
# 0
# Images_Train\00000\00005_00015.ppm
# 0
# Images_Train\00000\00005_00016.ppm
# 0
# Images_Train\00000\00005_00017.ppm
# 0
# Images_Train\00000\00005_00018.ppm
# 0
# Images_Train\00000\00005_00019.ppm
# 0
# Images_Train\00000\00005_00020.ppm
# 0
# Images_Train\00000\00005_00021.ppm
# 0
# Images_Train\00000\00005_00022.ppm
# 0
# Images_Train\00000\00005_00023.ppm
# 0
# Images_Train\00000\00005_00024.ppm
# 0
# Images_Train\00000\00005_00025.ppm
# 0
# Images_Train\00000\00005_00026.ppm
# 0
# Images_Train\00000\00005_00027.ppm
# 0
# Images_Train\00000\00005_00028.ppm
# 0
# Images_Train\00000\00005_00029.ppm
# 0
# Images_Train\00000\00006_00000.ppm
# 0
# Images_Train\00000\00006_00001.ppm
# 0
# Images_Train\00000\00006_00002.ppm
# 0
# Images_Train\00000\00006_00003.ppm
# 0
# Images_Train\00000\00006_00004.ppm
# 0
# Images_Train\00000\00006_00005.ppm
# 0
# Images_Train\00000\00006_00006.ppm
# 0
# Images_Train\00000\00006_00007.ppm
# 0
# Images_Train\00000\00006_00008.ppm
# 0
# Images_Train\00000\00006_00009.ppm
# 0
# Images_Train\00000\00006_00010.ppm
# 0
# Images_Train\00000\00006_00011.ppm
# 0
# Images_Train\00000\00006_00012.ppm
# 0
# Images_Train\00000\00006_00013.ppm
# 0
# Images_Train\00000\00006_00014.ppm
# 0
# Images_Train\00000\00006_00015.ppm
# 0
# Images_Train\00000\00006_00016.ppm
# 0
# Images_Train\00000\00006_00017.ppm
# 0
# Images_Train\00000\00006_00018.ppm
# 0
# Images_Train\00000\00006_00019.ppm
# 0
# Images_Train\00000\00006_00020.ppm
# 0
# Images_Train\00000\00006_00021.ppm
# 0
# Images_Train\00000\00006_00022.ppm
# 0
# Images_Train\00000\00006_00023.ppm
# 0
# Images_Train\00000\00006_00024.ppm
# 0
# Images_Train\00000\00006_00025.ppm
# 0
# Images_Train\00000\00006_00026.ppm
# 0
# Images_Train\00000\00006_00027.ppm
# 0
# Images_Train\00000\00006_00028.ppm
# 0
# Images_Train\00000\00006_00029.ppm
# 0
# Images_Train\00001
# Images_Train\00001\00000_00000.ppm
# 1
# Images_Train\00001\00000_00001.ppm
# 1
# Images_Train\00001\00000_00002.ppm
# 1
# Images_Train\00001\00000_00003.ppm
# 1
# Images_Train\00001\00000_00004.ppm
# 1
# Images_Train\00001\00000_00005.ppm
# 1
# Images_Train\00001\00000_00006.ppm
# 1
# Images_Train\00001\00000_00007.ppm
# 1
# Images_Train\00001\00000_00008.ppm
# 1
# Images_Train\00001\00000_00009.ppm
# 1
# Images_Train\00001\00000_00010.ppm
# 1
# Images_Train\00001\00000_00011.ppm
# 1
# Images_Train\00001\00000_00012.ppm
# 1
# Images_Train\00001\00000_00013.ppm
# 1
# Images_Train\00001\00000_00014.ppm
# 1
# Images_Train\00001\00000_00015.ppm
# 1
# Images_Train\00001\00000_00016.ppm
# 1
# Images_Train\00001\00000_00017.ppm
# 1
# Images_Train\00001\00000_00018.ppm
# 1
# Images_Train\00001\00000_00019.ppm
# 1
# Images_Train\00001\00000_00020.ppm
# 1
# Images_Train\00001\00000_00021.ppm
# 1
# Images_Train\00001\00000_00022.ppm
# 1
# Images_Train\00001\00000_00023.ppm
# 1
# Images_Train\00001\00000_00024.ppm
# 1
# Images_Train\00001\00000_00025.ppm
# 1
# Images_Train\00001\00000_00026.ppm
# 1
# Images_Train\00001\00000_00027.ppm
# 1
# Images_Train\00001\00000_00028.ppm
# 1
# Images_Train\00001\00000_00029.ppm
# 1
# Images_Train\00001\00001_00000.ppm
# 1
# Images_Train\00001\00001_00001.ppm
# 1
# Images_Train\00001\00001_00002.ppm
# 1
# Images_Train\00001\00001_00003.ppm
# 1
# Images_Train\00001\00001_00004.ppm
# 1
# Images_Train\00001\00001_00005.ppm
# 1
# Images_Train\00001\00001_00006.ppm
# 1
# Images_Train\00001\00001_00007.ppm
# 1
# Images_Train\00001\00001_00008.ppm
# 1
# Images_Train\00001\00001_00009.ppm
# 1
# Images_Train\00001\00001_00010.ppm
# 1
# Images_Train\00001\00001_00011.ppm
# 1
# Images_Train\00001\00001_00012.ppm
# 1
# Images_Train\00001\00001_00013.ppm
# 1
# Images_Train\00001\00001_00014.ppm
# 1
# Images_Train\00001\00001_00015.ppm
# 1
# Images_Train\00001\00001_00016.ppm
# 1
# Images_Train\00001\00001_00017.ppm
# 1
# Images_Train\00001\00001_00018.ppm
# 1
# Images_Train\00001\00001_00019.ppm
# 1
# Images_Train\00001\00001_00020.ppm
# 1
# Images_Train\00001\00001_00021.ppm
# 1
# Images_Train\00001\00001_00022.ppm
# 1
# Images_Train\00001\00001_00023.ppm
# 1
# Images_Train\00001\00001_00024.ppm
# 1
# Images_Train\00001\00001_00025.ppm
# 1
# Images_Train\00001\00001_00026.ppm
# 1
# Images_Train\00001\00001_00027.ppm
# 1
# Images_Train\00001\00001_00028.ppm
# 1
# Images_Train\00001\00001_00029.ppm
# 1
# Images_Train\00001\00002_00000.ppm
# 1
# Images_Train\00001\00002_00001.ppm
# 1
# Images_Train\00001\00002_00002.ppm
# 1
# Images_Train\00001\00002_00003.ppm
# 1
# Images_Train\00001\00002_00004.ppm
# 1
# Images_Train\00001\00002_00005.ppm
# 1
# Images_Train\00001\00002_00006.ppm
# 1
# Images_Train\00001\00002_00007.ppm
# 1
# Images_Train\00001\00002_00008.ppm
# 1
# Images_Train\00001\00002_00009.ppm
# 1
# Images_Train\00001\00002_00010.ppm
# 1
# Images_Train\00001\00002_00011.ppm
# 1
# Images_Train\00001\00002_00012.ppm
# 1
# Images_Train\00001\00002_00013.ppm
# 1
# Images_Train\00001\00002_00014.ppm
# 1
# Images_Train\00001\00002_00015.ppm
# 1
# Images_Train\00001\00002_00016.ppm
# 1
# Images_Train\00001\00002_00017.ppm
# 1
# Images_Train\00001\00002_00018.ppm
# 1
# Images_Train\00001\00002_00019.ppm
# 1
# Images_Train\00001\00002_00020.ppm
# 1
# Images_Train\00001\00002_00021.ppm
# 1
# Images_Train\00001\00002_00022.ppm
# 1
# Images_Train\00001\00002_00023.ppm
# 1
# Images_Train\00001\00002_00024.ppm
# 1
# Images_Train\00001\00002_00025.ppm
# 1
# Images_Train\00001\00002_00026.ppm
# 1
# Images_Train\00001\00002_00027.ppm
# 1
# Images_Train\00001\00002_00028.ppm
# 1
# Images_Train\00001\00002_00029.ppm
# 1
# Images_Train\00001\00003_00000.ppm
# 1
# Images_Train\00001\00003_00001.ppm
# 1
# Images_Train\00001\00003_00002.ppm
# 1
# Images_Train\00001\00003_00003.ppm
# 1
# Images_Train\00001\00003_00004.ppm
# 1
# Images_Train\00001\00003_00005.ppm
# 1
# Images_Train\00001\00003_00006.ppm
# 1
# Images_Train\00001\00003_00007.ppm
# 1
# Images_Train\00001\00003_00008.ppm
# 1
# Images_Train\00001\00003_00009.ppm
# 1
# Images_Train\00001\00003_00010.ppm
# 1
# Images_Train\00001\00003_00011.ppm
# 1
# Images_Train\00001\00003_00012.ppm
# 1
# Images_Train\00001\00003_00013.ppm
# 1
# Images_Train\00001\00003_00014.ppm
# 1
# Images_Train\00001\00003_00015.ppm
# 1
# Images_Train\00001\00003_00016.ppm
# 1
# Images_Train\00001\00003_00017.ppm
# 1
# Images_Train\00001\00003_00018.ppm
# 1
# Images_Train\00001\00003_00019.ppm
# 1
# Images_Train\00001\00003_00020.ppm
# 1
# Images_Train\00001\00003_00021.ppm
# 1
# Images_Train\00001\00003_00022.ppm
# 1
# Images_Train\00001\00003_00023.ppm
# 1
# Images_Train\00001\00003_00024.ppm
# 1
# Images_Train\00001\00003_00025.ppm
# 1
# Images_Train\00001\00003_00026.ppm
# 1
# Images_Train\00001\00003_00027.ppm
# 1
# Images_Train\00001\00003_00028.ppm
# 1
# Images_Train\00001\00003_00029.ppm
# 1
# Images_Train\00001\00004_00000.ppm
# 1
# Images_Train\00001\00004_00001.ppm
# 1
# Images_Train\00001\00004_00002.ppm
# 1
# Images_Train\00001\00004_00003.ppm
# 1
# Images_Train\00001\00004_00004.ppm
# 1
# Images_Train\00001\00004_00005.ppm
# 1
# Images_Train\00001\00004_00006.ppm
# 1
# Images_Train\00001\00004_00007.ppm
# 1
# Images_Train\00001\00004_00008.ppm
# 1
# Images_Train\00001\00004_00009.ppm
# 1
# Images_Train\00001\00004_00010.ppm
# 1
# Images_Train\00001\00004_00011.ppm
# 1
# Images_Train\00001\00004_00012.ppm
# 1
# Images_Train\00001\00004_00013.ppm
# 1
# Images_Train\00001\00004_00014.ppm
# 1
# Images_Train\00001\00004_00015.ppm
# 1
# Images_Train\00001\00004_00016.ppm
# 1
# Images_Train\00001\00004_00017.ppm
# 1
# Images_Train\00001\00004_00018.ppm
# 1
# Images_Train\00001\00004_00019.ppm
# 1
# Images_Train\00001\00004_00020.ppm
# 1
# Images_Train\00001\00004_00021.ppm
# 1
# Images_Train\00001\00004_00022.ppm
# 1
# Images_Train\00001\00004_00023.ppm
# 1
# Images_Train\00001\00004_00024.ppm
# 1
# Images_Train\00001\00004_00025.ppm
# 1
# Images_Train\00001\00004_00026.ppm
# 1
# Images_Train\00001\00004_00027.ppm
# 1
# Images_Train\00001\00004_00028.ppm
# 1
# Images_Train\00001\00004_00029.ppm
# 1
# Images_Train\00001\00005_00000.ppm
# 1
# Images_Train\00001\00005_00001.ppm
# 1
# Images_Train\00001\00005_00002.ppm
# 1
# Images_Train\00001\00005_00003.ppm
# 1
# Images_Train\00001\00005_00004.ppm
# 1
# Images_Train\00001\00005_00005.ppm
# 1
# Images_Train\00001\00005_00006.ppm
# 1
# Images_Train\00001\00005_00007.ppm
# 1
# Images_Train\00001\00005_00008.ppm
# 1
# Images_Train\00001\00005_00009.ppm
# 1
# Images_Train\00001\00005_00010.ppm
# 1
# Images_Train\00001\00005_00011.ppm
# 1
# Images_Train\00001\00005_00012.ppm
# 1
# Images_Train\00001\00005_00013.ppm
# 1
# Images_Train\00001\00005_00014.ppm
# 1
# Images_Train\00001\00005_00015.ppm
# 1
# Images_Train\00001\00005_00016.ppm
# 1
# Images_Train\00001\00005_00017.ppm
# 1
# Images_Train\00001\00005_00018.ppm
# 1
# Images_Train\00001\00005_00019.ppm
# 1
# Images_Train\00001\00005_00020.ppm
# 1
# Images_Train\00001\00005_00021.ppm
# 1
# Images_Train\00001\00005_00022.ppm
# 1
# Images_Train\00001\00005_00023.ppm
# 1
# Images_Train\00001\00005_00024.ppm
# 1
# Images_Train\00001\00005_00025.ppm
# 1
# Images_Train\00001\00005_00026.ppm
# 1
# Images_Train\00001\00005_00027.ppm
# 1
# Images_Train\00001\00005_00028.ppm
# 1
# Images_Train\00001\00005_00029.ppm
# 1
# Images_Train\00001\00006_00000.ppm
# 1
# Images_Train\00001\00006_00001.ppm
# 1
# Images_Train\00001\00006_00002.ppm
# 1
# Images_Train\00001\00006_00003.ppm
# 1
# Images_Train\00001\00006_00004.ppm
# 1
# Images_Train\00001\00006_00005.ppm
# 1
# Images_Train\00001\00006_00006.ppm
# 1
# Images_Train\00001\00006_00007.ppm
# 1
# Images_Train\00001\00006_00008.ppm
# 1
# Images_Train\00001\00006_00009.ppm
# 1
# Images_Train\00001\00006_00010.ppm
# 1
# Images_Train\00001\00006_00011.ppm
# 1
# Images_Train\00001\00006_00012.ppm
# 1
# Images_Train\00001\00006_00013.ppm
# 1
# Images_Train\00001\00006_00014.ppm
# 1
# Images_Train\00001\00006_00015.ppm
# 1
# Images_Train\00001\00006_00016.ppm
# 1
# Images_Train\00001\00006_00017.ppm
# 1
# Images_Train\00001\00006_00018.ppm
# 1
# Images_Train\00001\00006_00019.ppm
# 1
# Images_Train\00001\00006_00020.ppm
# 1
# Images_Train\00001\00006_00021.ppm
# 1
# Images_Train\00001\00006_00022.ppm
# 1
# Images_Train\00001\00006_00023.ppm
# 1
# Images_Train\00001\00006_00024.ppm
# 1
# Images_Train\00001\00006_00025.ppm
# 1
# Images_Train\00001\00006_00026.ppm
# 1
# Images_Train\00001\00006_00027.ppm
# 1
# Images_Train\00001\00006_00028.ppm
# 1
# Images_Train\00001\00006_00029.ppm
# 1
# Images_Train\00001\00007_00000.ppm
# 1
# Images_Train\00001\00007_00001.ppm
# 1
# Images_Train\00001\00007_00002.ppm
# 1
# Images_Train\00001\00007_00003.ppm
# 1
# Images_Train\00001\00007_00004.ppm
# 1
# Images_Train\00001\00007_00005.ppm
# 1
# Images_Train\00001\00007_00006.ppm
# 1
# Images_Train\00001\00007_00007.ppm
# 1
# Images_Train\00001\00007_00008.ppm
# 1
# Images_Train\00001\00007_00009.ppm
# 1
# Images_Train\00001\00007_00010.ppm
# 1
# Images_Train\00001\00007_00011.ppm
# 1
# Images_Train\00001\00007_00012.ppm
# 1
# Images_Train\00001\00007_00013.ppm
# 1
# Images_Train\00001\00007_00014.ppm
# 1
# Images_Train\00001\00007_00015.ppm
# 1
# Images_Train\00001\00007_00016.ppm
# 1
# Images_Train\00001\00007_00017.ppm
# 1
# Images_Train\00001\00007_00018.ppm
# 1
# Images_Train\00001\00007_00019.ppm
# 1
# Images_Train\00001\00007_00020.ppm
# 1
# Images_Train\00001\00007_00021.ppm
# 1
# Images_Train\00001\00007_00022.ppm
# 1
# Images_Train\00001\00007_00023.ppm
# 1
# Images_Train\00001\00007_00024.ppm
# 1
# Images_Train\00001\00007_00025.ppm
# 1
# Images_Train\00001\00007_00026.ppm
# 1
# Images_Train\00001\00007_00027.ppm
# 1
# Images_Train\00001\00007_00028.ppm
# 1
# Images_Train\00001\00007_00029.ppm
# 1
# Images_Train\00001\00008_00000.ppm
# 1
# Images_Train\00001\00008_00001.ppm
# 1
# Images_Train\00001\00008_00002.ppm
# 1
# Images_Train\00001\00008_00003.ppm
# 1
# Images_Train\00001\00008_00004.ppm
# 1
# Images_Train\00001\00008_00005.ppm
# 1
# Images_Train\00001\00008_00006.ppm
# 1
# Images_Train\00001\00008_00007.ppm
# 1
# Images_Train\00001\00008_00008.ppm
# 1
# Images_Train\00001\00008_00009.ppm
# 1
# Images_Train\00001\00008_00010.ppm
# 1
# Images_Train\00001\00008_00011.ppm
# 1
# Images_Train\00001\00008_00012.ppm
# 1
# Images_Train\00001\00008_00013.ppm
# 1
# Images_Train\00001\00008_00014.ppm
# 1
# Images_Train\00001\00008_00015.ppm
# 1
# Images_Train\00001\00008_00016.ppm
# 1
# Images_Train\00001\00008_00017.ppm
# 1
# Images_Train\00001\00008_00018.ppm
# 1
# Images_Train\00001\00008_00019.ppm
# 1
# Images_Train\00001\00008_00020.ppm
# 1
# Images_Train\00001\00008_00021.ppm
# 1
# Images_Train\00001\00008_00022.ppm
# 1
# Images_Train\00001\00008_00023.ppm
# 1
# Images_Train\00001\00008_00024.ppm
# 1
# Images_Train\00001\00008_00025.ppm
# 1
# Images_Train\00001\00008_00026.ppm
# 1
# Images_Train\00001\00008_00027.ppm
# 1
# Images_Train\00001\00008_00028.ppm
# 1
# Images_Train\00001\00008_00029.ppm
# 1
# Images_Train\00001\00009_00000.ppm
# 1
# Images_Train\00001\00009_00001.ppm
# 1
# Images_Train\00001\00009_00002.ppm
# 1
# Images_Train\00001\00009_00003.ppm
# 1
# Images_Train\00001\00009_00004.ppm
# 1
# Images_Train\00001\00009_00005.ppm
# 1
# Images_Train\00001\00009_00006.ppm
# 1
# Images_Train\00001\00009_00007.ppm
# 1
# Images_Train\00001\00009_00008.ppm
# 1
# Images_Train\00001\00009_00009.ppm
# 1
# Images_Train\00001\00009_00010.ppm
# 1
# Images_Train\00001\00009_00011.ppm
# 1
# Images_Train\00001\00009_00012.ppm
# 1
# Images_Train\00001\00009_00013.ppm
# 1
# Images_Train\00001\00009_00014.ppm
# 1
# Images_Train\00001\00009_00015.ppm
# 1
# Images_Train\00001\00009_00016.ppm
# 1
# Images_Train\00001\00009_00017.ppm
# 1
# Images_Train\00001\00009_00018.ppm
# 1
# Images_Train\00001\00009_00019.ppm
# 1
# Images_Train\00001\00009_00020.ppm
# 1
# Images_Train\00001\00009_00021.ppm
# 1
# Images_Train\00001\00009_00022.ppm
# 1
# Images_Train\00001\00009_00023.ppm
# 1
# Images_Train\00001\00009_00024.ppm
# 1
# Images_Train\00001\00009_00025.ppm
# 1
# Images_Train\00001\00009_00026.ppm
# 1
# Images_Train\00001\00009_00027.ppm
# 1
# Images_Train\00001\00009_00028.ppm
# 1
# Images_Train\00001\00009_00029.ppm
# 1
# Images_Train\00001\00010_00000.ppm
# 1
# Images_Train\00001\00010_00001.ppm
# 1
# Images_Train\00001\00010_00002.ppm
# 1
# Images_Train\00001\00010_00003.ppm
# 1
# Images_Train\00001\00010_00004.ppm
# 1
# Images_Train\00001\00010_00005.ppm
# 1
# Images_Train\00001\00010_00006.ppm
# 1
# Images_Train\00001\00010_00007.ppm
# 1
# Images_Train\00001\00010_00008.ppm
# 1
# Images_Train\00001\00010_00009.ppm
# 1
# Images_Train\00001\00010_00010.ppm
# 1
# Images_Train\00001\00010_00011.ppm
# 1
# Images_Train\00001\00010_00012.ppm
# 1
# Images_Train\00001\00010_00013.ppm
# 1
# Images_Train\00001\00010_00014.ppm
# 1
# Images_Train\00001\00010_00015.ppm
# 1
# Images_Train\00001\00010_00016.ppm
# 1
# Images_Train\00001\00010_00017.ppm
# 1
# Images_Train\00001\00010_00018.ppm
# 1
# Images_Train\00001\00010_00019.ppm
# 1
# Images_Train\00001\00010_00020.ppm
# 1
# Images_Train\00001\00010_00021.ppm
# 1
# Images_Train\00001\00010_00022.ppm
# 1
# Images_Train\00001\00010_00023.ppm
# 1
# Images_Train\00001\00010_00024.ppm
# 1
# Images_Train\00001\00010_00025.ppm
# 1
# Images_Train\00001\00010_00026.ppm
# 1
# Images_Train\00001\00010_00027.ppm
# 1
# Images_Train\00001\00010_00028.ppm
# 1
# Images_Train\00001\00010_00029.ppm
# 1
# Images_Train\00001\00011_00000.ppm
# 1
# Images_Train\00001\00011_00001.ppm
# 1
# Images_Train\00001\00011_00002.ppm
# 1
# Images_Train\00001\00011_00003.ppm
# 1
# Images_Train\00001\00011_00004.ppm
# 1
# Images_Train\00001\00011_00005.ppm
# 1
# Images_Train\00001\00011_00006.ppm
# 1
# Images_Train\00001\00011_00007.ppm
# 1
# Images_Train\00001\00011_00008.ppm
# 1
# Images_Train\00001\00011_00009.ppm
# 1
# Images_Train\00001\00011_00010.ppm
# 1
# Images_Train\00001\00011_00011.ppm
# 1
# Images_Train\00001\00011_00012.ppm
# 1
# Images_Train\00001\00011_00013.ppm
# 1
# Images_Train\00001\00011_00014.ppm
# 1
# Images_Train\00001\00011_00015.ppm
# 1
# Images_Train\00001\00011_00016.ppm
# 1
# Images_Train\00001\00011_00017.ppm
# 1
# Images_Train\00001\00011_00018.ppm
# 1
# Images_Train\00001\00011_00019.ppm
# 1
# Images_Train\00001\00011_00020.ppm
# 1
# Images_Train\00001\00011_00021.ppm
# 1
# Images_Train\00001\00011_00022.ppm
# 1
# Images_Train\00001\00011_00023.ppm
# 1
# Images_Train\00001\00011_00024.ppm
# 1
# Images_Train\00001\00011_00025.ppm
# 1
# Images_Train\00001\00011_00026.ppm
# 1
# Images_Train\00001\00011_00027.ppm
# 1
# Images_Train\00001\00011_00028.ppm
# 1
# Images_Train\00001\00011_00029.ppm
# 1
# Images_Train\00001\00012_00000.ppm
# 1
# Images_Train\00001\00012_00001.ppm
# 1
# Images_Train\00001\00012_00002.ppm
# 1
# Images_Train\00001\00012_00003.ppm
# 1
# Images_Train\00001\00012_00004.ppm
# 1
# Images_Train\00001\00012_00005.ppm
# 1
# Images_Train\00001\00012_00006.ppm
# 1
# Images_Train\00001\00012_00007.ppm
# 1
# Images_Train\00001\00012_00008.ppm
# 1
# Images_Train\00001\00012_00009.ppm
# 1
# Images_Train\00001\00012_00010.ppm
# 1
# Images_Train\00001\00012_00011.ppm
# 1
# Images_Train\00001\00012_00012.ppm
# 1
# Images_Train\00001\00012_00013.ppm
# 1
# Images_Train\00001\00012_00014.ppm
# 1
# Images_Train\00001\00012_00015.ppm
# 1
# Images_Train\00001\00012_00016.ppm
# 1
# Images_Train\00001\00012_00017.ppm
# 1
# Images_Train\00001\00012_00018.ppm
# 1
# Images_Train\00001\00012_00019.ppm
# 1
# Images_Train\00001\00012_00020.ppm
# 1
# Images_Train\00001\00012_00021.ppm
# 1
# Images_Train\00001\00012_00022.ppm
# 1
# Images_Train\00001\00012_00023.ppm
# 1
# Images_Train\00001\00012_00024.ppm
# 1
# Images_Train\00001\00012_00025.ppm
# 1
# Images_Train\00001\00012_00026.ppm
# 1
# Images_Train\00001\00012_00027.ppm
# 1
# Images_Train\00001\00012_00028.ppm
# 1
# Images_Train\00001\00012_00029.ppm
# 1
# Images_Train\00001\00013_00000.ppm
# 1
# Images_Train\00001\00013_00001.ppm
# 1
# Images_Train\00001\00013_00002.ppm
# 1
# Images_Train\00001\00013_00003.ppm
# 1
# Images_Train\00001\00013_00004.ppm
# 1
# Images_Train\00001\00013_00005.ppm
# 1
# Images_Train\00001\00013_00006.ppm
# 1
# Images_Train\00001\00013_00007.ppm
# 1
# Images_Train\00001\00013_00008.ppm
# 1
# Images_Train\00001\00013_00009.ppm
# 1
# Images_Train\00001\00013_00010.ppm
# 1
# Images_Train\00001\00013_00011.ppm
# 1
# Images_Train\00001\00013_00012.ppm
# 1
# Images_Train\00001\00013_00013.ppm
# 1
# Images_Train\00001\00013_00014.ppm
# 1
# Images_Train\00001\00013_00015.ppm
# 1
# Images_Train\00001\00013_00016.ppm
# 1
# Images_Train\00001\00013_00017.ppm
# 1
# Images_Train\00001\00013_00018.ppm
# 1
# Images_Train\00001\00013_00019.ppm
# 1
# Images_Train\00001\00013_00020.ppm
# 1
# Images_Train\00001\00013_00021.ppm
# 1
# Images_Train\00001\00013_00022.ppm
# 1
# Images_Train\00001\00013_00023.ppm
# 1
# Images_Train\00001\00013_00024.ppm
# 1
# Images_Train\00001\00013_00025.ppm
# 1
# Images_Train\00001\00013_00026.ppm
# 1
# Images_Train\00001\00013_00027.ppm
# 1
# Images_Train\00001\00013_00028.ppm
# 1
# Images_Train\00001\00013_00029.ppm
# 1
# Images_Train\00001\00014_00000.ppm
# 1
# Images_Train\00001\00014_00001.ppm
# 1
# Images_Train\00001\00014_00002.ppm
# 1
# Images_Train\00001\00014_00003.ppm
# 1
# Images_Train\00001\00014_00004.ppm
# 1
# Images_Train\00001\00014_00005.ppm
# 1
# Images_Train\00001\00014_00006.ppm
# 1
# Images_Train\00001\00014_00007.ppm
# 1
# Images_Train\00001\00014_00008.ppm
# 1
# Images_Train\00001\00014_00009.ppm
# 1
# Images_Train\00001\00014_00010.ppm
# 1
# Images_Train\00001\00014_00011.ppm
# 1
# Images_Train\00001\00014_00012.ppm
# 1
# Images_Train\00001\00014_00013.ppm
# 1
# Images_Train\00001\00014_00014.ppm
# 1
# Images_Train\00001\00014_00015.ppm
# 1
# Images_Train\00001\00014_00016.ppm
# 1
# Images_Train\00001\00014_00017.ppm
# 1
# Images_Train\00001\00014_00018.ppm
# 1
# Images_Train\00001\00014_00019.ppm
# 1
# Images_Train\00001\00014_00020.ppm
# 1
# Images_Train\00001\00014_00021.ppm
# 1
# Images_Train\00001\00014_00022.ppm
# 1
# Images_Train\00001\00014_00023.ppm
# 1
# Images_Train\00001\00014_00024.ppm
# 1
# Images_Train\00001\00014_00025.ppm
# 1
# Images_Train\00001\00014_00026.ppm
# 1
# Images_Train\00001\00014_00027.ppm
# 1
# Images_Train\00001\00014_00028.ppm
# 1
# Images_Train\00001\00014_00029.ppm
# 1
# Images_Train\00001\00015_00000.ppm
# 1
# Images_Train\00001\00015_00001.ppm
# 1
# Images_Train\00001\00015_00002.ppm
# 1
# Images_Train\00001\00015_00003.ppm
# 1
# Images_Train\00001\00015_00004.ppm
# 1
# Images_Train\00001\00015_00005.ppm
# 1
# Images_Train\00001\00015_00006.ppm
# 1
# Images_Train\00001\00015_00007.ppm
# 1
# Images_Train\00001\00015_00008.ppm
# 1
# Images_Train\00001\00015_00009.ppm
# 1
# Images_Train\00001\00015_00010.ppm
# 1
# Images_Train\00001\00015_00011.ppm
# 1
# Images_Train\00001\00015_00012.ppm
# 1
# Images_Train\00001\00015_00013.ppm
# 1
# Images_Train\00001\00015_00014.ppm
# 1
# Images_Train\00001\00015_00015.ppm
# 1
# Images_Train\00001\00015_00016.ppm
# 1
# Images_Train\00001\00015_00017.ppm
# 1
# Images_Train\00001\00015_00018.ppm
# 1
# Images_Train\00001\00015_00019.ppm
# 1
# Images_Train\00001\00015_00020.ppm
# 1
# Images_Train\00001\00015_00021.ppm
# 1
# Images_Train\00001\00015_00022.ppm
# 1
# Images_Train\00001\00015_00023.ppm
# 1
# Images_Train\00001\00015_00024.ppm
# 1
# Images_Train\00001\00015_00025.ppm
# 1
# Images_Train\00001\00015_00026.ppm
# 1
# Images_Train\00001\00015_00027.ppm
# 1
# Images_Train\00001\00015_00028.ppm
# 1
# Images_Train\00001\00015_00029.ppm
# 1
# Images_Train\00001\00016_00000.ppm
# 1
# Images_Train\00001\00016_00001.ppm
# 1
# Images_Train\00001\00016_00002.ppm
# 1
# Images_Train\00001\00016_00003.ppm
# 1
# Images_Train\00001\00016_00004.ppm
# 1
# Images_Train\00001\00016_00005.ppm
# 1
# Images_Train\00001\00016_00006.ppm
# 1
# Images_Train\00001\00016_00007.ppm
# 1
# Images_Train\00001\00016_00008.ppm
# 1
# Images_Train\00001\00016_00009.ppm
# 1
# Images_Train\00001\00016_00010.ppm
# 1
# Images_Train\00001\00016_00011.ppm
# 1
# Images_Train\00001\00016_00012.ppm
# 1
# Images_Train\00001\00016_00013.ppm
# 1
# Images_Train\00001\00016_00014.ppm
# 1
# Images_Train\00001\00016_00015.ppm
# 1
# Images_Train\00001\00016_00016.ppm
# 1
# Images_Train\00001\00016_00017.ppm
# 1
# Images_Train\00001\00016_00018.ppm
# 1
# Images_Train\00001\00016_00019.ppm
# 1
# Images_Train\00001\00016_00020.ppm
# 1
# Images_Train\00001\00016_00021.ppm
# 1
# Images_Train\00001\00016_00022.ppm
# 1
# Images_Train\00001\00016_00023.ppm
# 1
# Images_Train\00001\00016_00024.ppm
# 1
# Images_Train\00001\00016_00025.ppm
# 1
# Images_Train\00001\00016_00026.ppm
# 1
# Images_Train\00001\00016_00027.ppm
# 1
# Images_Train\00001\00016_00028.ppm
# 1
# Images_Train\00001\00016_00029.ppm
# 1
# Images_Train\00001\00017_00000.ppm
# 1
# Images_Train\00001\00017_00001.ppm
# 1
# Images_Train\00001\00017_00002.ppm
# 1
# Images_Train\00001\00017_00003.ppm
# 1
# Images_Train\00001\00017_00004.ppm
# 1
# Images_Train\00001\00017_00005.ppm
# 1
# Images_Train\00001\00017_00006.ppm
# 1
# Images_Train\00001\00017_00007.ppm
# 1
# Images_Train\00001\00017_00008.ppm
# 1
# Images_Train\00001\00017_00009.ppm
# 1
# Images_Train\00001\00017_00010.ppm
# 1
# Images_Train\00001\00017_00011.ppm
# 1
# Images_Train\00001\00017_00012.ppm
# 1
# Images_Train\00001\00017_00013.ppm
# 1
# Images_Train\00001\00017_00014.ppm
# 1
# Images_Train\00001\00017_00015.ppm
# 1
# Images_Train\00001\00017_00016.ppm
# 1
# Images_Train\00001\00017_00017.ppm
# 1
# Images_Train\00001\00017_00018.ppm
# 1
# Images_Train\00001\00017_00019.ppm
# 1
# Images_Train\00001\00017_00020.ppm
# 1
# Images_Train\00001\00017_00021.ppm
# 1
# Images_Train\00001\00017_00022.ppm
# 1
# Images_Train\00001\00017_00023.ppm
# 1
# Images_Train\00001\00017_00024.ppm
# 1
# Images_Train\00001\00017_00025.ppm
# 1
# Images_Train\00001\00017_00026.ppm
# 1
# Images_Train\00001\00017_00027.ppm
# 1
# Images_Train\00001\00017_00028.ppm
# 1
# Images_Train\00001\00017_00029.ppm
# 1
# Images_Train\00001\00018_00000.ppm
# 1
# Images_Train\00001\00018_00001.ppm
# 1
# Images_Train\00001\00018_00002.ppm
# 1
# Images_Train\00001\00018_00003.ppm
# 1
# Images_Train\00001\00018_00004.ppm
# 1
# Images_Train\00001\00018_00005.ppm
# 1
# Images_Train\00001\00018_00006.ppm
# 1
# Images_Train\00001\00018_00007.ppm
# 1
# Images_Train\00001\00018_00008.ppm
# 1
# Images_Train\00001\00018_00009.ppm
# 1
# Images_Train\00001\00018_00010.ppm
# 1
# Images_Train\00001\00018_00011.ppm
# 1
# Images_Train\00001\00018_00012.ppm
# 1
# Images_Train\00001\00018_00013.ppm
# 1
# Images_Train\00001\00018_00014.ppm
# 1
# Images_Train\00001\00018_00015.ppm
# 1
# Images_Train\00001\00018_00016.ppm
# 1
# Images_Train\00001\00018_00017.ppm
# 1
# Images_Train\00001\00018_00018.ppm
# 1
# Images_Train\00001\00018_00019.ppm
# 1
# Images_Train\00001\00018_00020.ppm
# 1
# Images_Train\00001\00018_00021.ppm
# 1
# Images_Train\00001\00018_00022.ppm
# 1
# Images_Train\00001\00018_00023.ppm
# 1
# Images_Train\00001\00018_00024.ppm
# 1
# Images_Train\00001\00018_00025.ppm
# 1
# Images_Train\00001\00018_00026.ppm
# 1
# Images_Train\00001\00018_00027.ppm
# 1
# Images_Train\00001\00018_00028.ppm
# 1
# Images_Train\00001\00018_00029.ppm
# 1
# Images_Train\00001\00019_00000.ppm
# 1
# Images_Train\00001\00019_00001.ppm
# 1
# Images_Train\00001\00019_00002.ppm
# 1
# Images_Train\00001\00019_00003.ppm
# 1
# Images_Train\00001\00019_00004.ppm
# 1
# Images_Train\00001\00019_00005.ppm
# 1
# Images_Train\00001\00019_00006.ppm
# 1
# Images_Train\00001\00019_00007.ppm
# 1
# Images_Train\00001\00019_00008.ppm
# 1
# Images_Train\00001\00019_00009.ppm
# 1
# Images_Train\00001\00019_00010.ppm
# 1
# Images_Train\00001\00019_00011.ppm
# 1
# Images_Train\00001\00019_00012.ppm
# 1
# Images_Train\00001\00019_00013.ppm
# 1
# Images_Train\00001\00019_00014.ppm
# 1
# Images_Train\00001\00019_00015.ppm
# 1
# Images_Train\00001\00019_00016.ppm
# 1
# Images_Train\00001\00019_00017.ppm
# 1
# Images_Train\00001\00019_00018.ppm
# 1
# Images_Train\00001\00019_00019.ppm
# 1
# Images_Train\00001\00019_00020.ppm
# 1
# Images_Train\00001\00019_00021.ppm
# 1
# Images_Train\00001\00019_00022.ppm
# 1
# Images_Train\00001\00019_00023.ppm
# 1
# Images_Train\00001\00019_00024.ppm
# 1
# Images_Train\00001\00019_00025.ppm
# 1
# Images_Train\00001\00019_00026.ppm
# 1
# Images_Train\00001\00019_00027.ppm
# 1
# Images_Train\00001\00019_00028.ppm
# 1
# Images_Train\00001\00019_00029.ppm
# 1
# Images_Train\00001\00020_00000.ppm
# 1
# Images_Train\00001\00020_00001.ppm
# 1
# Images_Train\00001\00020_00002.ppm
# 1
# Images_Train\00001\00020_00003.ppm
# 1
# Images_Train\00001\00020_00004.ppm
# 1
# Images_Train\00001\00020_00005.ppm
# 1
# Images_Train\00001\00020_00006.ppm
# 1
# Images_Train\00001\00020_00007.ppm
# 1
# Images_Train\00001\00020_00008.ppm
# 1
# Images_Train\00001\00020_00009.ppm
# 1
# Images_Train\00001\00020_00010.ppm
# 1
# Images_Train\00001\00020_00011.ppm
# 1
# Images_Train\00001\00020_00012.ppm
# 1
# Images_Train\00001\00020_00013.ppm
# 1
# Images_Train\00001\00020_00014.ppm
# 1
# Images_Train\00001\00020_00015.ppm
# 1
# Images_Train\00001\00020_00016.ppm
# 1
# Images_Train\00001\00020_00017.ppm
# 1
# Images_Train\00001\00020_00018.ppm
# 1
# Images_Train\00001\00020_00019.ppm
# 1
# Images_Train\00001\00020_00020.ppm
# 1
# Images_Train\00001\00020_00021.ppm
# 1
# Images_Train\00001\00020_00022.ppm
# 1
# Images_Train\00001\00020_00023.ppm
# 1
# Images_Train\00001\00020_00024.ppm
# 1
# Images_Train\00001\00020_00025.ppm
# 1
# Images_Train\00001\00020_00026.ppm
# 1
# Images_Train\00001\00020_00027.ppm
# 1
# Images_Train\00001\00020_00028.ppm
# 1
# Images_Train\00001\00020_00029.ppm
# 1
# Images_Train\00001\00021_00000.ppm
# 1
# Images_Train\00001\00021_00001.ppm
# 1
# Images_Train\00001\00021_00002.ppm
# 1
# Images_Train\00001\00021_00003.ppm
# 1
# Images_Train\00001\00021_00004.ppm
# 1
# Images_Train\00001\00021_00005.ppm
# 1
# Images_Train\00001\00021_00006.ppm
# 1
# Images_Train\00001\00021_00007.ppm
# 1
# Images_Train\00001\00021_00008.ppm
# 1
# Images_Train\00001\00021_00009.ppm
# 1
# Images_Train\00001\00021_00010.ppm
# 1
# Images_Train\00001\00021_00011.ppm
# 1
# Images_Train\00001\00021_00012.ppm
# 1
# Images_Train\00001\00021_00013.ppm
# 1
# Images_Train\00001\00021_00014.ppm
# 1
# Images_Train\00001\00021_00015.ppm
# 1
# Images_Train\00001\00021_00016.ppm
# 1
# Images_Train\00001\00021_00017.ppm
# 1
# Images_Train\00001\00021_00018.ppm
# 1
# Images_Train\00001\00021_00019.ppm
# 1
# Images_Train\00001\00021_00020.ppm
# 1
# Images_Train\00001\00021_00021.ppm
# 1
# Images_Train\00001\00021_00022.ppm
# 1
# Images_Train\00001\00021_00023.ppm
# 1
# Images_Train\00001\00021_00024.ppm
# 1
# Images_Train\00001\00021_00025.ppm
# 1
# Images_Train\00001\00021_00026.ppm
# 1
# Images_Train\00001\00021_00027.ppm
# 1
# Images_Train\00001\00021_00028.ppm
# 1
# Images_Train\00001\00021_00029.ppm
# 1
# Images_Train\00001\00022_00000.ppm
# 1
# Images_Train\00001\00022_00001.ppm
# 1
# Images_Train\00001\00022_00002.ppm
# 1
# Images_Train\00001\00022_00003.ppm
# 1
# Images_Train\00001\00022_00004.ppm
# 1
# Images_Train\00001\00022_00005.ppm
# 1
# Images_Train\00001\00022_00006.ppm
# 1
# Images_Train\00001\00022_00007.ppm
# 1
# Images_Train\00001\00022_00008.ppm
# 1
# Images_Train\00001\00022_00009.ppm
# 1
# Images_Train\00001\00022_00010.ppm
# 1
# Images_Train\00001\00022_00011.ppm
# 1
# Images_Train\00001\00022_00012.ppm
# 1
# Images_Train\00001\00022_00013.ppm
# 1
# Images_Train\00001\00022_00014.ppm
# 1
# Images_Train\00001\00022_00015.ppm
# 1
# Images_Train\00001\00022_00016.ppm
# 1
# Images_Train\00001\00022_00017.ppm
# 1
# Images_Train\00001\00022_00018.ppm
# 1
# Images_Train\00001\00022_00019.ppm
# 1
# Images_Train\00001\00022_00020.ppm
# 1
# Images_Train\00001\00022_00021.ppm
# 1
# Images_Train\00001\00022_00022.ppm
# 1
# Images_Train\00001\00022_00023.ppm
# 1
# Images_Train\00001\00022_00024.ppm
# 1
# Images_Train\00001\00022_00025.ppm
# 1
# Images_Train\00001\00022_00026.ppm
# 1
# Images_Train\00001\00022_00027.ppm
# 1
# Images_Train\00001\00022_00028.ppm
# 1
# Images_Train\00001\00022_00029.ppm
# 1
# Images_Train\00001\00023_00000.ppm
# 1
# Images_Train\00001\00023_00001.ppm
# 1
# Images_Train\00001\00023_00002.ppm
# 1
# Images_Train\00001\00023_00003.ppm
# 1
# Images_Train\00001\00023_00004.ppm
# 1
# Images_Train\00001\00023_00005.ppm
# 1
# Images_Train\00001\00023_00006.ppm
# 1
# Images_Train\00001\00023_00007.ppm
# 1
# Images_Train\00001\00023_00008.ppm
# 1
# Images_Train\00001\00023_00009.ppm
# 1
# Images_Train\00001\00023_00010.ppm
# 1
# Images_Train\00001\00023_00011.ppm
# 1
# Images_Train\00001\00023_00012.ppm
# 1
# Images_Train\00001\00023_00013.ppm
# 1
# Images_Train\00001\00023_00014.ppm
# 1
# Images_Train\00001\00023_00015.ppm
# 1
# Images_Train\00001\00023_00016.ppm
# 1
# Images_Train\00001\00023_00017.ppm
# 1
# Images_Train\00001\00023_00018.ppm
# 1
# Images_Train\00001\00023_00019.ppm
# 1
# Images_Train\00001\00023_00020.ppm
# 1
# Images_Train\00001\00023_00021.ppm
# 1
# Images_Train\00001\00023_00022.ppm
# 1
# Images_Train\00001\00023_00023.ppm
# 1
# Images_Train\00001\00023_00024.ppm
# 1
# Images_Train\00001\00023_00025.ppm
# 1
# Images_Train\00001\00023_00026.ppm
# 1
# Images_Train\00001\00023_00027.ppm
# 1
# Images_Train\00001\00023_00028.ppm
# 1
# Images_Train\00001\00023_00029.ppm
# 1
# Images_Train\00001\00024_00000.ppm
# 1
# Images_Train\00001\00024_00001.ppm
# 1
# Images_Train\00001\00024_00002.ppm
# 1
# Images_Train\00001\00024_00003.ppm
# 1
# Images_Train\00001\00024_00004.ppm
# 1
# Images_Train\00001\00024_00005.ppm
# 1
# Images_Train\00001\00024_00006.ppm
# 1
# Images_Train\00001\00024_00007.ppm
# 1
# Images_Train\00001\00024_00008.ppm
# 1
# Images_Train\00001\00024_00009.ppm
# 1
# Images_Train\00001\00024_00010.ppm
# 1
# Images_Train\00001\00024_00011.ppm
# 1
# Images_Train\00001\00024_00012.ppm
# 1
# Images_Train\00001\00024_00013.ppm
# 1
# Images_Train\00001\00024_00014.ppm
# 1
# Images_Train\00001\00024_00015.ppm
# 1
# Images_Train\00001\00024_00016.ppm
# 1
# Images_Train\00001\00024_00017.ppm
# 1
# Images_Train\00001\00024_00018.ppm
# 1
# Images_Train\00001\00024_00019.ppm
# 1
# Images_Train\00001\00024_00020.ppm
# 1
# Images_Train\00001\00024_00021.ppm
# 1
# Images_Train\00001\00024_00022.ppm
# 1
# Images_Train\00001\00024_00023.ppm
# 1
# Images_Train\00001\00024_00024.ppm
# 1
# Images_Train\00001\00024_00025.ppm
# 1
# Images_Train\00001\00024_00026.ppm
# 1
# Images_Train\00001\00024_00027.ppm
# 1
# Images_Train\00001\00024_00028.ppm
# 1
# Images_Train\00001\00024_00029.ppm
# 1
# Images_Train\00001\00025_00000.ppm
# 1
# Images_Train\00001\00025_00001.ppm
# 1
# Images_Train\00001\00025_00002.ppm
# 1
# Images_Train\00001\00025_00003.ppm
# 1
# Images_Train\00001\00025_00004.ppm
# 1
# Images_Train\00001\00025_00005.ppm
# 1
# Images_Train\00001\00025_00006.ppm
# 1
# Images_Train\00001\00025_00007.ppm
# 1
# Images_Train\00001\00025_00008.ppm
# 1
# Images_Train\00001\00025_00009.ppm
# 1
# Images_Train\00001\00025_00010.ppm
# 1
# Images_Train\00001\00025_00011.ppm
# 1
# Images_Train\00001\00025_00012.ppm
# 1
# Images_Train\00001\00025_00013.ppm
# 1
# Images_Train\00001\00025_00014.ppm
# 1
# Images_Train\00001\00025_00015.ppm
# 1
# Images_Train\00001\00025_00016.ppm
# 1
# Images_Train\00001\00025_00017.ppm
# 1
# Images_Train\00001\00025_00018.ppm
# 1
# Images_Train\00001\00025_00019.ppm
# 1
# Images_Train\00001\00025_00020.ppm
# 1
# Images_Train\00001\00025_00021.ppm
# 1
# Images_Train\00001\00025_00022.ppm
# 1
# Images_Train\00001\00025_00023.ppm
# 1
# Images_Train\00001\00025_00024.ppm
# 1
# Images_Train\00001\00025_00025.ppm
# 1
# Images_Train\00001\00025_00026.ppm
# 1
# Images_Train\00001\00025_00027.ppm
# 1
# Images_Train\00001\00025_00028.ppm
# 1
# Images_Train\00001\00025_00029.ppm
# 1
# Images_Train\00001\00026_00000.ppm
# 1
# Images_Train\00001\00026_00001.ppm
# 1
# Images_Train\00001\00026_00002.ppm
# 1
# Images_Train\00001\00026_00003.ppm
# 1
# Images_Train\00001\00026_00004.ppm
# 1
# Images_Train\00001\00026_00005.ppm
# 1
# Images_Train\00001\00026_00006.ppm
# 1
# Images_Train\00001\00026_00007.ppm
# 1
# Images_Train\00001\00026_00008.ppm
# 1
# Images_Train\00001\00026_00009.ppm
# 1
# Images_Train\00001\00026_00010.ppm
# 1
# Images_Train\00001\00026_00011.ppm
# 1
# Images_Train\00001\00026_00012.ppm
# 1
# Images_Train\00001\00026_00013.ppm
# 1
# Images_Train\00001\00026_00014.ppm
# 1
# Images_Train\00001\00026_00015.ppm
# 1
# Images_Train\00001\00026_00016.ppm
# 1
# Images_Train\00001\00026_00017.ppm
# 1
# Images_Train\00001\00026_00018.ppm
# 1
# Images_Train\00001\00026_00019.ppm
# 1
# Images_Train\00001\00026_00020.ppm
# 1
# Images_Train\00001\00026_00021.ppm
# 1
# Images_Train\00001\00026_00022.ppm
# 1
# Images_Train\00001\00026_00023.ppm
# 1
# Images_Train\00001\00026_00024.ppm
# 1
# Images_Train\00001\00026_00025.ppm
# 1
# Images_Train\00001\00026_00026.ppm
# 1
# Images_Train\00001\00026_00027.ppm
# 1
# Images_Train\00001\00026_00028.ppm
# 1
# Images_Train\00001\00026_00029.ppm
# 1
# Images_Train\00001\00027_00000.ppm
# 1
# Images_Train\00001\00027_00001.ppm
# 1
# Images_Train\00001\00027_00002.ppm
# 1
# Images_Train\00001\00027_00003.ppm
# 1
# Images_Train\00001\00027_00004.ppm
# 1
# Images_Train\00001\00027_00005.ppm
# 1
# Images_Train\00001\00027_00006.ppm
# 1
# Images_Train\00001\00027_00007.ppm
# 1
# Images_Train\00001\00027_00008.ppm
# 1
# Images_Train\00001\00027_00009.ppm
# 1
# Images_Train\00001\00027_00010.ppm
# 1
# Images_Train\00001\00027_00011.ppm
# 1
# Images_Train\00001\00027_00012.ppm
# 1
# Images_Train\00001\00027_00013.ppm
# 1
# Images_Train\00001\00027_00014.ppm
# 1
# Images_Train\00001\00027_00015.ppm
# 1
# Images_Train\00001\00027_00016.ppm
# 1
# Images_Train\00001\00027_00017.ppm
# 1
# Images_Train\00001\00027_00018.ppm
# 1
# Images_Train\00001\00027_00019.ppm
# 1
# Images_Train\00001\00027_00020.ppm
# 1
# Images_Train\00001\00027_00021.ppm
# 1
# Images_Train\00001\00027_00022.ppm
# 1
# Images_Train\00001\00027_00023.ppm
# 1
# Images_Train\00001\00027_00024.ppm
# 1
# Images_Train\00001\00027_00025.ppm
# 1
# Images_Train\00001\00027_00026.ppm
# 1
# Images_Train\00001\00027_00027.ppm
# 1
# Images_Train\00001\00027_00028.ppm
# 1
# Images_Train\00001\00027_00029.ppm
# 1
# Images_Train\00001\00028_00000.ppm
# 1
# Images_Train\00001\00028_00001.ppm
# 1
# Images_Train\00001\00028_00002.ppm
# 1
# Images_Train\00001\00028_00003.ppm
# 1
# Images_Train\00001\00028_00004.ppm
# 1
# Images_Train\00001\00028_00005.ppm
# 1
# Images_Train\00001\00028_00006.ppm
# 1
# Images_Train\00001\00028_00007.ppm
# 1
# Images_Train\00001\00028_00008.ppm
# 1
# Images_Train\00001\00028_00009.ppm
# 1
# Images_Train\00001\00028_00010.ppm
# 1
# Images_Train\00001\00028_00011.ppm
# 1
# Images_Train\00001\00028_00012.ppm
# 1
# Images_Train\00001\00028_00013.ppm
# 1
# Images_Train\00001\00028_00014.ppm
# 1
# Images_Train\00001\00028_00015.ppm
# 1
# Images_Train\00001\00028_00016.ppm
# 1
# Images_Train\00001\00028_00017.ppm
# 1
# Images_Train\00001\00028_00018.ppm
# 1
# Images_Train\00001\00028_00019.ppm
# 1
# Images_Train\00001\00028_00020.ppm
# 1
# Images_Train\00001\00028_00021.ppm
# 1
# Images_Train\00001\00028_00022.ppm
# 1
# Images_Train\00001\00028_00023.ppm
# 1
# Images_Train\00001\00028_00024.ppm
# 1
# Images_Train\00001\00028_00025.ppm
# 1
# Images_Train\00001\00028_00026.ppm
# 1
# Images_Train\00001\00028_00027.ppm
# 1
# Images_Train\00001\00028_00028.ppm
# 1
# Images_Train\00001\00028_00029.ppm
# 1
# Images_Train\00001\00029_00000.ppm
# 1
# Images_Train\00001\00029_00001.ppm
# 1
# Images_Train\00001\00029_00002.ppm
# 1
# Images_Train\00001\00029_00003.ppm
# 1
# Images_Train\00001\00029_00004.ppm
# 1
# Images_Train\00001\00029_00005.ppm
# 1
# Images_Train\00001\00029_00006.ppm
# 1
# Images_Train\00001\00029_00007.ppm
# 1
# Images_Train\00001\00029_00008.ppm
# 1
# Images_Train\00001\00029_00009.ppm
# 1
# Images_Train\00001\00029_00010.ppm
# 1
# Images_Train\00001\00029_00011.ppm
# 1
# Images_Train\00001\00029_00012.ppm
# 1
# Images_Train\00001\00029_00013.ppm
# 1
# Images_Train\00001\00029_00014.ppm
# 1
# Images_Train\00001\00029_00015.ppm
# 1
# Images_Train\00001\00029_00016.ppm
# 1
# Images_Train\00001\00029_00017.ppm
# 1
# Images_Train\00001\00029_00018.ppm
# 1
# Images_Train\00001\00029_00019.ppm
# 1
# Images_Train\00001\00029_00020.ppm
# 1
# Images_Train\00001\00029_00021.ppm
# 1
# Images_Train\00001\00029_00022.ppm
# 1
# Images_Train\00001\00029_00023.ppm
# 1
# Images_Train\00001\00029_00024.ppm
# 1
# Images_Train\00001\00029_00025.ppm
# 1
# Images_Train\00001\00029_00026.ppm
# 1
# Images_Train\00001\00029_00027.ppm
# 1
# Images_Train\00001\00029_00028.ppm
# 1
# Images_Train\00001\00029_00029.ppm
# 1
# Images_Train\00001\00030_00000.ppm
# 1
# Images_Train\00001\00030_00001.ppm
# 1
# Images_Train\00001\00030_00002.ppm
# 1
# Images_Train\00001\00030_00003.ppm
# 1
# Images_Train\00001\00030_00004.ppm
# 1
# Images_Train\00001\00030_00005.ppm
# 1
# Images_Train\00001\00030_00006.ppm
# 1
# Images_Train\00001\00030_00007.ppm
# 1
# Images_Train\00001\00030_00008.ppm
# 1
# Images_Train\00001\00030_00009.ppm
# 1
# Images_Train\00001\00030_00010.ppm
# 1
# Images_Train\00001\00030_00011.ppm
# 1
# Images_Train\00001\00030_00012.ppm
# 1
# Images_Train\00001\00030_00013.ppm
# 1
# Images_Train\00001\00030_00014.ppm
# 1
# Images_Train\00001\00030_00015.ppm
# 1
# Images_Train\00001\00030_00016.ppm
# 1
# Images_Train\00001\00030_00017.ppm
# 1
# Images_Train\00001\00030_00018.ppm
# 1
# Images_Train\00001\00030_00019.ppm
# 1
# Images_Train\00001\00030_00020.ppm
# 1
# Images_Train\00001\00030_00021.ppm
# 1
# Images_Train\00001\00030_00022.ppm
# 1
# Images_Train\00001\00030_00023.ppm
# 1
# Images_Train\00001\00030_00024.ppm
# 1
# Images_Train\00001\00030_00025.ppm
# 1
# Images_Train\00001\00030_00026.ppm
# 1
# Images_Train\00001\00030_00027.ppm
# 1
# Images_Train\00001\00030_00028.ppm
# 1
# Images_Train\00001\00030_00029.ppm
# 1
# Images_Train\00001\00031_00000.ppm
# 1
# Images_Train\00001\00031_00001.ppm
# 1
# Images_Train\00001\00031_00002.ppm
# 1
# Images_Train\00001\00031_00003.ppm
# 1
# Images_Train\00001\00031_00004.ppm
# 1
# Images_Train\00001\00031_00005.ppm
# 1
# Images_Train\00001\00031_00006.ppm
# 1
# Images_Train\00001\00031_00007.ppm
# 1
# Images_Train\00001\00031_00008.ppm
# 1
# Images_Train\00001\00031_00009.ppm
# 1
# Images_Train\00001\00031_00010.ppm
# 1
# Images_Train\00001\00031_00011.ppm
# 1
# Images_Train\00001\00031_00012.ppm
# 1
# Images_Train\00001\00031_00013.ppm
# 1
# Images_Train\00001\00031_00014.ppm
# 1
# Images_Train\00001\00031_00015.ppm
# 1
# Images_Train\00001\00031_00016.ppm
# 1
# Images_Train\00001\00031_00017.ppm
# 1
# Images_Train\00001\00031_00018.ppm
# 1
# Images_Train\00001\00031_00019.ppm
# 1
# Images_Train\00001\00031_00020.ppm
# 1
# Images_Train\00001\00031_00021.ppm
# 1
# Images_Train\00001\00031_00022.ppm
# 1
# Images_Train\00001\00031_00023.ppm
# 1
# Images_Train\00001\00031_00024.ppm
# 1
# Images_Train\00001\00031_00025.ppm
# 1
# Images_Train\00001\00031_00026.ppm
# 1
# Images_Train\00001\00031_00027.ppm
# 1
# Images_Train\00001\00031_00028.ppm
# 1
# Images_Train\00001\00031_00029.ppm
# 1
# Images_Train\00001\00032_00000.ppm
# 1
# Images_Train\00001\00032_00001.ppm
# 1
# Images_Train\00001\00032_00002.ppm
# 1
# Images_Train\00001\00032_00003.ppm
# 1
# Images_Train\00001\00032_00004.ppm
# 1
# Images_Train\00001\00032_00005.ppm
# 1
# Images_Train\00001\00032_00006.ppm
# 1
# Images_Train\00001\00032_00007.ppm
# 1
# Images_Train\00001\00032_00008.ppm
# 1
# Images_Train\00001\00032_00009.ppm
# 1
# Images_Train\00001\00032_00010.ppm
# 1
# Images_Train\00001\00032_00011.ppm
# 1
# Images_Train\00001\00032_00012.ppm
# 1
# Images_Train\00001\00032_00013.ppm
# 1
# Images_Train\00001\00032_00014.ppm
# 1
# Images_Train\00001\00032_00015.ppm
# 1
# Images_Train\00001\00032_00016.ppm
# 1
# Images_Train\00001\00032_00017.ppm
# 1
# Images_Train\00001\00032_00018.ppm
# 1
# Images_Train\00001\00032_00019.ppm
# 1
# Images_Train\00001\00032_00020.ppm
# 1
# Images_Train\00001\00032_00021.ppm
# 1
# Images_Train\00001\00032_00022.ppm
# 1
# Images_Train\00001\00032_00023.ppm
# 1
# Images_Train\00001\00032_00024.ppm
# 1
# Images_Train\00001\00032_00025.ppm
# 1
# Images_Train\00001\00032_00026.ppm
# 1
# Images_Train\00001\00032_00027.ppm
# 1
# Images_Train\00001\00032_00028.ppm
# 1
# Images_Train\00001\00032_00029.ppm
# 1
# Images_Train\00001\00033_00000.ppm
# 1
# Images_Train\00001\00033_00001.ppm
# 1
# Images_Train\00001\00033_00002.ppm
# 1
# Images_Train\00001\00033_00003.ppm
# 1
# Images_Train\00001\00033_00004.ppm
# 1
# Images_Train\00001\00033_00005.ppm
# 1
# Images_Train\00001\00033_00006.ppm
# 1
# Images_Train\00001\00033_00007.ppm
# 1
# Images_Train\00001\00033_00008.ppm
# 1
# Images_Train\00001\00033_00009.ppm
# 1
# Images_Train\00001\00033_00010.ppm
# 1
# Images_Train\00001\00033_00011.ppm
# 1
# Images_Train\00001\00033_00012.ppm
# 1
# Images_Train\00001\00033_00013.ppm
# 1
# Images_Train\00001\00033_00014.ppm
# 1
# Images_Train\00001\00033_00015.ppm
# 1
# Images_Train\00001\00033_00016.ppm
# 1
# Images_Train\00001\00033_00017.ppm
# 1
# Images_Train\00001\00033_00018.ppm
# 1
# Images_Train\00001\00033_00019.ppm
# 1
# Images_Train\00001\00033_00020.ppm
# 1
# Images_Train\00001\00033_00021.ppm
# 1
# Images_Train\00001\00033_00022.ppm
# 1
# Images_Train\00001\00033_00023.ppm
# 1
# Images_Train\00001\00033_00024.ppm
# 1
# Images_Train\00001\00033_00025.ppm
# 1
# Images_Train\00001\00033_00026.ppm
# 1
# Images_Train\00001\00033_00027.ppm
# 1
# Images_Train\00001\00033_00028.ppm
# 1
# Images_Train\00001\00033_00029.ppm
# 1
# Images_Train\00001\00034_00000.ppm
# 1
# Images_Train\00001\00034_00001.ppm
# 1
# Images_Train\00001\00034_00002.ppm
# 1
# Images_Train\00001\00034_00003.ppm
# 1
# Images_Train\00001\00034_00004.ppm
# 1
# Images_Train\00001\00034_00005.ppm
# 1
# Images_Train\00001\00034_00006.ppm
# 1
# Images_Train\00001\00034_00007.ppm
# 1
# Images_Train\00001\00034_00008.ppm
# 1
# Images_Train\00001\00034_00009.ppm
# 1
# Images_Train\00001\00034_00010.ppm
# 1
# Images_Train\00001\00034_00011.ppm
# 1
# Images_Train\00001\00034_00012.ppm
# 1
# Images_Train\00001\00034_00013.ppm
# 1
# Images_Train\00001\00034_00014.ppm
# 1
# Images_Train\00001\00034_00015.ppm
# 1
# Images_Train\00001\00034_00016.ppm
# 1
# Images_Train\00001\00034_00017.ppm
# 1
# Images_Train\00001\00034_00018.ppm
# 1
# Images_Train\00001\00034_00019.ppm
# 1
# Images_Train\00001\00034_00020.ppm
# 1
# Images_Train\00001\00034_00021.ppm
# 1
# Images_Train\00001\00034_00022.ppm
# 1
# Images_Train\00001\00034_00023.ppm
# 1
# Images_Train\00001\00034_00024.ppm
# 1
# Images_Train\00001\00034_00025.ppm
# 1
# Images_Train\00001\00034_00026.ppm
# 1
# Images_Train\00001\00034_00027.ppm
# 1
# Images_Train\00001\00034_00028.ppm
# 1
# Images_Train\00001\00034_00029.ppm
# 1
# Images_Train\00001\00035_00000.ppm
# 1
# Images_Train\00001\00035_00001.ppm
# 1
# Images_Train\00001\00035_00002.ppm
# 1
# Images_Train\00001\00035_00003.ppm
# 1
# Images_Train\00001\00035_00004.ppm
# 1
# Images_Train\00001\00035_00005.ppm
# 1
# Images_Train\00001\00035_00006.ppm
# 1
# Images_Train\00001\00035_00007.ppm
# 1
# Images_Train\00001\00035_00008.ppm
# 1
# Images_Train\00001\00035_00009.ppm
# 1
# Images_Train\00001\00035_00010.ppm
# 1
# Images_Train\00001\00035_00011.ppm
# 1
# Images_Train\00001\00035_00012.ppm
# 1
# Images_Train\00001\00035_00013.ppm
# 1
# Images_Train\00001\00035_00014.ppm
# 1
# Images_Train\00001\00035_00015.ppm
# 1
# Images_Train\00001\00035_00016.ppm
# 1
# Images_Train\00001\00035_00017.ppm
# 1
# Images_Train\00001\00035_00018.ppm
# 1
# Images_Train\00001\00035_00019.ppm
# 1
# Images_Train\00001\00035_00020.ppm
# 1
# Images_Train\00001\00035_00021.ppm
# 1
# Images_Train\00001\00035_00022.ppm
# 1
# Images_Train\00001\00035_00023.ppm
# 1
# Images_Train\00001\00035_00024.ppm
# 1
# Images_Train\00001\00035_00025.ppm
# 1
# Images_Train\00001\00035_00026.ppm
# 1
# Images_Train\00001\00035_00027.ppm
# 1
# Images_Train\00001\00035_00028.ppm
# 1
# Images_Train\00001\00035_00029.ppm
# 1
# Images_Train\00001\00036_00000.ppm
# 1
# Images_Train\00001\00036_00001.ppm
# 1
# Images_Train\00001\00036_00002.ppm
# 1
# Images_Train\00001\00036_00003.ppm
# 1
# Images_Train\00001\00036_00004.ppm
# 1
# ...
# 41
# Images_Train\00041\00002_00000.ppm
# 41
# Images_Train\00041\00002_00001.ppm
# 41
# Images_Train\00041\00002_00002.ppm
# 41
# Images_Train\00041\00002_00003.ppm
# 41
# Images_Train\00041\00002_00004.ppm
# 41
# Images_Train\00041\00002_00005.ppm
# 41
# Images_Train\00041\00002_00006.ppm
# 41
# Images_Train\00041\00002_00007.ppm
# 41
# Images_Train\00041\00002_00008.ppm
# 41
# Images_Train\00041\00002_00009.ppm
# 41
# Images_Train\00041\00002_00010.ppm
# 41
# Images_Train\00041\00002_00011.ppm
# 41
# Images_Train\00041\00002_00012.ppm
# 41
# Images_Train\00041\00002_00013.ppm
# 41
# Images_Train\00041\00002_00014.ppm
# 41
# Images_Train\00041\00002_00015.ppm
# 41
# Images_Train\00041\00002_00016.ppm
# 41
# Images_Train\00041\00002_00017.ppm
# 41
# Images_Train\00041\00002_00018.ppm
# 41
# Images_Train\00041\00002_00019.ppm
# 41
# Images_Train\00041\00002_00020.ppm
# 41
# Images_Train\00041\00002_00021.ppm
# 41
# Images_Train\00041\00002_00022.ppm
# 41
# Images_Train\00041\00002_00023.ppm
# 41
# Images_Train\00041\00002_00024.ppm
# 41
# Images_Train\00041\00002_00025.ppm
# 41
# Images_Train\00041\00002_00026.ppm
# 41
# Images_Train\00041\00002_00027.ppm
# 41
# Images_Train\00041\00002_00028.ppm
# 41
# Images_Train\00041\00002_00029.ppm
# 41
# Images_Train\00041\00003_00000.ppm
# 41
# Images_Train\00041\00003_00001.ppm
# 41
# Images_Train\00041\00003_00002.ppm
# 41
# Images_Train\00041\00003_00003.ppm
# 41
# Images_Train\00041\00003_00004.ppm
# 41
# Images_Train\00041\00003_00005.ppm
# 41
# Images_Train\00041\00003_00006.ppm
# 41
# Images_Train\00041\00003_00007.ppm
# 41
# Images_Train\00041\00003_00008.ppm
# 41
# Images_Train\00041\00003_00009.ppm
# 41
# Images_Train\00041\00003_00010.ppm
# 41
# Images_Train\00041\00003_00011.ppm
# 41
# Images_Train\00041\00003_00012.ppm
# 41
# Images_Train\00041\00003_00013.ppm
# 41
# Images_Train\00041\00003_00014.ppm
# 41
# Images_Train\00041\00003_00015.ppm
# 41
# Images_Train\00041\00003_00016.ppm
# 41
# Images_Train\00041\00003_00017.ppm
# 41
# Images_Train\00041\00003_00018.ppm
# 41
# Images_Train\00041\00003_00019.ppm
# 41
# Images_Train\00041\00003_00020.ppm
# 41
# Images_Train\00041\00003_00021.ppm
# 41
# Images_Train\00041\00003_00022.ppm
# 41
# Images_Train\00041\00003_00023.ppm
# 41
# Images_Train\00041\00003_00024.ppm
# 41
# Images_Train\00041\00003_00025.ppm
# 41
# Images_Train\00041\00003_00026.ppm
# 41
# Images_Train\00041\00003_00027.ppm
# 41
# Images_Train\00041\00003_00028.ppm
# 41
# Images_Train\00041\00003_00029.ppm
# 41
# Images_Train\00041\00004_00000.ppm
# 41
# Images_Train\00041\00004_00001.ppm
# 41
# Images_Train\00041\00004_00002.ppm
# 41
# Images_Train\00041\00004_00003.ppm
# 41
# Images_Train\00041\00004_00004.ppm
# 41
# Images_Train\00041\00004_00005.ppm
# 41
# Images_Train\00041\00004_00006.ppm
# 41
# Images_Train\00041\00004_00007.ppm
# 41
# Images_Train\00041\00004_00008.ppm
# 41
# Images_Train\00041\00004_00009.ppm
# 41
# Images_Train\00041\00004_00010.ppm
# 41
# Images_Train\00041\00004_00011.ppm
# 41
# Images_Train\00041\00004_00012.ppm
# 41
# Images_Train\00041\00004_00013.ppm
# 41
# Images_Train\00041\00004_00014.ppm
# 41
# Images_Train\00041\00004_00015.ppm
# 41
# Images_Train\00041\00004_00016.ppm
# 41
# Images_Train\00041\00004_00017.ppm
# 41
# Images_Train\00041\00004_00018.ppm
# 41
# Images_Train\00041\00004_00019.ppm
# 41
# Images_Train\00041\00004_00020.ppm
# 41
# Images_Train\00041\00004_00021.ppm
# 41
# Images_Train\00041\00004_00022.ppm
# 41
# Images_Train\00041\00004_00023.ppm
# 41
# Images_Train\00041\00004_00024.ppm
# 41
# Images_Train\00041\00004_00025.ppm
# 41
# Images_Train\00041\00004_00026.ppm
# 41
# Images_Train\00041\00004_00027.ppm
# 41
# Images_Train\00041\00004_00028.ppm
# 41
# Images_Train\00041\00004_00029.ppm
# 41
# Images_Train\00041\00005_00000.ppm
# 41
# Images_Train\00041\00005_00001.ppm
# 41
# Images_Train\00041\00005_00002.ppm
# 41
# Images_Train\00041\00005_00003.ppm
# 41
# Images_Train\00041\00005_00004.ppm
# 41
# Images_Train\00041\00005_00005.ppm
# 41
# Images_Train\00041\00005_00006.ppm
# 41
# Images_Train\00041\00005_00007.ppm
# 41
# Images_Train\00041\00005_00008.ppm
# 41
# Images_Train\00041\00005_00009.ppm
# 41
# Images_Train\00041\00005_00010.ppm
# 41
# Images_Train\00041\00005_00011.ppm
# 41
# Images_Train\00041\00005_00012.ppm
# 41
# Images_Train\00041\00005_00013.ppm
# 41
# Images_Train\00041\00005_00014.ppm
# 41
# Images_Train\00041\00005_00015.ppm
# 41
# Images_Train\00041\00005_00016.ppm
# 41
# Images_Train\00041\00005_00017.ppm
# 41
# Images_Train\00041\00005_00018.ppm
# 41
# Images_Train\00041\00005_00019.ppm
# 41
# Images_Train\00041\00005_00020.ppm
# 41
# Images_Train\00041\00005_00021.ppm
# 41
# Images_Train\00041\00005_00022.ppm
# 41
# Images_Train\00041\00005_00023.ppm
# 41
# Images_Train\00041\00005_00024.ppm
# 41
# Images_Train\00041\00005_00025.ppm
# 41
# Images_Train\00041\00005_00026.ppm
# 41
# Images_Train\00041\00005_00027.ppm
# 41
# Images_Train\00041\00005_00028.ppm
# 41
# Images_Train\00041\00005_00029.ppm
# 41
# Images_Train\00041\00006_00000.ppm
# 41
# Images_Train\00041\00006_00001.ppm
# 41
# Images_Train\00041\00006_00002.ppm
# 41
# Images_Train\00041\00006_00003.ppm
# 41
# Images_Train\00041\00006_00004.ppm
# 41
# Images_Train\00041\00006_00005.ppm
# 41
# Images_Train\00041\00006_00006.ppm
# 41
# Images_Train\00041\00006_00007.ppm
# 41
# Images_Train\00041\00006_00008.ppm
# 41
# Images_Train\00041\00006_00009.ppm
# 41
# Images_Train\00041\00006_00010.ppm
# 41
# Images_Train\00041\00006_00011.ppm
# 41
# Images_Train\00041\00006_00012.ppm
# 41
# Images_Train\00041\00006_00013.ppm
# 41
# Images_Train\00041\00006_00014.ppm
# 41
# Images_Train\00041\00006_00015.ppm
# 41
# Images_Train\00041\00006_00016.ppm
# 41
# Images_Train\00041\00006_00017.ppm
# 41
# Images_Train\00041\00006_00018.ppm
# 41
# Images_Train\00041\00006_00019.ppm
# 41
# Images_Train\00041\00006_00020.ppm
# 41
# Images_Train\00041\00006_00021.ppm
# 41
# Images_Train\00041\00006_00022.ppm
# 41
# Images_Train\00041\00006_00023.ppm
# 41
# Images_Train\00041\00006_00024.ppm
# 41
# Images_Train\00041\00006_00025.ppm
# 41
# Images_Train\00041\00006_00026.ppm
# 41
# Images_Train\00041\00006_00027.ppm
# 41
# Images_Train\00041\00006_00028.ppm
# 41
# Images_Train\00041\00006_00029.ppm
# 41
# Images_Train\00041\00007_00000.ppm
# 41
# Images_Train\00041\00007_00001.ppm
# 41
# Images_Train\00041\00007_00002.ppm
# 41
# Images_Train\00041\00007_00003.ppm
# 41
# Images_Train\00041\00007_00004.ppm
# 41
# Images_Train\00041\00007_00005.ppm
# 41
# Images_Train\00041\00007_00006.ppm
# 41
# Images_Train\00041\00007_00007.ppm
# 41
# Images_Train\00041\00007_00008.ppm
# 41
# Images_Train\00041\00007_00009.ppm
# 41
# Images_Train\00041\00007_00010.ppm
# 41
# Images_Train\00041\00007_00011.ppm
# 41
# Images_Train\00041\00007_00012.ppm
# 41
# Images_Train\00041\00007_00013.ppm
# 41
# Images_Train\00041\00007_00014.ppm
# 41
# Images_Train\00041\00007_00015.ppm
# 41
# Images_Train\00041\00007_00016.ppm
# 41
# Images_Train\00041\00007_00017.ppm
# 41
# Images_Train\00041\00007_00018.ppm
# 41
# Images_Train\00041\00007_00019.ppm
# 41
# Images_Train\00041\00007_00020.ppm
# 41
# Images_Train\00041\00007_00021.ppm
# 41
# Images_Train\00041\00007_00022.ppm
# 41
# Images_Train\00041\00007_00023.ppm
# 41
# Images_Train\00041\00007_00024.ppm
# 41
# Images_Train\00041\00007_00025.ppm
# 41
# Images_Train\00041\00007_00026.ppm
# 41
# Images_Train\00041\00007_00027.ppm
# 41
# Images_Train\00041\00007_00028.ppm
# 41
# Images_Train\00041\00007_00029.ppm
# 41
# Images_Train\00042
# Images_Train\00042\00000_00000.ppm
# 42
# Images_Train\00042\00000_00001.ppm
# 42
# Images_Train\00042\00000_00002.ppm
# 42
# Images_Train\00042\00000_00003.ppm
# 42
# Images_Train\00042\00000_00004.ppm
# 42
# Images_Train\00042\00000_00005.ppm
# 42
# Images_Train\00042\00000_00006.ppm
# 42
# Images_Train\00042\00000_00007.ppm
# 42
# Images_Train\00042\00000_00008.ppm
# 42
# Images_Train\00042\00000_00009.ppm
# 42
# Images_Train\00042\00000_00010.ppm
# 42
# Images_Train\00042\00000_00011.ppm
# 42
# Images_Train\00042\00000_00012.ppm
# 42
# Images_Train\00042\00000_00013.ppm
# 42
# Images_Train\00042\00000_00014.ppm
# 42
# Images_Train\00042\00000_00015.ppm
# 42
# Images_Train\00042\00000_00016.ppm
# 42
# Images_Train\00042\00000_00017.ppm
# 42
# Images_Train\00042\00000_00018.ppm
# 42
# Images_Train\00042\00000_00019.ppm
# 42
# Images_Train\00042\00000_00020.ppm
# 42
# Images_Train\00042\00000_00021.ppm
# 42
# Images_Train\00042\00000_00022.ppm
# 42
# Images_Train\00042\00000_00023.ppm
# 42
# Images_Train\00042\00000_00024.ppm
# 42
# Images_Train\00042\00000_00025.ppm
# 42
# Images_Train\00042\00000_00026.ppm
# 42
# Images_Train\00042\00000_00027.ppm
# 42
# Images_Train\00042\00000_00028.ppm
# 42
# Images_Train\00042\00000_00029.ppm
# 42
# Images_Train\00042\00001_00000.ppm
# 42
# Images_Train\00042\00001_00001.ppm
# 42
# Images_Train\00042\00001_00002.ppm
# 42
# Images_Train\00042\00001_00003.ppm
# 42
# Images_Train\00042\00001_00004.ppm
# 42
# Images_Train\00042\00001_00005.ppm
# 42
# Images_Train\00042\00001_00006.ppm
# 42
# Images_Train\00042\00001_00007.ppm
# 42
# Images_Train\00042\00001_00008.ppm
# 42
# Images_Train\00042\00001_00009.ppm
# 42
# Images_Train\00042\00001_00010.ppm
# 42
# Images_Train\00042\00001_00011.ppm
# 42
# Images_Train\00042\00001_00012.ppm
# 42
# Images_Train\00042\00001_00013.ppm
# 42
# Images_Train\00042\00001_00014.ppm
# 42
# Images_Train\00042\00001_00015.ppm
# 42
# Images_Train\00042\00001_00016.ppm
# 42
# Images_Train\00042\00001_00017.ppm
# 42
# Images_Train\00042\00001_00018.ppm
# 42
# Images_Train\00042\00001_00019.ppm
# 42
# Images_Train\00042\00001_00020.ppm
# 42
# Images_Train\00042\00001_00021.ppm
# 42
# Images_Train\00042\00001_00022.ppm
# 42
# Images_Train\00042\00001_00023.ppm
# 42
# Images_Train\00042\00001_00024.ppm
# 42
# Images_Train\00042\00001_00025.ppm
# 42
# Images_Train\00042\00001_00026.ppm
# 42
# Images_Train\00042\00001_00027.ppm
# 42
# Images_Train\00042\00001_00028.ppm
# 42
# Images_Train\00042\00001_00029.ppm
# 42
# Images_Train\00042\00002_00000.ppm
# 42
# Images_Train\00042\00002_00001.ppm
# 42
# Images_Train\00042\00002_00002.ppm
# 42
# Images_Train\00042\00002_00003.ppm
# 42
# Images_Train\00042\00002_00004.ppm
# 42
# Images_Train\00042\00002_00005.ppm
# 42
# Images_Train\00042\00002_00006.ppm
# 42
# Images_Train\00042\00002_00007.ppm
# 42
# Images_Train\00042\00002_00008.ppm
# 42
# Images_Train\00042\00002_00009.ppm
# 42
# Images_Train\00042\00002_00010.ppm
# 42
# Images_Train\00042\00002_00011.ppm
# 42
# Images_Train\00042\00002_00012.ppm
# 42
# Images_Train\00042\00002_00013.ppm
# 42
# Images_Train\00042\00002_00014.ppm
# 42
# Images_Train\00042\00002_00015.ppm
# 42
# Images_Train\00042\00002_00016.ppm
# 42
# Images_Train\00042\00002_00017.ppm
# 42
# Images_Train\00042\00002_00018.ppm
# 42
# Images_Train\00042\00002_00019.ppm
# 42
# Images_Train\00042\00002_00020.ppm
# 42
# Images_Train\00042\00002_00021.ppm
# 42
# Images_Train\00042\00002_00022.ppm
# 42
# Images_Train\00042\00002_00023.ppm
# 42
# Images_Train\00042\00002_00024.ppm
# 42
# Images_Train\00042\00002_00025.ppm
# 42
# Images_Train\00042\00002_00026.ppm
# 42
# Images_Train\00042\00002_00027.ppm
# 42
# Images_Train\00042\00002_00028.ppm
# 42
# Images_Train\00042\00002_00029.ppm
# 42
# Images_Train\00042\00003_00000.ppm
# 42
# Images_Train\00042\00003_00001.ppm
# 42
# Images_Train\00042\00003_00002.ppm
# 42
# Images_Train\00042\00003_00003.ppm
# 42
# Images_Train\00042\00003_00004.ppm
# 42
# Images_Train\00042\00003_00005.ppm
# 42
# Images_Train\00042\00003_00006.ppm
# 42
# Images_Train\00042\00003_00007.ppm
# 42
# Images_Train\00042\00003_00008.ppm
# 42
# Images_Train\00042\00003_00009.ppm
# 42
# Images_Train\00042\00003_00010.ppm
# 42
# Images_Train\00042\00003_00011.ppm
# 42
# Images_Train\00042\00003_00012.ppm
# 42
# Images_Train\00042\00003_00013.ppm
# 42
# Images_Train\00042\00003_00014.ppm
# 42
# Images_Train\00042\00003_00015.ppm
# 42
# Images_Train\00042\00003_00016.ppm
# 42
# Images_Train\00042\00003_00017.ppm
# 42
# Images_Train\00042\00003_00018.ppm
# 42
# Images_Train\00042\00003_00019.ppm
# 42
# Images_Train\00042\00003_00020.ppm
# 42
# Images_Train\00042\00003_00021.ppm
# 42
# Images_Train\00042\00003_00022.ppm
# 42
# Images_Train\00042\00003_00023.ppm
# 42
# Images_Train\00042\00003_00024.ppm
# 42
# Images_Train\00042\00003_00025.ppm
# 42
# Images_Train\00042\00003_00026.ppm
# 42
# Images_Train\00042\00003_00027.ppm
# 42
# Images_Train\00042\00003_00028.ppm
# 42
# Images_Train\00042\00003_00029.ppm
# 42
# Images_Train\00042\00004_00000.ppm
# 42
# Images_Train\00042\00004_00001.ppm
# 42
# Images_Train\00042\00004_00002.ppm
# 42
# Images_Train\00042\00004_00003.ppm
# 42
# Images_Train\00042\00004_00004.ppm
# 42
# Images_Train\00042\00004_00005.ppm
# 42
# Images_Train\00042\00004_00006.ppm
# 42
# Images_Train\00042\00004_00007.ppm
# 42
# Images_Train\00042\00004_00008.ppm
# 42
# Images_Train\00042\00004_00009.ppm
# 42
# Images_Train\00042\00004_00010.ppm
# 42
# Images_Train\00042\00004_00011.ppm
# 42
# Images_Train\00042\00004_00012.ppm
# 42
# Images_Train\00042\00004_00013.ppm
# 42
# Images_Train\00042\00004_00014.ppm
# 42
# Images_Train\00042\00004_00015.ppm
# 42
# Images_Train\00042\00004_00016.ppm
# 42
# Images_Train\00042\00004_00017.ppm
# 42
# Images_Train\00042\00004_00018.ppm
# 42
# Images_Train\00042\00004_00019.ppm
# 42
# Images_Train\00042\00004_00020.ppm
# 42
# Images_Train\00042\00004_00021.ppm
# 42
# Images_Train\00042\00004_00022.ppm
# 42
# Images_Train\00042\00004_00023.ppm
# 42
# Images_Train\00042\00004_00024.ppm
# 42
# Images_Train\00042\00004_00025.ppm
# 42
# Images_Train\00042\00004_00026.ppm
# 42
# Images_Train\00042\00004_00027.ppm
# 42
# Images_Train\00042\00004_00028.ppm
# 42
# Images_Train\00042\00004_00029.ppm
# 42
# Images_Train\00042\00005_00000.ppm
# 42
# Images_Train\00042\00005_00001.ppm
# 42
# Images_Train\00042\00005_00002.ppm
# 42
# Images_Train\00042\00005_00003.ppm
# 42
# Images_Train\00042\00005_00004.ppm
# 42
# Images_Train\00042\00005_00005.ppm
# 42
# Images_Train\00042\00005_00006.ppm
# 42
# Images_Train\00042\00005_00007.ppm
# 42
# Images_Train\00042\00005_00008.ppm
# 42
# Images_Train\00042\00005_00009.ppm
# 42
# Images_Train\00042\00005_00010.ppm
# 42
# Images_Train\00042\00005_00011.ppm
# 42
# Images_Train\00042\00005_00012.ppm
# 42
# Images_Train\00042\00005_00013.ppm
# 42
# Images_Train\00042\00005_00014.ppm
# 42
# Images_Train\00042\00005_00015.ppm
# 42
# Images_Train\00042\00005_00016.ppm
# 42
# Images_Train\00042\00005_00017.ppm
# 42
# Images_Train\00042\00005_00018.ppm
# 42
# Images_Train\00042\00005_00019.ppm
# 42
# Images_Train\00042\00005_00020.ppm
# 42
# Images_Train\00042\00005_00021.ppm
# 42
# Images_Train\00042\00005_00022.ppm
# 42
# Images_Train\00042\00005_00023.ppm
# 42
# Images_Train\00042\00005_00024.ppm
# 42
# Images_Train\00042\00005_00025.ppm
# 42
# Images_Train\00042\00005_00026.ppm
# 42
# Images_Train\00042\00005_00027.ppm
# 42
# Images_Train\00042\00005_00028.ppm
# 42
# Images_Train\00042\00005_00029.ppm
# 42
# Images_Train\00042\00006_00000.ppm
# 42
# Images_Train\00042\00006_00001.ppm
# 42
# Images_Train\00042\00006_00002.ppm
# 42
# Images_Train\00042\00006_00003.ppm
# 42
# Images_Train\00042\00006_00004.ppm
# 42
# Images_Train\00042\00006_00005.ppm
# 42
# Images_Train\00042\00006_00006.ppm
# 42
# Images_Train\00042\00006_00007.ppm
# 42
# Images_Train\00042\00006_00008.ppm
# 42
# Images_Train\00042\00006_00009.ppm
# 42
# Images_Train\00042\00006_00010.ppm
# 42
# Images_Train\00042\00006_00011.ppm
# 42
# Images_Train\00042\00006_00012.ppm
# 42
# Images_Train\00042\00006_00013.ppm
# 42
# Images_Train\00042\00006_00014.ppm
# 42
# Images_Train\00042\00006_00015.ppm
# 42
# Images_Train\00042\00006_00016.ppm
# 42
# Images_Train\00042\00006_00017.ppm
# 42
# Images_Train\00042\00006_00018.ppm
# 42
# Images_Train\00042\00006_00019.ppm
# 42
# Images_Train\00042\00006_00020.ppm
# 42
# Images_Train\00042\00006_00021.ppm
# 42
# Images_Train\00042\00006_00022.ppm
# 42
# Images_Train\00042\00006_00023.ppm
# 42
# Images_Train\00042\00006_00024.ppm
# 42
# Images_Train\00042\00006_00025.ppm
# 42
# Images_Train\00042\00006_00026.ppm
# 42
# Images_Train\00042\00006_00027.ppm
# 42
# Images_Train\00042\00006_00028.ppm
# 42
# Images_Train\00042\00006_00029.ppm
# 42
# Images_Train\00042\00007_00000.ppm
# 42
# Images_Train\00042\00007_00001.ppm
# 42
# Images_Train\00042\00007_00002.ppm
# 42
# Images_Train\00042\00007_00003.ppm
# 42
# Images_Train\00042\00007_00004.ppm
# 42
# Images_Train\00042\00007_00005.ppm
# 42
# Images_Train\00042\00007_00006.ppm
# 42
# Images_Train\00042\00007_00007.ppm
# 42
# Images_Train\00042\00007_00008.ppm
# 42
# Images_Train\00042\00007_00009.ppm
# 42
# Images_Train\00042\00007_00010.ppm
# 42
# Images_Train\00042\00007_00011.ppm
# 42
# Images_Train\00042\00007_00012.ppm
# 42
# Images_Train\00042\00007_00013.ppm
# 42
# Images_Train\00042\00007_00014.ppm
# 42
# Images_Train\00042\00007_00015.ppm
# 42
# Images_Train\00042\00007_00016.ppm
# 42
# Images_Train\00042\00007_00017.ppm
# 42
# Images_Train\00042\00007_00018.ppm
# 42
# Images_Train\00042\00007_00019.ppm
# 42
# Images_Train\00042\00007_00020.ppm
# 42
# Images_Train\00042\00007_00021.ppm
# 42
# Images_Train\00042\00007_00022.ppm
# 42
# Images_Train\00042\00007_00023.ppm
# 42
# Images_Train\00042\00007_00024.ppm
# 42
# Images_Train\00042\00007_00025.ppm
# 42
# Images_Train\00042\00007_00026.ppm
# 42
# Images_Train\00042\00007_00027.ppm
# 42
# Images_Train\00042\00007_00028.ppm
# 42
# Images_Train\00042\00007_00029.ppm
# 42

# %% [markdown]
# ## Load Test Data

# %%
#Read the test images
X_test_list, y_test_list = read_data_test(Test_dir,directories_test)
# Out:
# Images_Test
# Images_Test\00000.ppm
# 0
# Images_Test\00001.ppm
# 1
# Images_Test\00002.ppm
# 2
# Images_Test\00003.ppm
# 3
# Images_Test\00004.ppm
# 4
# Images_Test\00005.ppm
# 5
# Images_Test\00006.ppm
# 6
# Images_Test\00007.ppm
# 7
# Images_Test\00008.ppm
# 8
# Images_Test\00009.ppm
# 9
# Images_Test\00010.ppm
# 10
# Images_Test\00011.ppm
# 11
# Images_Test\00012.ppm
# 12
# Images_Test\00013.ppm
# 13
# Images_Test\00014.ppm
# 14
# Images_Test\00015.ppm
# 15
# Images_Test\00016.ppm
# 16
# Images_Test\00017.ppm
# 17
# Images_Test\00018.ppm
# 18
# Images_Test\00019.ppm
# 19
# Images_Test\00020.ppm
# 20
# Images_Test\00021.ppm
# 21
# Images_Test\00022.ppm
# 22
# Images_Test\00023.ppm
# 23
# Images_Test\00024.ppm
# 24
# Images_Test\00025.ppm
# 25
# Images_Test\00026.ppm
# 26
# Images_Test\00027.ppm
# 27
# Images_Test\00028.ppm
# 28
# Images_Test\00029.ppm
# 29
# Images_Test\00030.ppm
# 30
# Images_Test\00031.ppm
# 31
# Images_Test\00032.ppm
# 32
# Images_Test\00033.ppm
# 33
# Images_Test\00034.ppm
# 34
# Images_Test\00035.ppm
# 35
# Images_Test\00036.ppm
# 36
# Images_Test\00037.ppm
# 37
# Images_Test\00038.ppm
# 38
# Images_Test\00039.ppm
# 39
# Images_Test\00040.ppm
# 40
# Images_Test\00041.ppm
# 41
# Images_Test\00042.ppm
# 42
# Images_Test\00043.ppm
# 43
# Images_Test\00044.ppm
# 44
# Images_Test\00045.ppm
# 45
# Images_Test\00046.ppm
# 46
# Images_Test\00047.ppm
# 47
# Images_Test\00048.ppm
# 48
# Images_Test\00049.ppm
# 49
# Images_Test\00050.ppm
# 50
# Images_Test\00051.ppm
# 51
# Images_Test\00052.ppm
# 52
# Images_Test\00053.ppm
# 53
# Images_Test\00054.ppm
# 54
# Images_Test\00055.ppm
# 55
# Images_Test\00056.ppm
# 56
# Images_Test\00057.ppm
# 57
# Images_Test\00058.ppm
# 58
# Images_Test\00059.ppm
# 59
# Images_Test\00060.ppm
# 60
# Images_Test\00061.ppm
# 61
# Images_Test\00062.ppm
# 62
# Images_Test\00063.ppm
# 63
# Images_Test\00064.ppm
# 64
# Images_Test\00065.ppm
# 65
# Images_Test\00066.ppm
# 66
# Images_Test\00067.ppm
# 67
# Images_Test\00068.ppm
# 68
# Images_Test\00069.ppm
# 69
# Images_Test\00070.ppm
# 70
# Images_Test\00071.ppm
# 71
# Images_Test\00072.ppm
# 72
# Images_Test\00073.ppm
# 73
# Images_Test\00074.ppm
# 74
# Images_Test\00075.ppm
# 75
# Images_Test\00076.ppm
# 76
# Images_Test\00077.ppm
# 77
# Images_Test\00078.ppm
# 78
# Images_Test\00079.ppm
# 79
# Images_Test\00080.ppm
# 80
# Images_Test\00081.ppm
# 81
# Images_Test\00082.ppm
# 82
# Images_Test\00083.ppm
# 83
# Images_Test\00084.ppm
# 84
# Images_Test\00085.ppm
# 85
# Images_Test\00086.ppm
# 86
# Images_Test\00087.ppm
# 87
# Images_Test\00088.ppm
# 88
# Images_Test\00089.ppm
# 89
# Images_Test\00090.ppm
# 90
# Images_Test\00091.ppm
# 91
# Images_Test\00092.ppm
# 92
# Images_Test\00093.ppm
# 93
# Images_Test\00094.ppm
# 94
# Images_Test\00095.ppm
# 95
# Images_Test\00096.ppm
# 96
# Images_Test\00097.ppm
# 97
# Images_Test\00098.ppm
# 98
# Images_Test\00099.ppm
# 99
# Images_Test\00100.ppm
# 0
# Images_Test\00101.ppm
# 1
# Images_Test\00102.ppm
# 2
# Images_Test\00103.ppm
# 3
# Images_Test\00104.ppm
# 4
# Images_Test\00105.ppm
# 5
# Images_Test\00106.ppm
# 6
# Images_Test\00107.ppm
# 7
# Images_Test\00108.ppm
# 8
# Images_Test\00109.ppm
# 9
# Images_Test\00110.ppm
# 10
# Images_Test\00111.ppm
# 11
# Images_Test\00112.ppm
# 12
# Images_Test\00113.ppm
# 13
# Images_Test\00114.ppm
# 14
# Images_Test\00115.ppm
# 15
# Images_Test\00116.ppm
# 16
# Images_Test\00117.ppm
# 17
# Images_Test\00118.ppm
# 18
# Images_Test\00119.ppm
# 19
# Images_Test\00120.ppm
# 20
# Images_Test\00121.ppm
# 21
# Images_Test\00122.ppm
# 22
# Images_Test\00123.ppm
# 23
# Images_Test\00124.ppm
# 24
# Images_Test\00125.ppm
# 25
# Images_Test\00126.ppm
# 26
# Images_Test\00127.ppm
# 27
# Images_Test\00128.ppm
# 28
# Images_Test\00129.ppm
# 29
# Images_Test\00130.ppm
# 30
# Images_Test\00131.ppm
# 31
# Images_Test\00132.ppm
# 32
# Images_Test\00133.ppm
# 33
# Images_Test\00134.ppm
# 34
# Images_Test\00135.ppm
# 35
# Images_Test\00136.ppm
# 36
# Images_Test\00137.ppm
# 37
# Images_Test\00138.ppm
# 38
# Images_Test\00139.ppm
# 39
# Images_Test\00140.ppm
# 40
# Images_Test\00141.ppm
# 41
# Images_Test\00142.ppm
# 42
# Images_Test\00143.ppm
# 43
# Images_Test\00144.ppm
# 44
# Images_Test\00145.ppm
# 45
# Images_Test\00146.ppm
# 46
# Images_Test\00147.ppm
# 47
# Images_Test\00148.ppm
# 48
# Images_Test\00149.ppm
# 49
# Images_Test\00150.ppm
# 50
# Images_Test\00151.ppm
# 51
# Images_Test\00152.ppm
# 52
# Images_Test\00153.ppm
# 53
# Images_Test\00154.ppm
# 54
# Images_Test\00155.ppm
# 55
# Images_Test\00156.ppm
# 56
# Images_Test\00157.ppm
# 57
# Images_Test\00158.ppm
# 58
# Images_Test\00159.ppm
# 59
# Images_Test\00160.ppm
# 60
# Images_Test\00161.ppm
# 61
# Images_Test\00162.ppm
# 62
# Images_Test\00163.ppm
# 63
# Images_Test\00164.ppm
# 64
# Images_Test\00165.ppm
# 65
# Images_Test\00166.ppm
# 66
# Images_Test\00167.ppm
# 67
# Images_Test\00168.ppm
# 68
# Images_Test\00169.ppm
# 69
# Images_Test\00170.ppm
# 70
# Images_Test\00171.ppm
# 71
# Images_Test\00172.ppm
# 72
# Images_Test\00173.ppm
# 73
# Images_Test\00174.ppm
# 74
# Images_Test\00175.ppm
# 75
# Images_Test\00176.ppm
# 76
# Images_Test\00177.ppm
# 77
# Images_Test\00178.ppm
# 78
# Images_Test\00179.ppm
# 79
# Images_Test\00180.ppm
# 80
# Images_Test\00181.ppm
# 81
# Images_Test\00182.ppm
# 82
# Images_Test\00183.ppm
# 83
# Images_Test\00184.ppm
# 84
# Images_Test\00185.ppm
# 85
# Images_Test\00186.ppm
# 86
# Images_Test\00187.ppm
# 87
# Images_Test\00188.ppm
# 88
# Images_Test\00189.ppm
# 89
# Images_Test\00190.ppm
# 90
# Images_Test\00191.ppm
# 91
# Images_Test\00192.ppm
# 92
# Images_Test\00193.ppm
# 93
# Images_Test\00194.ppm
# 94
# Images_Test\00195.ppm
# 95
# Images_Test\00196.ppm
# 96
# Images_Test\00197.ppm
# 97
# Images_Test\00198.ppm
# 98
# Images_Test\00199.ppm
# 99
# Images_Test\00200.ppm
# 0
# Images_Test\00201.ppm
# 1
# Images_Test\00202.ppm
# 2
# Images_Test\00203.ppm
# 3
# Images_Test\00204.ppm
# 4
# Images_Test\00205.ppm
# 5
# Images_Test\00206.ppm
# 6
# Images_Test\00207.ppm
# 7
# Images_Test\00208.ppm
# 8
# Images_Test\00209.ppm
# 9
# Images_Test\00210.ppm
# 10
# Images_Test\00211.ppm
# 11
# Images_Test\00212.ppm
# 12
# Images_Test\00213.ppm
# 13
# Images_Test\00214.ppm
# 14
# Images_Test\00215.ppm
# 15
# Images_Test\00216.ppm
# 16
# Images_Test\00217.ppm
# 17
# Images_Test\00218.ppm
# 18
# Images_Test\00219.ppm
# 19
# Images_Test\00220.ppm
# 20
# Images_Test\00221.ppm
# 21
# Images_Test\00222.ppm
# 22
# Images_Test\00223.ppm
# 23
# Images_Test\00224.ppm
# 24
# Images_Test\00225.ppm
# 25
# Images_Test\00226.ppm
# 26
# Images_Test\00227.ppm
# 27
# Images_Test\00228.ppm
# 28
# Images_Test\00229.ppm
# 29
# Images_Test\00230.ppm
# 30
# Images_Test\00231.ppm
# 31
# Images_Test\00232.ppm
# 32
# Images_Test\00233.ppm
# 33
# Images_Test\00234.ppm
# 34
# Images_Test\00235.ppm
# 35
# Images_Test\00236.ppm
# 36
# Images_Test\00237.ppm
# 37
# Images_Test\00238.ppm
# 38
# Images_Test\00239.ppm
# 39
# Images_Test\00240.ppm
# 40
# Images_Test\00241.ppm
# 41
# Images_Test\00242.ppm
# 42
# Images_Test\00243.ppm
# 43
# Images_Test\00244.ppm
# 44
# Images_Test\00245.ppm
# 45
# Images_Test\00246.ppm
# 46
# Images_Test\00247.ppm
# 47
# Images_Test\00248.ppm
# 48
# Images_Test\00249.ppm
# 49
# Images_Test\00250.ppm
# 50
# Images_Test\00251.ppm
# 51
# Images_Test\00252.ppm
# 52
# Images_Test\00253.ppm
# 53
# Images_Test\00254.ppm
# 54
# Images_Test\00255.ppm
# 55
# Images_Test\00256.ppm
# 56
# Images_Test\00257.ppm
# 57
# Images_Test\00258.ppm
# 58
# Images_Test\00259.ppm
# 59
# Images_Test\00260.ppm
# 60
# Images_Test\00261.ppm
# 61
# Images_Test\00262.ppm
# 62
# Images_Test\00263.ppm
# 63
# Images_Test\00264.ppm
# 64
# Images_Test\00265.ppm
# 65
# Images_Test\00266.ppm
# 66
# Images_Test\00267.ppm
# 67
# Images_Test\00268.ppm
# 68
# Images_Test\00269.ppm
# 69
# Images_Test\00270.ppm
# 70
# Images_Test\00271.ppm
# 71
# Images_Test\00272.ppm
# 72
# Images_Test\00273.ppm
# 73
# Images_Test\00274.ppm
# 74
# Images_Test\00275.ppm
# 75
# Images_Test\00276.ppm
# 76
# Images_Test\00277.ppm
# 77
# Images_Test\00278.ppm
# 78
# Images_Test\00279.ppm
# 79
# Images_Test\00280.ppm
# 80
# Images_Test\00281.ppm
# 81
# Images_Test\00282.ppm
# 82
# Images_Test\00283.ppm
# 83
# Images_Test\00284.ppm
# 84
# Images_Test\00285.ppm
# 85
# Images_Test\00286.ppm
# 86
# Images_Test\00287.ppm
# 87
# Images_Test\00288.ppm
# 88
# Images_Test\00289.ppm
# 89
# Images_Test\00290.ppm
# 90
# Images_Test\00291.ppm
# 91
# Images_Test\00292.ppm
# 92
# Images_Test\00293.ppm
# 93
# Images_Test\00294.ppm
# 94
# Images_Test\00295.ppm
# 95
# Images_Test\00296.ppm
# 96
# Images_Test\00297.ppm
# 97
# Images_Test\00298.ppm
# 98
# Images_Test\00299.ppm
# 99
# Images_Test\00300.ppm
# 0
# Images_Test\00301.ppm
# 1
# Images_Test\00302.ppm
# 2
# Images_Test\00303.ppm
# 3
# Images_Test\00304.ppm
# 4
# Images_Test\00305.ppm
# 5
# Images_Test\00306.ppm
# 6
# Images_Test\00307.ppm
# 7
# Images_Test\00308.ppm
# 8
# Images_Test\00309.ppm
# 9
# Images_Test\00310.ppm
# 10
# Images_Test\00311.ppm
# 11
# Images_Test\00312.ppm
# 12
# Images_Test\00313.ppm
# 13
# Images_Test\00314.ppm
# 14
# Images_Test\00315.ppm
# 15
# Images_Test\00316.ppm
# 16
# Images_Test\00317.ppm
# 17
# Images_Test\00318.ppm
# 18
# Images_Test\00319.ppm
# 19
# Images_Test\00320.ppm
# 20
# Images_Test\00321.ppm
# 21
# Images_Test\00322.ppm
# 22
# Images_Test\00323.ppm
# 23
# Images_Test\00324.ppm
# 24
# Images_Test\00325.ppm
# 25
# Images_Test\00326.ppm
# 26
# Images_Test\00327.ppm
# 27
# Images_Test\00328.ppm
# 28
# Images_Test\00329.ppm
# 29
# Images_Test\00330.ppm
# 30
# Images_Test\00331.ppm
# 31
# Images_Test\00332.ppm
# 32
# Images_Test\00333.ppm
# 33
# Images_Test\00334.ppm
# 34
# Images_Test\00335.ppm
# 35
# Images_Test\00336.ppm
# 36
# Images_Test\00337.ppm
# 37
# Images_Test\00338.ppm
# 38
# Images_Test\00339.ppm
# 39
# Images_Test\00340.ppm
# 40
# Images_Test\00341.ppm
# 41
# Images_Test\00342.ppm
# 42
# Images_Test\00343.ppm
# 43
# Images_Test\00344.ppm
# 44
# Images_Test\00345.ppm
# 45
# Images_Test\00346.ppm
# 46
# Images_Test\00347.ppm
# 47
# Images_Test\00348.ppm
# 48
# Images_Test\00349.ppm
# 49
# Images_Test\00350.ppm
# 50
# Images_Test\00351.ppm
# 51
# Images_Test\00352.ppm
# 52
# Images_Test\00353.ppm
# 53
# Images_Test\00354.ppm
# 54
# Images_Test\00355.ppm
# 55
# Images_Test\00356.ppm
# 56
# Images_Test\00357.ppm
# 57
# Images_Test\00358.ppm
# 58
# Images_Test\00359.ppm
# 59
# Images_Test\00360.ppm
# 60
# Images_Test\00361.ppm
# 61
# Images_Test\00362.ppm
# 62
# Images_Test\00363.ppm
# 63
# Images_Test\00364.ppm
# 64
# Images_Test\00365.ppm
# 65
# Images_Test\00366.ppm
# 66
# Images_Test\00367.ppm
# 67
# Images_Test\00368.ppm
# 68
# Images_Test\00369.ppm
# 69
# Images_Test\00370.ppm
# 70
# Images_Test\00371.ppm
# 71
# Images_Test\00372.ppm
# 72
# Images_Test\00373.ppm
# 73
# Images_Test\00374.ppm
# 74
# Images_Test\00375.ppm
# 75
# Images_Test\00376.ppm
# 76
# Images_Test\00377.ppm
# 77
# Images_Test\00378.ppm
# 78
# Images_Test\00379.ppm
# 79
# Images_Test\00380.ppm
# 80
# Images_Test\00381.ppm
# 81
# Images_Test\00382.ppm
# 82
# Images_Test\00383.ppm
# 83
# Images_Test\00384.ppm
# 84
# Images_Test\00385.ppm
# 85
# Images_Test\00386.ppm
# 86
# Images_Test\00387.ppm
# 87
# Images_Test\00388.ppm
# 88
# Images_Test\00389.ppm
# 89
# Images_Test\00390.ppm
# 90
# Images_Test\00391.ppm
# 91
# Images_Test\00392.ppm
# 92
# Images_Test\00393.ppm
# 93
# Images_Test\00394.ppm
# 94
# Images_Test\00395.ppm
# 95
# Images_Test\00396.ppm
# 96
# Images_Test\00397.ppm
# 97
# Images_Test\00398.ppm
# 98
# Images_Test\00399.ppm
# 99
# Images_Test\00400.ppm
# 0
# Images_Test\00401.ppm
# 1
# Images_Test\00402.ppm
# 2
# Images_Test\00403.ppm
# 3
# Images_Test\00404.ppm
# 4
# Images_Test\00405.ppm
# 5
# Images_Test\00406.ppm
# 6
# Images_Test\00407.ppm
# 7
# Images_Test\00408.ppm
# 8
# Images_Test\00409.ppm
# 9
# Images_Test\00410.ppm
# 10
# Images_Test\00411.ppm
# 11
# Images_Test\00412.ppm
# 12
# Images_Test\00413.ppm
# 13
# Images_Test\00414.ppm
# 14
# Images_Test\00415.ppm
# 15
# Images_Test\00416.ppm
# 16
# Images_Test\00417.ppm
# 17
# Images_Test\00418.ppm
# 18
# Images_Test\00419.ppm
# 19
# Images_Test\00420.ppm
# 20
# Images_Test\00421.ppm
# 21
# Images_Test\00422.ppm
# 22
# Images_Test\00423.ppm
# 23
# Images_Test\00424.ppm
# 24
# Images_Test\00425.ppm
# 25
# Images_Test\00426.ppm
# 26
# Images_Test\00427.ppm
# 27
# Images_Test\00428.ppm
# 28
# Images_Test\00429.ppm
# 29
# Images_Test\00430.ppm
# 30
# Images_Test\00431.ppm
# 31
# Images_Test\00432.ppm
# 32
# Images_Test\00433.ppm
# 33
# Images_Test\00434.ppm
# 34
# Images_Test\00435.ppm
# 35
# Images_Test\00436.ppm
# 36
# Images_Test\00437.ppm
# 37
# Images_Test\00438.ppm
# 38
# Images_Test\00439.ppm
# 39
# Images_Test\00440.ppm
# 40
# Images_Test\00441.ppm
# 41
# Images_Test\00442.ppm
# 42
# Images_Test\00443.ppm
# 43
# Images_Test\00444.ppm
# 44
# Images_Test\00445.ppm
# 45
# Images_Test\00446.ppm
# 46
# Images_Test\00447.ppm
# 47
# Images_Test\00448.ppm
# 48
# Images_Test\00449.ppm
# 49
# Images_Test\00450.ppm
# 50
# Images_Test\00451.ppm
# 51
# Images_Test\00452.ppm
# 52
# Images_Test\00453.ppm
# 53
# Images_Test\00454.ppm
# 54
# Images_Test\00455.ppm
# 55
# Images_Test\00456.ppm
# 56
# Images_Test\00457.ppm
# 57
# Images_Test\00458.ppm
# 58
# Images_Test\00459.ppm
# 59
# Images_Test\00460.ppm
# 60
# Images_Test\00461.ppm
# 61
# Images_Test\00462.ppm
# 62
# Images_Test\00463.ppm
# 63
# Images_Test\00464.ppm
# 64
# Images_Test\00465.ppm
# 65
# Images_Test\00466.ppm
# 66
# Images_Test\00467.ppm
# 67
# Images_Test\00468.ppm
# 68
# Images_Test\00469.ppm
# 69
# Images_Test\00470.ppm
# 70
# Images_Test\00471.ppm
# 71
# Images_Test\00472.ppm
# 72
# Images_Test\00473.ppm
# 73
# Images_Test\00474.ppm
# 74
# Images_Test\00475.ppm
# 75
# Images_Test\00476.ppm
# 76
# Images_Test\00477.ppm
# 77
# Images_Test\00478.ppm
# 78
# Images_Test\00479.ppm
# 79
# Images_Test\00480.ppm
# 80
# Images_Test\00481.ppm
# 81
# Images_Test\00482.ppm
# 82
# Images_Test\00483.ppm
# 83
# Images_Test\00484.ppm
# 84
# Images_Test\00485.ppm
# 85
# Images_Test\00486.ppm
# 86
# Images_Test\00487.ppm
# 87
# Images_Test\00488.ppm
# 88
# Images_Test\00489.ppm
# 89
# Images_Test\00490.ppm
# 90
# Images_Test\00491.ppm
# 91
# Images_Test\00492.ppm
# 92
# Images_Test\00493.ppm
# 93
# Images_Test\00494.ppm
# 94
# Images_Test\00495.ppm
# 95
# Images_Test\00496.ppm
# 96
# Images_Test\00497.ppm
# 97
# Images_Test\00498.ppm
# 98
# Images_Test\00499.ppm
# 99
# Images_Test\00500.ppm
# 0
# Images_Test\00501.ppm
# 1
# Images_Test\00502.ppm
# 2
# Images_Test\00503.ppm
# 3
# Images_Test\00504.ppm
# 4
# Images_Test\00505.ppm
# 5
# Images_Test\00506.ppm
# 6
# Images_Test\00507.ppm
# 7
# Images_Test\00508.ppm
# 8
# Images_Test\00509.ppm
# 9
# Images_Test\00510.ppm
# 10
# Images_Test\00511.ppm
# 11
# Images_Test\00512.ppm
# 12
# Images_Test\00513.ppm
# 13
# Images_Test\00514.ppm
# 14
# Images_Test\00515.ppm
# 15
# Images_Test\00516.ppm
# 16
# Images_Test\00517.ppm
# 17
# Images_Test\00518.ppm
# 18
# Images_Test\00519.ppm
# 19
# Images_Test\00520.ppm
# 20
# Images_Test\00521.ppm
# 21
# Images_Test\00522.ppm
# 22
# Images_Test\00523.ppm
# 23
# Images_Test\00524.ppm
# 24
# Images_Test\00525.ppm
# 25
# Images_Test\00526.ppm
# 26
# Images_Test\00527.ppm
# 27
# Images_Test\00528.ppm
# 28
# Images_Test\00529.ppm
# 29
# Images_Test\00530.ppm
# 30
# Images_Test\00531.ppm
# 31
# Images_Test\00532.ppm
# 32
# Images_Test\00533.ppm
# 33
# Images_Test\00534.ppm
# 34
# Images_Test\00535.ppm
# 35
# Images_Test\00536.ppm
# 36
# Images_Test\00537.ppm
# 37
# Images_Test\00538.ppm
# 38
# Images_Test\00539.ppm
# 39
# Images_Test\00540.ppm
# 40
# Images_Test\00541.ppm
# 41
# Images_Test\00542.ppm
# 42
# Images_Test\00543.ppm
# 43
# Images_Test\00544.ppm
# 44
# Images_Test\00545.ppm
# 45
# Images_Test\00546.ppm
# 46
# Images_Test\00547.ppm
# 47
# Images_Test\00548.ppm
# 48
# Images_Test\00549.ppm
# 49
# Images_Test\00550.ppm
# 50
# Images_Test\00551.ppm
# 51
# Images_Test\00552.ppm
# 52
# Images_Test\00553.ppm
# 53
# Images_Test\00554.ppm
# 54
# Images_Test\00555.ppm
# 55
# Images_Test\00556.ppm
# 56
# Images_Test\00557.ppm
# 57
# Images_Test\00558.ppm
# 58
# Images_Test\00559.ppm
# 59
# Images_Test\00560.ppm
# 60
# Images_Test\00561.ppm
# 61
# Images_Test\00562.ppm
# 62
# Images_Test\00563.ppm
# 63
# Images_Test\00564.ppm
# 64
# Images_Test\00565.ppm
# 65
# Images_Test\00566.ppm
# 66
# Images_Test\00567.ppm
# 67
# Images_Test\00568.ppm
# 68
# Images_Test\00569.ppm
# 69
# Images_Test\00570.ppm
# 70
# Images_Test\00571.ppm
# 71
# Images_Test\00572.ppm
# 72
# Images_Test\00573.ppm
# 73
# Images_Test\00574.ppm
# 74
# Images_Test\00575.ppm
# 75
# Images_Test\00576.ppm
# 76
# Images_Test\00577.ppm
# 77
# Images_Test\00578.ppm
# 78
# Images_Test\00579.ppm
# 79
# Images_Test\00580.ppm
# 80
# Images_Test\00581.ppm
# 81
# Images_Test\00582.ppm
# 82
# Images_Test\00583.ppm
# 83
# Images_Test\00584.ppm
# 84
# Images_Test\00585.ppm
# 85
# Images_Test\00586.ppm
# 86
# Images_Test\00587.ppm
# 87
# Images_Test\00588.ppm
# 88
# Images_Test\00589.ppm
# 89
# Images_Test\00590.ppm
# 90
# Images_Test\00591.ppm
# 91
# Images_Test\00592.ppm
# 92
# Images_Test\00593.ppm
# 93
# Images_Test\00594.ppm
# 94
# Images_Test\00595.ppm
# 95
# Images_Test\00596.ppm
# 96
# Images_Test\00597.ppm
# 97
# Images_Test\00598.ppm
# 98
# Images_Test\00599.ppm
# 99
# Images_Test\00600.ppm
# 0
# Images_Test\00601.ppm
# 1
# Images_Test\00602.ppm
# 2
# Images_Test\00603.ppm
# 3
# Images_Test\00604.ppm
# 4
# Images_Test\00605.ppm
# 5
# Images_Test\00606.ppm
# 6
# Images_Test\00607.ppm
# 7
# Images_Test\00608.ppm
# 8
# Images_Test\00609.ppm
# 9
# Images_Test\00610.ppm
# 10
# Images_Test\00611.ppm
# 11
# Images_Test\00612.ppm
# 12
# Images_Test\00613.ppm
# 13
# Images_Test\00614.ppm
# 14
# Images_Test\00615.ppm
# 15
# Images_Test\00616.ppm
# 16
# Images_Test\00617.ppm
# 17
# Images_Test\00618.ppm
# 18
# Images_Test\00619.ppm
# 19
# Images_Test\00620.ppm
# 20
# Images_Test\00621.ppm
# 21
# Images_Test\00622.ppm
# 22
# Images_Test\00623.ppm
# 23
# Images_Test\00624.ppm
# 24
# Images_Test\00625.ppm
# 25
# Images_Test\00626.ppm
# 26
# Images_Test\00627.ppm
# 27
# Images_Test\00628.ppm
# 28
# Images_Test\00629.ppm
# 29
# Images_Test\00630.ppm
# 30
# Images_Test\00631.ppm
# 31
# Images_Test\00632.ppm
# 32
# Images_Test\00633.ppm
# 33
# Images_Test\00634.ppm
# 34
# Images_Test\00635.ppm
# 35
# Images_Test\00636.ppm
# 36
# Images_Test\00637.ppm
# 37
# Images_Test\00638.ppm
# 38
# Images_Test\00639.ppm
# 39
# Images_Test\00640.ppm
# 40
# Images_Test\00641.ppm
# 41
# Images_Test\00642.ppm
# 42
# Images_Test\00643.ppm
# 43
# Images_Test\00644.ppm
# 44
# Images_Test\00645.ppm
# 45
# Images_Test\00646.ppm
# 46
# Images_Test\00647.ppm
# 47
# Images_Test\00648.ppm
# 48
# Images_Test\00649.ppm
# 49
# Images_Test\00650.ppm
# 50
# Images_Test\00651.ppm
# 51
# Images_Test\00652.ppm
# 52
# Images_Test\00653.ppm
# 53
# Images_Test\00654.ppm
# 54
# Images_Test\00655.ppm
# 55
# Images_Test\00656.ppm
# 56
# Images_Test\00657.ppm
# 57
# Images_Test\00658.ppm
# 58
# Images_Test\00659.ppm
# 59
# Images_Test\00660.ppm
# 60
# Images_Test\00661.ppm
# 61
# Images_Test\00662.ppm
# 62
# Images_Test\00663.ppm
# 63
# Images_Test\00664.ppm
# 64
# Images_Test\00665.ppm
# 65
# Images_Test\00666.ppm
# 66
# Images_Test\00667.ppm
# 67
# Images_Test\00668.ppm
# 68
# Images_Test\00669.ppm
# 69
# Images_Test\00670.ppm
# 70
# Images_Test\00671.ppm
# 71
# Images_Test\00672.ppm
# 72
# Images_Test\00673.ppm
# 73
# Images_Test\00674.ppm
# 74
# Images_Test\00675.ppm
# 75
# Images_Test\00676.ppm
# 76
# Images_Test\00677.ppm
# 77
# Images_Test\00678.ppm
# 78
# Images_Test\00679.ppm
# 79
# Images_Test\00680.ppm
# 80
# Images_Test\00681.ppm
# 81
# Images_Test\00682.ppm
# 82
# Images_Test\00683.ppm
# 83
# Images_Test\00684.ppm
# 84
# Images_Test\00685.ppm
# 85
# Images_Test\00686.ppm
# 86
# Images_Test\00687.ppm
# 87
# Images_Test\00688.ppm
# 88
# Images_Test\00689.ppm
# 89
# Images_Test\00690.ppm
# 90
# Images_Test\00691.ppm
# 91
# Images_Test\00692.ppm
# 92
# Images_Test\00693.ppm
# 93
# Images_Test\00694.ppm
# 94
# Images_Test\00695.ppm
# 95
# Images_Test\00696.ppm
# 96
# Images_Test\00697.ppm
# 97
# Images_Test\00698.ppm
# 98
# Images_Test\00699.ppm
# 99
# Images_Test\00700.ppm
# 0
# Images_Test\00701.ppm
# 1
# Images_Test\00702.ppm
# 2
# Images_Test\00703.ppm
# 3
# Images_Test\00704.ppm
# 4
# Images_Test\00705.ppm
# 5
# Images_Test\00706.ppm
# 6
# Images_Test\00707.ppm
# 7
# Images_Test\00708.ppm
# 8
# Images_Test\00709.ppm
# 9
# Images_Test\00710.ppm
# 10
# Images_Test\00711.ppm
# 11
# Images_Test\00712.ppm
# 12
# Images_Test\00713.ppm
# 13
# Images_Test\00714.ppm
# 14
# Images_Test\00715.ppm
# 15
# Images_Test\00716.ppm
# 16
# Images_Test\00717.ppm
# 17
# Images_Test\00718.ppm
# 18
# Images_Test\00719.ppm
# 19
# Images_Test\00720.ppm
# 20
# Images_Test\00721.ppm
# 21
# Images_Test\00722.ppm
# 22
# Images_Test\00723.ppm
# 23
# Images_Test\00724.ppm
# 24
# Images_Test\00725.ppm
# 25
# Images_Test\00726.ppm
# 26
# Images_Test\00727.ppm
# 27
# Images_Test\00728.ppm
# 28
# Images_Test\00729.ppm
# 29
# Images_Test\00730.ppm
# 30
# Images_Test\00731.ppm
# 31
# Images_Test\00732.ppm
# 32
# Images_Test\00733.ppm
# 33
# Images_Test\00734.ppm
# 34
# Images_Test\00735.ppm
# 35
# Images_Test\00736.ppm
# 36
# Images_Test\00737.ppm
# 37
# Images_Test\00738.ppm
# 38
# Images_Test\00739.ppm
# 39
# Images_Test\00740.ppm
# 40
# Images_Test\00741.ppm
# 41
# Images_Test\00742.ppm
# 42
# Images_Test\00743.ppm
# 43
# Images_Test\00744.ppm
# 44
# Images_Test\00745.ppm
# 45
# Images_Test\00746.ppm
# 46
# Images_Test\00747.ppm
# 47
# Images_Test\00748.ppm
# 48
# Images_Test\00749.ppm
# 49
# Images_Test\00750.ppm
# 50
# Images_Test\00751.ppm
# 51
# Images_Test\00752.ppm
# 52
# Images_Test\00753.ppm
# 53
# Images_Test\00754.ppm
# 54
# Images_Test\00755.ppm
# 55
# Images_Test\00756.ppm
# 56
# Images_Test\00757.ppm
# 57
# Images_Test\00758.ppm
# 58
# Images_Test\00759.ppm
# 59
# Images_Test\00760.ppm
# 60
# Images_Test\00761.ppm
# 61
# Images_Test\00762.ppm
# 62
# Images_Test\00763.ppm
# 63
# Images_Test\00764.ppm
# 64
# Images_Test\00765.ppm
# 65
# Images_Test\00766.ppm
# 66
# Images_Test\00767.ppm
# 67
# Images_Test\00768.ppm
# 68
# Images_Test\00769.ppm
# 69
# Images_Test\00770.ppm
# 70
# Images_Test\00771.ppm
# 71
# Images_Test\00772.ppm
# 72
# Images_Test\00773.ppm
# 73
# Images_Test\00774.ppm
# 74
# Images_Test\00775.ppm
# 75
# Images_Test\00776.ppm
# 76
# Images_Test\00777.ppm
# 77
# Images_Test\00778.ppm
# 78
# Images_Test\00779.ppm
# 79
# Images_Test\00780.ppm
# 80
# Images_Test\00781.ppm
# 81
# Images_Test\00782.ppm
# 82
# Images_Test\00783.ppm
# 83
# Images_Test\00784.ppm
# 84
# Images_Test\00785.ppm
# 85
# Images_Test\00786.ppm
# 86
# Images_Test\00787.ppm
# 87
# Images_Test\00788.ppm
# 88
# Images_Test\00789.ppm
# 89
# Images_Test\00790.ppm
# 90
# Images_Test\00791.ppm
# 91
# Images_Test\00792.ppm
# 92
# Images_Test\00793.ppm
# 93
# Images_Test\00794.ppm
# 94
# Images_Test\00795.ppm
# 95
# Images_Test\00796.ppm
# 96
# Images_Test\00797.ppm
# 97
# Images_Test\00798.ppm
# 98
# Images_Test\00799.ppm
# 99
# Images_Test\00800.ppm
# 0
# Images_Test\00801.ppm
# 1
# Images_Test\00802.ppm
# 2
# Images_Test\00803.ppm
# 3
# Images_Test\00804.ppm
# 4
# Images_Test\00805.ppm
# 5
# Images_Test\00806.ppm
# 6
# Images_Test\00807.ppm
# 7
# Images_Test\00808.ppm
# 8
# Images_Test\00809.ppm
# 9
# Images_Test\00810.ppm
# 10
# Images_Test\00811.ppm
# 11
# Images_Test\00812.ppm
# 12
# Images_Test\00813.ppm
# 13
# Images_Test\00814.ppm
# 14
# Images_Test\00815.ppm
# 15
# Images_Test\00816.ppm
# 16
# Images_Test\00817.ppm
# 17
# Images_Test\00818.ppm
# 18
# Images_Test\00819.ppm
# 19
# Images_Test\00820.ppm
# 20
# Images_Test\00821.ppm
# 21
# Images_Test\00822.ppm
# 22
# Images_Test\00823.ppm
# 23
# Images_Test\00824.ppm
# 24
# Images_Test\00825.ppm
# 25
# Images_Test\00826.ppm
# 26
# Images_Test\00827.ppm
# 27
# Images_Test\00828.ppm
# 28
# Images_Test\00829.ppm
# 29
# Images_Test\00830.ppm
# 30
# Images_Test\00831.ppm
# 31
# Images_Test\00832.ppm
# 32
# Images_Test\00833.ppm
# 33
# Images_Test\00834.ppm
# 34
# Images_Test\00835.ppm
# 35
# Images_Test\00836.ppm
# 36
# Images_Test\00837.ppm
# 37
# Images_Test\00838.ppm
# 38
# Images_Test\00839.ppm
# 39
# Images_Test\00840.ppm
# 40
# Images_Test\00841.ppm
# 41
# Images_Test\00842.ppm
# 42
# Images_Test\00843.ppm
# 43
# Images_Test\00844.ppm
# 44
# Images_Test\00845.ppm
# 45
# Images_Test\00846.ppm
# 46
# Images_Test\00847.ppm
# 47
# Images_Test\00848.ppm
# 48
# Images_Test\00849.ppm
# 49
# Images_Test\00850.ppm
# 50
# Images_Test\00851.ppm
# 51
# Images_Test\00852.ppm
# 52
# Images_Test\00853.ppm
# 53
# Images_Test\00854.ppm
# 54
# Images_Test\00855.ppm
# 55
# Images_Test\00856.ppm
# 56
# Images_Test\00857.ppm
# 57
# Images_Test\00858.ppm
# 58
# Images_Test\00859.ppm
# 59
# Images_Test\00860.ppm
# 60
# Images_Test\00861.ppm
# 61
# Images_Test\00862.ppm
# 62
# Images_Test\00863.ppm
# 63
# Images_Test\00864.ppm
# 64
# Images_Test\00865.ppm
# 65
# Images_Test\00866.ppm
# 66
# Images_Test\00867.ppm
# 67
# Images_Test\00868.ppm
# 68
# Images_Test\00869.ppm
# 69
# Images_Test\00870.ppm
# 70
# Images_Test\00871.ppm
# 71
# Images_Test\00872.ppm
# 72
# Images_Test\00873.ppm
# 73
# Images_Test\00874.ppm
# 74
# Images_Test\00875.ppm
# 75
# Images_Test\00876.ppm
# 76
# Images_Test\00877.ppm
# 77
# Images_Test\00878.ppm
# 78
# Images_Test\00879.ppm
# 79
# Images_Test\00880.ppm
# 80
# Images_Test\00881.ppm
# 81
# Images_Test\00882.ppm
# 82
# Images_Test\00883.ppm
# 83
# Images_Test\00884.ppm
# 84
# Images_Test\00885.ppm
# 85
# Images_Test\00886.ppm
# 86
# Images_Test\00887.ppm
# 87
# Images_Test\00888.ppm
# 88
# Images_Test\00889.ppm
# 89
# Images_Test\00890.ppm
# 90
# Images_Test\00891.ppm
# 91
# Images_Test\00892.ppm
# 92
# Images_Test\00893.ppm
# 93
# Images_Test\00894.ppm
# 94
# Images_Test\00895.ppm
# 95
# Images_Test\00896.ppm
# 96
# Images_Test\00897.ppm
# 97
# Images_Test\00898.ppm
# 98
# Images_Test\00899.ppm
# 99
# Images_Test\00900.ppm
# 0
# Images_Test\00901.ppm
# 1
# Images_Test\00902.ppm
# 2
# Images_Test\00903.ppm
# 3
# Images_Test\00904.ppm
# 4
# Images_Test\00905.ppm
# 5
# Images_Test\00906.ppm
# 6
# Images_Test\00907.ppm
# 7
# Images_Test\00908.ppm
# 8
# Images_Test\00909.ppm
# 9
# Images_Test\00910.ppm
# 10
# Images_Test\00911.ppm
# 11
# Images_Test\00912.ppm
# 12
# Images_Test\00913.ppm
# 13
# Images_Test\00914.ppm
# 14
# Images_Test\00915.ppm
# 15
# Images_Test\00916.ppm
# 16
# Images_Test\00917.ppm
# 17
# Images_Test\00918.ppm
# 18
# Images_Test\00919.ppm
# 19
# Images_Test\00920.ppm
# 20
# Images_Test\00921.ppm
# 21
# Images_Test\00922.ppm
# 22
# Images_Test\00923.ppm
# 23
# Images_Test\00924.ppm
# 24
# Images_Test\00925.ppm
# 25
# Images_Test\00926.ppm
# 26
# Images_Test\00927.ppm
# 27
# Images_Test\00928.ppm
# 28
# Images_Test\00929.ppm
# 29
# Images_Test\00930.ppm
# 30
# Images_Test\00931.ppm
# 31
# Images_Test\00932.ppm
# 32
# Images_Test\00933.ppm
# 33
# Images_Test\00934.ppm
# 34
# Images_Test\00935.ppm
# 35
# Images_Test\00936.ppm
# 36
# Images_Test\00937.ppm
# 37
# Images_Test\00938.ppm
# 38
# Images_Test\00939.ppm
# 39
# Images_Test\00940.ppm
# 40
# Images_Test\00941.ppm
# 41
# Images_Test\00942.ppm
# 42
# Images_Test\00943.ppm
# 43
# Images_Test\00944.ppm
# 44
# Images_Test\00945.ppm
# 45
# Images_Test\00946.ppm
# 46
# Images_Test\00947.ppm
# 47
# Images_Test\00948.ppm
# 48
# Images_Test\00949.ppm
# 49
# Images_Test\00950.ppm
# 50
# Images_Test\00951.ppm
# 51
# Images_Test\00952.ppm
# 52
# Images_Test\00953.ppm
# 53
# Images_Test\00954.ppm
# 54
# Images_Test\00955.ppm
# 55
# Images_Test\00956.ppm
# 56
# Images_Test\00957.ppm
# 57
# Images_Test\00958.ppm
# 58
# Images_Test\00959.ppm
# 59
# Images_Test\00960.ppm
# 60
# Images_Test\00961.ppm
# 61
# Images_Test\00962.ppm
# 62
# Images_Test\00963.ppm
# 63
# Images_Test\00964.ppm
# 64
# Images_Test\00965.ppm
# 65
# Images_Test\00966.ppm
# 66
# Images_Test\00967.ppm
# 67
# Images_Test\00968.ppm
# 68
# Images_Test\00969.ppm
# 69
# Images_Test\00970.ppm
# 70
# Images_Test\00971.ppm
# 71
# Images_Test\00972.ppm
# 72
# Images_Test\00973.ppm
# 73
# Images_Test\00974.ppm
# 74
# Images_Test\00975.ppm
# 75
# Images_Test\00976.ppm
# 76
# Images_Test\00977.ppm
# 77
# Images_Test\00978.ppm
# 78
# Images_Test\00979.ppm
# 79
# Images_Test\00980.ppm
# 80
# Images_Test\00981.ppm
# 81
# Images_Test\00982.ppm
# 82
# Images_Test\00983.ppm
# 83
# Images_Test\00984.ppm
# 84
# Images_Test\00985.ppm
# 85
# Images_Test\00986.ppm
# 86
# Images_Test\00987.ppm
# 87
# Images_Test\00988.ppm
# 88
# Images_Test\00989.ppm
# 89
# Images_Test\00990.ppm
# 90
# Images_Test\00991.ppm
# 91
# Images_Test\00992.ppm
# 92
# Images_Test\00993.ppm
# 93
# Images_Test\00994.ppm
# 94
# Images_Test\00995.ppm
# 95
# Images_Test\00996.ppm
# 96
# Images_Test\00997.ppm
# 97
# Images_Test\00998.ppm
# 98
# Images_Test\00999.ppm
# 99
# Images_Test\01000.ppm
# 0
# Images_Test\01001.ppm
# 1
# Images_Test\01002.ppm
# 2
# Images_Test\01003.ppm
# 3
# Images_Test\01004.ppm
# 4
# Images_Test\01005.ppm
# 5
# Images_Test\01006.ppm
# 6
# Images_Test\01007.ppm
# 7
# Images_Test\01008.ppm
# 8
# Images_Test\01009.ppm
# 9
# Images_Test\01010.ppm
# 10
# Images_Test\01011.ppm
# 11
# Images_Test\01012.ppm
# 12
# Images_Test\01013.ppm
# 13
# Images_Test\01014.ppm
# 14
# Images_Test\01015.ppm
# 15
# Images_Test\01016.ppm
# 16
# Images_Test\01017.ppm
# 17
# Images_Test\01018.ppm
# 18
# Images_Test\01019.ppm
# 19
# Images_Test\01020.ppm
# 20
# Images_Test\01021.ppm
# 21
# Images_Test\01022.ppm
# 22
# Images_Test\01023.ppm
# 23
# Images_Test\01024.ppm
# 24
# Images_Test\01025.ppm
# 25
# Images_Test\01026.ppm
# 26
# Images_Test\01027.ppm
# 27
# Images_Test\01028.ppm
# 28
# Images_Test\01029.ppm
# 29
# Images_Test\01030.ppm
# 30
# Images_Test\01031.ppm
# 31
# Images_Test\01032.ppm
# 32
# Images_Test\01033.ppm
# 33
# Images_Test\01034.ppm
# 34
# Images_Test\01035.ppm
# 35
# Images_Test\01036.ppm
# 36
# Images_Test\01037.ppm
# 37
# Images_Test\01038.ppm
# 38
# Images_Test\01039.ppm
# 39
# Images_Test\01040.ppm
# 40
# Images_Test\01041.ppm
# 41
# Images_Test\01042.ppm
# 42
# Images_Test\01043.ppm
# 43
# Images_Test\01044.ppm
# 44
# Images_Test\01045.ppm
# 45
# Images_Test\01046.ppm
# 46
# Images_Test\01047.ppm
# 47
# Images_Test\01048.ppm
# 48
# Images_Test\01049.ppm
# 49
# Images_Test\01050.ppm
# 50
# Images_Test\01051.ppm
# 51
# Images_Test\01052.ppm
# 52
# Images_Test\01053.ppm
# 53
# Images_Test\01054.ppm
# 54
# Images_Test\01055.ppm
# 55
# Images_Test\01056.ppm
# 56
# Images_Test\01057.ppm
# 57
# Images_Test\01058.ppm
# 58
# Images_Test\01059.ppm
# 59
# Images_Test\01060.ppm
# 60
# Images_Test\01061.ppm
# 61
# Images_Test\01062.ppm
# 62
# Images_Test\01063.ppm
# 63
# Images_Test\01064.ppm
# 64
# Images_Test\01065.ppm
# 65
# Images_Test\01066.ppm
# 66
# Images_Test\01067.ppm
# 67
# Images_Test\01068.ppm
# 68
# Images_Test\01069.ppm
# 69
# Images_Test\01070.ppm
# 70
# Images_Test\01071.ppm
# 71
# Images_Test\01072.ppm
# 72
# Images_Test\01073.ppm
# 73
# Images_Test\01074.ppm
# 74
# Images_Test\01075.ppm
# 75
# Images_Test\01076.ppm
# 76
# Images_Test\01077.ppm
# 77
# Images_Test\01078.ppm
# 78
# Images_Test\01079.ppm
# 79
# Images_Test\01080.ppm
# 80
# Images_Test\01081.ppm
# 81
# Images_Test\01082.ppm
# 82
# Images_Test\01083.ppm
# 83
# Images_Test\01084.ppm
# 84
# Images_Test\01085.ppm
# 85
# Images_Test\01086.ppm
# 86
# Images_Test\01087.ppm
# 87
# Images_Test\01088.ppm
# 88
# Images_Test\01089.ppm
# 89
# Images_Test\01090.ppm
# 90
# Images_Test\01091.ppm
# 91
# Images_Test\01092.ppm
# 92
# Images_Test\01093.ppm
# 93
# Images_Test\01094.ppm
# 94
# Images_Test\01095.ppm
# 95
# Images_Test\01096.ppm
# 96
# Images_Test\01097.ppm
# 97
# Images_Test\01098.ppm
# 98
# Images_Test\01099.ppm
# 99
# Images_Test\01100.ppm
# 0
# Images_Test\01101.ppm
# 1
# Images_Test\01102.ppm
# 2
# Images_Test\01103.ppm
# 3
# Images_Test\01104.ppm
# 4
# Images_Test\01105.ppm
# 5
# Images_Test\01106.ppm
# 6
# Images_Test\01107.ppm
# 7
# Images_Test\01108.ppm
# 8
# Images_Test\01109.ppm
# 9
# Images_Test\01110.ppm
# 10
# Images_Test\01111.ppm
# 11
# Images_Test\01112.ppm
# 12
# Images_Test\01113.ppm
# 13
# Images_Test\01114.ppm
# 14
# Images_Test\01115.ppm
# 15
# Images_Test\01116.ppm
# 16
# Images_Test\01117.ppm
# 17
# Images_Test\01118.ppm
# 18
# Images_Test\01119.ppm
# 19
# Images_Test\01120.ppm
# 20
# Images_Test\01121.ppm
# 21
# Images_Test\01122.ppm
# 22
# Images_Test\01123.ppm
# 23
# Images_Test\01124.ppm
# 24
# Images_Test\01125.ppm
# 25
# Images_Test\01126.ppm
# 26
# Images_Test\01127.ppm
# 27
# Images_Test\01128.ppm
# 28
# Images_Test\01129.ppm
# 29
# Images_Test\01130.ppm
# 30
# Images_Test\01131.ppm
# 31
# Images_Test\01132.ppm
# 32
# Images_Test\01133.ppm
# 33
# Images_Test\01134.ppm
# 34
# Images_Test\01135.ppm
# 35
# Images_Test\01136.ppm
# 36
# Images_Test\01137.ppm
# 37
# Images_Test\01138.ppm
# 38
# Images_Test\01139.ppm
# 39
# Images_Test\01140.ppm
# 40
# Images_Test\01141.ppm
# 41
# Images_Test\01142.ppm
# 42
# Images_Test\01143.ppm
# 43
# Images_Test\01144.ppm
# 44
# Images_Test\01145.ppm
# 45
# Images_Test\01146.ppm
# 46
# Images_Test\01147.ppm
# 47
# Images_Test\01148.ppm
# 48
# Images_Test\01149.ppm
# 49
# Images_Test\01150.ppm
# 50
# Images_Test\01151.ppm
# 51
# Images_Test\01152.ppm
# 52
# Images_Test\01153.ppm
# 53
# Images_Test\01154.ppm
# 54
# Images_Test\01155.ppm
# 55
# Images_Test\01156.ppm
# 56
# Images_Test\01157.ppm
# 57
# Images_Test\01158.ppm
# 58
# Images_Test\01159.ppm
# 59
# Images_Test\01160.ppm
# 60
# Images_Test\01161.ppm
# 61
# Images_Test\01162.ppm
# 62
# Images_Test\01163.ppm
# 63
# Images_Test\01164.ppm
# 64
# Images_Test\01165.ppm
# 65
# Images_Test\01166.ppm
# 66
# Images_Test\01167.ppm
# 67
# Images_Test\01168.ppm
# 68
# Images_Test\01169.ppm
# 69
# Images_Test\01170.ppm
# 70
# Images_Test\01171.ppm
# 71
# Images_Test\01172.ppm
# 72
# Images_Test\01173.ppm
# 73
# Images_Test\01174.ppm
# 74
# Images_Test\01175.ppm
# 75
# Images_Test\01176.ppm
# 76
# Images_Test\01177.ppm
# 77
# Images_Test\01178.ppm
# 78
# Images_Test\01179.ppm
# 79
# Images_Test\01180.ppm
# 80
# Images_Test\01181.ppm
# 81
# Images_Test\01182.ppm
# 82
# Images_Test\01183.ppm
# 83
# Images_Test\01184.ppm
# 84
# Images_Test\01185.ppm
# 85
# Images_Test\01186.ppm
# 86
# Images_Test\01187.ppm
# 87
# Images_Test\01188.ppm
# 88
# Images_Test\01189.ppm
# 89
# Images_Test\01190.ppm
# 90
# Images_Test\01191.ppm
# 91
# Images_Test\01192.ppm
# 92
# Images_Test\01193.ppm
# 93
# Images_Test\01194.ppm
# 94
# Images_Test\01195.ppm
# 95
# Images_Test\01196.ppm
# 96
# Images_Test\01197.ppm
# 97
# Images_Test\01198.ppm
# 98
# Images_Test\01199.ppm
# 99
# Images_Test\01200.ppm
# 0
# Images_Test\01201.ppm
# 1
# Images_Test\01202.ppm
# 2
# Images_Test\01203.ppm
# 3
# Images_Test\01204.ppm
# 4
# Images_Test\01205.ppm
# 5
# Images_Test\01206.ppm
# 6
# Images_Test\01207.ppm
# 7
# Images_Test\01208.ppm
# 8
# Images_Test\01209.ppm
# 9
# Images_Test\01210.ppm
# 10
# Images_Test\01211.ppm
# 11
# Images_Test\01212.ppm
# 12
# Images_Test\01213.ppm
# 13
# Images_Test\01214.ppm
# 14
# Images_Test\01215.ppm
# 15
# Images_Test\01216.ppm
# 16
# Images_Test\01217.ppm
# 17
# Images_Test\01218.ppm
# 18
# Images_Test\01219.ppm
# 19
# Images_Test\01220.ppm
# 20
# Images_Test\01221.ppm
# 21
# Images_Test\01222.ppm
# 22
# Images_Test\01223.ppm
# 23
# Images_Test\01224.ppm
# 24
# Images_Test\01225.ppm
# 25
# Images_Test\01226.ppm
# 26
# Images_Test\01227.ppm
# 27
# Images_Test\01228.ppm
# 28
# Images_Test\01229.ppm
# 29
# Images_Test\01230.ppm
# 30
# Images_Test\01231.ppm
# 31
# Images_Test\01232.ppm
# 32
# Images_Test\01233.ppm
# 33
# Images_Test\01234.ppm
# 34
# Images_Test\01235.ppm
# 35
# Images_Test\01236.ppm
# 36
# Images_Test\01237.ppm
# 37
# Images_Test\01238.ppm
# 38
# Images_Test\01239.ppm
# 39
# Images_Test\01240.ppm
# 40
# Images_Test\01241.ppm
# 41
# Images_Test\01242.ppm
# 42
# Images_Test\01243.ppm
# 43
# Images_Test\01244.ppm
# 44
# Images_Test\01245.ppm
# 45
# Images_Test\01246.ppm
# 46
# Images_Test\01247.ppm
# 47
# Images_Test\01248.ppm
# 48
# Images_Test\01249.ppm
# 49
# Images_Test\01250.ppm
# 50
# Images_Test\01251.ppm
# 51
# Images_Test\01252.ppm
# 52
# Images_Test\01253.ppm
# 53
# Images_Test\01254.ppm
# 54
# Images_Test\01255.ppm
# 55
# Images_Test\01256.ppm
# 56
# Images_Test\01257.ppm
# 57
# Images_Test\01258.ppm
# 58
# Images_Test\01259.ppm
# 59
# Images_Test\01260.ppm
# 60
# Images_Test\01261.ppm
# 61
# Images_Test\01262.ppm
# 62
# Images_Test\01263.ppm
# 63
# Images_Test\01264.ppm
# 64
# Images_Test\01265.ppm
# 65
# Images_Test\01266.ppm
# 66
# Images_Test\01267.ppm
# 67
# Images_Test\01268.ppm
# 68
# Images_Test\01269.ppm
# 69
# Images_Test\01270.ppm
# 70
# Images_Test\01271.ppm
# 71
# Images_Test\01272.ppm
# 72
# Images_Test\01273.ppm
# 73
# Images_Test\01274.ppm
# 74
# Images_Test\01275.ppm
# 75
# Images_Test\01276.ppm
# 76
# Images_Test\01277.ppm
# 77
# Images_Test\01278.ppm
# 78
# Images_Test\01279.ppm
# 79
# Images_Test\01280.ppm
# 80
# Images_Test\01281.ppm
# 81
# Images_Test\01282.ppm
# 82
# Images_Test\01283.ppm
# 83
# Images_Test\01284.ppm
# 84
# Images_Test\01285.ppm
# 85
# Images_Test\01286.ppm
# 86
# Images_Test\01287.ppm
# 87
# Images_Test\01288.ppm
# 88
# Images_Test\01289.ppm
# 89
# Images_Test\01290.ppm
# 90
# Images_Test\01291.ppm
# 91
# Images_Test\01292.ppm
# 92
# Images_Test\01293.ppm
# 93
# Images_Test\01294.ppm
# 94
# Images_Test\01295.ppm
# 95
# Images_Test\01296.ppm
# 96
# Images_Test\01297.ppm
# 97
# Images_Test\01298.ppm
# 98
# Images_Test\01299.ppm
# 99
# Images_Test\01300.ppm
# 0
# Images_Test\01301.ppm
# 1
# Images_Test\01302.ppm
# 2
# Images_Test\01303.ppm
# 3
# Images_Test\01304.ppm
# 4
# Images_Test\01305.ppm
# 5
# Images_Test\01306.ppm
# 6
# Images_Test\01307.ppm
# 7
# Images_Test\01308.ppm
# 8
# Images_Test\01309.ppm
# 9
# Images_Test\01310.ppm
# 10
# Images_Test\01311.ppm
# 11
# Images_Test\01312.ppm
# 12
# Images_Test\01313.ppm
# 13
# Images_Test\01314.ppm
# 14
# Images_Test\01315.ppm
# 15
# Images_Test\01316.ppm
# 16
# Images_Test\01317.ppm
# 17
# Images_Test\01318.ppm
# 18
# Images_Test\01319.ppm
# 19
# Images_Test\01320.ppm
# 20
# Images_Test\01321.ppm
# 21
# Images_Test\01322.ppm
# 22
# Images_Test\01323.ppm
# 23
# Images_Test\01324.ppm
# 24
# Images_Test\01325.ppm
# 25
# Images_Test\01326.ppm
# 26
# Images_Test\01327.ppm
# 27
# Images_Test\01328.ppm
# 28
# Images_Test\01329.ppm
# 29
# Images_Test\01330.ppm
# 30
# Images_Test\01331.ppm
# 31
# Images_Test\01332.ppm
# 32
# Images_Test\01333.ppm
# 33
# Images_Test\01334.ppm
# 34
# Images_Test\01335.ppm
# 35
# Images_Test\01336.ppm
# 36
# Images_Test\01337.ppm
# 37
# Images_Test\01338.ppm
# 38
# Images_Test\01339.ppm
# 39
# Images_Test\01340.ppm
# 40
# Images_Test\01341.ppm
# 41
# Images_Test\01342.ppm
# 42
# Images_Test\01343.ppm
# 43
# Images_Test\01344.ppm
# 44
# Images_Test\01345.ppm
# 45
# Images_Test\01346.ppm
# 46
# Images_Test\01347.ppm
# 47
# Images_Test\01348.ppm
# 48
# Images_Test\01349.ppm
# 49
# Images_Test\01350.ppm
# 50
# Images_Test\01351.ppm
# 51
# Images_Test\01352.ppm
# 52
# Images_Test\01353.ppm
# 53
# Images_Test\01354.ppm
# 54
# Images_Test\01355.ppm
# 55
# Images_Test\01356.ppm
# 56
# Images_Test\01357.ppm
# 57
# Images_Test\01358.ppm
# 58
# Images_Test\01359.ppm
# 59
# Images_Test\01360.ppm
# 60
# Images_Test\01361.ppm
# 61
# Images_Test\01362.ppm
# 62
# Images_Test\01363.ppm
# 63
# Images_Test\01364.ppm
# 64
# Images_Test\01365.ppm
# 65
# Images_Test\01366.ppm
# 66
# Images_Test\01367.ppm
# 67
# Images_Test\01368.ppm
# 68
# Images_Test\01369.ppm
# 69
# Images_Test\01370.ppm
# 70
# Images_Test\01371.ppm
# 71
# Images_Test\01372.ppm
# 72
# Images_Test\01373.ppm
# 73
# Images_Test\01374.ppm
# 74
# Images_Test\01375.ppm
# 75
# Images_Test\01376.ppm
# 76
# Images_Test\01377.ppm
# 77
# Images_Test\01378.ppm
# 78
# Images_Test\01379.ppm
# 79
# Images_Test\01380.ppm
# 80
# Images_Test\01381.ppm
# 81
# Images_Test\01382.ppm
# 82
# Images_Test\01383.ppm
# 83
# Images_Test\01384.ppm
# 84
# Images_Test\01385.ppm
# 85
# Images_Test\01386.ppm
# 86
# Images_Test\01387.ppm
# 87
# Images_Test\01388.ppm
# 88
# Images_Test\01389.ppm
# 89
# Images_Test\01390.ppm
# 90
# Images_Test\01391.ppm
# 91
# Images_Test\01392.ppm
# 92
# Images_Test\01393.ppm
# 93
# Images_Test\01394.ppm
# 94
# Images_Test\01395.ppm
# 95
# Images_Test\01396.ppm
# 96
# Images_Test\01397.ppm
# 97
# Images_Test\01398.ppm
# 98
# Images_Test\01399.ppm
# 99
# Images_Test\01400.ppm
# 0
# Images_Test\01401.ppm
# 1
# Images_Test\01402.ppm
# 2
# Images_Test\01403.ppm
# 3
# Images_Test\01404.ppm
# 4
# Images_Test\01405.ppm
# 5
# Images_Test\01406.ppm
# 6
# Images_Test\01407.ppm
# 7
# Images_Test\01408.ppm
# 8
# Images_Test\01409.ppm
# 9
# Images_Test\01410.ppm
# 10
# Images_Test\01411.ppm
# 11
# Images_Test\01412.ppm
# 12
# Images_Test\01413.ppm
# 13
# Images_Test\01414.ppm
# 14
# Images_Test\01415.ppm
# 15
# Images_Test\01416.ppm
# 16
# Images_Test\01417.ppm
# 17
# Images_Test\01418.ppm
# 18
# Images_Test\01419.ppm
# 19
# Images_Test\01420.ppm
# 20
# Images_Test\01421.ppm
# 21
# Images_Test\01422.ppm
# 22
# Images_Test\01423.ppm
# 23
# Images_Test\01424.ppm
# 24
# Images_Test\01425.ppm
# 25
# Images_Test\01426.ppm
# 26
# Images_Test\01427.ppm
# 27
# Images_Test\01428.ppm
# 28
# Images_Test\01429.ppm
# 29
# Images_Test\01430.ppm
# 30
# Images_Test\01431.ppm
# 31
# Images_Test\01432.ppm
# 32
# Images_Test\01433.ppm
# 33
# Images_Test\01434.ppm
# 34
# Images_Test\01435.ppm
# 35
# Images_Test\01436.ppm
# 36
# Images_Test\01437.ppm
# 37
# Images_Test\01438.ppm
# 38
# Images_Test\01439.ppm
# 39
# Images_Test\01440.ppm
# 40
# Images_Test\01441.ppm
# 41
# Images_Test\01442.ppm
# 42
# Images_Test\01443.ppm
# 43
# Images_Test\01444.ppm
# 44
# Images_Test\01445.ppm
# 45
# Images_Test\01446.ppm
# 46
# Images_Test\01447.ppm
# 47
# Images_Test\01448.ppm
# 48
# Images_Test\01449.ppm
# 49
# Images_Test\01450.ppm
# 50
# Images_Test\01451.ppm
# 51
# Images_Test\01452.ppm
# 52
# Images_Test\01453.ppm
# 53
# Images_Test\01454.ppm
# 54
# Images_Test\01455.ppm
# 55
# Images_Test\01456.ppm
# 56
# Images_Test\01457.ppm
# 57
# Images_Test\01458.ppm
# 58
# Images_Test\01459.ppm
# 59
# Images_Test\01460.ppm
# 60
# Images_Test\01461.ppm
# 61
# Images_Test\01462.ppm
# 62
# Images_Test\01463.ppm
# 63
# Images_Test\01464.ppm
# 64
# Images_Test\01465.ppm
# 65
# Images_Test\01466.ppm
# 66
# Images_Test\01467.ppm
# 67
# Images_Test\01468.ppm
# 68
# Images_Test\01469.ppm
# 69
# Images_Test\01470.ppm
# 70
# Images_Test\01471.ppm
# 71
# Images_Test\01472.ppm
# 72
# Images_Test\01473.ppm
# 73
# Images_Test\01474.ppm
# 74
# Images_Test\01475.ppm
# 75
# Images_Test\01476.ppm
# 76
# Images_Test\01477.ppm
# 77
# Images_Test\01478.ppm
# 78
# Images_Test\01479.ppm
# 79
# Images_Test\01480.ppm
# 80
# Images_Test\01481.ppm
# 81
# Images_Test\01482.ppm
# 82
# Images_Test\01483.ppm
# 83
# Images_Test\01484.ppm
# 84
# Images_Test\01485.ppm
# 85
# Images_Test\01486.ppm
# 86
# Images_Test\01487.ppm
# 87
# Images_Test\01488.ppm
# 88
# Images_Test\01489.ppm
# 89
# Images_Test\01490.ppm
# 90
# Images_Test\01491.ppm
# 91
# Images_Test\01492.ppm
# 92
# Images_Test\01493.ppm
# 93
# Images_Test\01494.ppm
# 94
# Images_Test\01495.ppm
# 95
# Images_Test\01496.ppm
# 96
# Images_Test\01497.ppm
# 97
# Images_Test\01498.ppm
# 98
# Images_Test\01499.ppm
# 99
# Images_Test\01500.ppm
# 0
# Images_Test\01501.ppm
# 1
# Images_Test\01502.ppm
# 2
# Images_Test\01503.ppm
# 3
# Images_Test\01504.ppm
# 4
# Images_Test\01505.ppm
# 5
# Images_Test\01506.ppm
# 6
# Images_Test\01507.ppm
# 7
# Images_Test\01508.ppm
# 8
# Images_Test\01509.ppm
# 9
# Images_Test\01510.ppm
# 10
# Images_Test\01511.ppm
# 11
# Images_Test\01512.ppm
# 12
# Images_Test\01513.ppm
# 13
# Images_Test\01514.ppm
# 14
# Images_Test\01515.ppm
# 15
# Images_Test\01516.ppm
# 16
# Images_Test\01517.ppm
# 17
# Images_Test\01518.ppm
# 18
# Images_Test\01519.ppm
# 19
# Images_Test\01520.ppm
# 20
# Images_Test\01521.ppm
# 21
# Images_Test\01522.ppm
# 22
# Images_Test\01523.ppm
# 23
# Images_Test\01524.ppm
# 24
# Images_Test\01525.ppm
# 25
# Images_Test\01526.ppm
# 26
# Images_Test\01527.ppm
# 27
# Images_Test\01528.ppm
# 28
# Images_Test\01529.ppm
# 29
# Images_Test\01530.ppm
# 30
# Images_Test\01531.ppm
# 31
# Images_Test\01532.ppm
# 32
# Images_Test\01533.ppm
# 33
# Images_Test\01534.ppm
# 34
# Images_Test\01535.ppm
# 35
# Images_Test\01536.ppm
# 36
# Images_Test\01537.ppm
# 37
# Images_Test\01538.ppm
# 38
# Images_Test\01539.ppm
# 39
# Images_Test\01540.ppm
# 40
# Images_Test\01541.ppm
# 41
# Images_Test\01542.ppm
# 42
# Images_Test\01543.ppm
# 43
# Images_Test\01544.ppm
# 44
# Images_Test\01545.ppm
# 45
# Images_Test\01546.ppm
# 46
# Images_Test\01547.ppm
# 47
# Images_Test\01548.ppm
# 48
# Images_Test\01549.ppm
# 49
# Images_Test\01550.ppm
# 50
# Images_Test\01551.ppm
# 51
# Images_Test\01552.ppm
# 52
# Images_Test\01553.ppm
# 53
# Images_Test\01554.ppm
# 54
# Images_Test\01555.ppm
# 55
# Images_Test\01556.ppm
# 56
# Images_Test\01557.ppm
# 57
# Images_Test\01558.ppm
# 58
# Images_Test\01559.ppm
# 59
# Images_Test\01560.ppm
# 60
# Images_Test\01561.ppm
# 61
# Images_Test\01562.ppm
# 62
# Images_Test\01563.ppm
# 63
# Images_Test\01564.ppm
# 64
# Images_Test\01565.ppm
# 65
# Images_Test\01566.ppm
# 66
# Images_Test\01567.ppm
# 67
# Images_Test\01568.ppm
# 68
# Images_Test\01569.ppm
# 69
# Images_Test\01570.ppm
# 70
# Images_Test\01571.ppm
# 71
# Images_Test\01572.ppm
# 72
# Images_Test\01573.ppm
# 73
# Images_Test\01574.ppm
# 74
# Images_Test\01575.ppm
# 75
# Images_Test\01576.ppm
# 76
# Images_Test\01577.ppm
# 77
# Images_Test\01578.ppm
# 78
# Images_Test\01579.ppm
# 79
# Images_Test\01580.ppm
# 80
# Images_Test\01581.ppm
# 81
# Images_Test\01582.ppm
# 82
# Images_Test\01583.ppm
# 83
# Images_Test\01584.ppm
# 84
# Images_Test\01585.ppm
# 85
# Images_Test\01586.ppm
# 86
# Images_Test\01587.ppm
# 87
# Images_Test\01588.ppm
# 88
# Images_Test\01589.ppm
# 89
# Images_Test\01590.ppm
# 90
# Images_Test\01591.ppm
# 91
# Images_Test\01592.ppm
# 92
# Images_Test\01593.ppm
# 93
# Images_Test\01594.ppm
# 94
# Images_Test\01595.ppm
# 95
# Images_Test\01596.ppm
# 96
# Images_Test\01597.ppm
# 97
# Images_Test\01598.ppm
# 98
# Images_Test\01599.ppm
# 99
# Images_Test\01600.ppm
# 0
# Images_Test\01601.ppm
# 1
# Images_Test\01602.ppm
# 2
# Images_Test\01603.ppm
# 3
# Images_Test\01604.ppm
# 4
# Images_Test\01605.ppm
# 5
# Images_Test\01606.ppm
# 6
# Images_Test\01607.ppm
# 7
# Images_Test\01608.ppm
# 8
# Images_Test\01609.ppm
# 9
# Images_Test\01610.ppm
# 10
# Images_Test\01611.ppm
# 11
# Images_Test\01612.ppm
# 12
# Images_Test\01613.ppm
# 13
# Images_Test\01614.ppm
# 14
# Images_Test\01615.ppm
# 15
# Images_Test\01616.ppm
# 16
# Images_Test\01617.ppm
# 17
# Images_Test\01618.ppm
# 18
# Images_Test\01619.ppm
# 19
# Images_Test\01620.ppm
# 20
# Images_Test\01621.ppm
# 21
# Images_Test\01622.ppm
# 22
# Images_Test\01623.ppm
# 23
# Images_Test\01624.ppm
# 24
# Images_Test\01625.ppm
# 25
# Images_Test\01626.ppm
# 26
# Images_Test\01627.ppm
# 27
# Images_Test\01628.ppm
# 28
# Images_Test\01629.ppm
# 29
# Images_Test\01630.ppm
# 30
# Images_Test\01631.ppm
# 31
# Images_Test\01632.ppm
# 32
# Images_Test\01633.ppm
# 33
# Images_Test\01634.ppm
# 34
# Images_Test\01635.ppm
# 35
# Images_Test\01636.ppm
# 36
# Images_Test\01637.ppm
# 37
# Images_Test\01638.ppm
# 38
# Images_Test\01639.ppm
# 39
# Images_Test\01640.ppm
# 40
# Images_Test\01641.ppm
# 41
# Images_Test\01642.ppm
# 42
# Images_Test\01643.ppm
# 43
# Images_Test\01644.ppm
# 44
# Images_Test\01645.ppm
# 45
# Images_Test\01646.ppm
# 46
# Images_Test\01647.ppm
# 47
# Images_Test\01648.ppm
# 48
# Images_Test\01649.ppm
# 49
# Images_Test\01650.ppm
# 50
# Images_Test\01651.ppm
# 51
# Images_Test\01652.ppm
# 52
# Images_Test\01653.ppm
# 53
# Images_Test\01654.ppm
# 54
# Images_Test\01655.ppm
# 55
# Images_Test\01656.ppm
# 56
# Images_Test\01657.ppm
# 57
# Images_Test\01658.ppm
# 58
# Images_Test\01659.ppm
# 59
# Images_Test\01660.ppm
# 60
# Images_Test\01661.ppm
# 61
# Images_Test\01662.ppm
# 62
# Images_Test\01663.ppm
# 63
# Images_Test\01664.ppm
# 64
# Images_Test\01665.ppm
# 65
# Images_Test\01666.ppm
# 66
# Images_Test\01667.ppm
# 67
# Images_Test\01668.ppm
# 68
# Images_Test\01669.ppm
# 69
# Images_Test\01670.ppm
# 70
# Images_Test\01671.ppm
# 71
# Images_Test\01672.ppm
# 72
# Images_Test\01673.ppm
# 73
# Images_Test\01674.ppm
# 74
# Images_Test\01675.ppm
# 75
# Images_Test\01676.ppm
# 76
# Images_Test\01677.ppm
# 77
# Images_Test\01678.ppm
# 78
# Images_Test\01679.ppm
# 79
# Images_Test\01680.ppm
# 80
# Images_Test\01681.ppm
# 81
# Images_Test\01682.ppm
# 82
# Images_Test\01683.ppm
# 83
# Images_Test\01684.ppm
# 84
# Images_Test\01685.ppm
# 85
# Images_Test\01686.ppm
# 86
# Images_Test\01687.ppm
# 87
# Images_Test\01688.ppm
# 88
# Images_Test\01689.ppm
# 89
# Images_Test\01690.ppm
# 90
# Images_Test\01691.ppm
# 91
# Images_Test\01692.ppm
# 92
# Images_Test\01693.ppm
# 93
# Images_Test\01694.ppm
# 94
# Images_Test\01695.ppm
# 95
# Images_Test\01696.ppm
# 96
# Images_Test\01697.ppm
# 97
# Images_Test\01698.ppm
# 98
# Images_Test\01699.ppm
# 99
# Images_Test\01700.ppm
# 0
# Images_Test\01701.ppm
# 1
# Images_Test\01702.ppm
# 2
# Images_Test\01703.ppm
# 3
# Images_Test\01704.ppm
# 4
# Images_Test\01705.ppm
# 5
# Images_Test\01706.ppm
# 6
# Images_Test\01707.ppm
# 7
# Images_Test\01708.ppm
# 8
# Images_Test\01709.ppm
# 9
# Images_Test\01710.ppm
# 10
# Images_Test\01711.ppm
# 11
# Images_Test\01712.ppm
# 12
# Images_Test\01713.ppm
# 13
# Images_Test\01714.ppm
# 14
# Images_Test\01715.ppm
# 15
# Images_Test\01716.ppm
# 16
# Images_Test\01717.ppm
# 17
# Images_Test\01718.ppm
# 18
# Images_Test\01719.ppm
# 19
# Images_Test\01720.ppm
# 20
# Images_Test\01721.ppm
# 21
# Images_Test\01722.ppm
# 22
# Images_Test\01723.ppm
# 23
# Images_Test\01724.ppm
# 24
# Images_Test\01725.ppm
# 25
# Images_Test\01726.ppm
# 26
# Images_Test\01727.ppm
# 27
# Images_Test\01728.ppm
# 28
# Images_Test\01729.ppm
# 29
# Images_Test\01730.ppm
# 30
# Images_Test\01731.ppm
# 31
# Images_Test\01732.ppm
# 32
# Images_Test\01733.ppm
# 33
# Images_Test\01734.ppm
# 34
# Images_Test\01735.ppm
# 35
# Images_Test\01736.ppm
# 36
# Images_Test\01737.ppm
# 37
# Images_Test\01738.ppm
# 38
# Images_Test\01739.ppm
# 39
# Images_Test\01740.ppm
# 40
# Images_Test\01741.ppm
# 41
# Images_Test\01742.ppm
# 42
# Images_Test\01743.ppm
# 43
# Images_Test\01744.ppm
# 44
# Images_Test\01745.ppm
# 45
# Images_Test\01746.ppm
# 46
# Images_Test\01747.ppm
# 47
# Images_Test\01748.ppm
# 48
# Images_Test\01749.ppm
# 49
# Images_Test\01750.ppm
# 50
# Images_Test\01751.ppm
# 51
# Images_Test\01752.ppm
# 52
# Images_Test\01753.ppm
# 53
# Images_Test\01754.ppm
# 54
# Images_Test\01755.ppm
# 55
# Images_Test\01756.ppm
# 56
# Images_Test\01757.ppm
# 57
# Images_Test\01758.ppm
# 58
# Images_Test\01759.ppm
# 59
# Images_Test\01760.ppm
# 60
# Images_Test\01761.ppm
# 61
# Images_Test\01762.ppm
# 62
# Images_Test\01763.ppm
# 63
# Images_Test\01764.ppm
# 64
# Images_Test\01765.ppm
# 65
# Images_Test\01766.ppm
# 66
# Images_Test\01767.ppm
# 67
# Images_Test\01768.ppm
# 68
# Images_Test\01769.ppm
# 69
# Images_Test\01770.ppm
# 70
# Images_Test\01771.ppm
# 71
# Images_Test\01772.ppm
# 72
# Images_Test\01773.ppm
# 73
# Images_Test\01774.ppm
# 74
# Images_Test\01775.ppm
# 75
# Images_Test\01776.ppm
# 76
# Images_Test\01777.ppm
# 77
# Images_Test\01778.ppm
# 78
# Images_Test\01779.ppm
# 79
# Images_Test\01780.ppm
# 80
# Images_Test\01781.ppm
# 81
# Images_Test\01782.ppm
# 82
# Images_Test\01783.ppm
# 83
# Images_Test\01784.ppm
# 84
# Images_Test\01785.ppm
# 85
# Images_Test\01786.ppm
# 86
# Images_Test\01787.ppm
# 87
# Images_Test\01788.ppm
# 88
# Images_Test\01789.ppm
# 89
# Images_Test\01790.ppm
# 90
# Images_Test\01791.ppm
# 91
# Images_Test\01792.ppm
# 92
# Images_Test\01793.ppm
# 93
# Images_Test\01794.ppm
# 94
# Images_Test\01795.ppm
# 95
# Images_Test\01796.ppm
# 96
# Images_Test\01797.ppm
# 97
# Images_Test\01798.ppm
# 98
# Images_Test\01799.ppm
# 99
# Images_Test\01800.ppm
# 0
# Images_Test\01801.ppm
# 1
# Images_Test\01802.ppm
# 2
# Images_Test\01803.ppm
# 3
# Images_Test\01804.ppm
# 4
# Images_Test\01805.ppm
# 5
# Images_Test\01806.ppm
# 6
# Images_Test\01807.ppm
# 7
# Images_Test\01808.ppm
# 8
# Images_Test\01809.ppm
# 9
# Images_Test\01810.ppm
# 10
# Images_Test\01811.ppm
# 11
# Images_Test\01812.ppm
# 12
# Images_Test\01813.ppm
# 13
# Images_Test\01814.ppm
# 14
# Images_Test\01815.ppm
# 15
# Images_Test\01816.ppm
# 16
# Images_Test\01817.ppm
# 17
# Images_Test\01818.ppm
# 18
# Images_Test\01819.ppm
# 19
# Images_Test\01820.ppm
# 20
# Images_Test\01821.ppm
# 21
# Images_Test\01822.ppm
# 22
# Images_Test\01823.ppm
# 23
# Images_Test\01824.ppm
# 24
# Images_Test\01825.ppm
# 25
# Images_Test\01826.ppm
# 26
# Images_Test\01827.ppm
# 27
# Images_Test\01828.ppm
# 28
# Images_Test\01829.ppm
# 29
# Images_Test\01830.ppm
# 30
# Images_Test\01831.ppm
# 31
# Images_Test\01832.ppm
# 32
# Images_Test\01833.ppm
# 33
# Images_Test\01834.ppm
# 34
# Images_Test\01835.ppm
# 35
# Images_Test\01836.ppm
# 36
# Images_Test\01837.ppm
# 37
# Images_Test\01838.ppm
# 38
# Images_Test\01839.ppm
# 39
# Images_Test\01840.ppm
# 40
# Images_Test\01841.ppm
# 41
# Images_Test\01842.ppm
# 42
# Images_Test\01843.ppm
# 43
# Images_Test\01844.ppm
# 44
# Images_Test\01845.ppm
# 45
# Images_Test\01846.ppm
# 46
# Images_Test\01847.ppm
# 47
# Images_Test\01848.ppm
# 48
# Images_Test\01849.ppm
# 49
# Images_Test\01850.ppm
# 50
# Images_Test\01851.ppm
# 51
# Images_Test\01852.ppm
# 52
# Images_Test\01853.ppm
# 53
# Images_Test\01854.ppm
# 54
# Images_Test\01855.ppm
# 55
# Images_Test\01856.ppm
# 56
# Images_Test\01857.ppm
# 57
# Images_Test\01858.ppm
# 58
# Images_Test\01859.ppm
# 59
# Images_Test\01860.ppm
# 60
# Images_Test\01861.ppm
# 61
# Images_Test\01862.ppm
# 62
# Images_Test\01863.ppm
# 63
# Images_Test\01864.ppm
# 64
# Images_Test\01865.ppm
# 65
# Images_Test\01866.ppm
# 66
# Images_Test\01867.ppm
# 67
# Images_Test\01868.ppm
# 68
# Images_Test\01869.ppm
# 69
# Images_Test\01870.ppm
# 70
# Images_Test\01871.ppm
# 71
# Images_Test\01872.ppm
# 72
# Images_Test\01873.ppm
# 73
# Images_Test\01874.ppm
# 74
# Images_Test\01875.ppm
# 75
# Images_Test\01876.ppm
# 76
# Images_Test\01877.ppm
# 77
# Images_Test\01878.ppm
# 78
# Images_Test\01879.ppm
# 79
# Images_Test\01880.ppm
# 80
# Images_Test\01881.ppm
# 81
# Images_Test\01882.ppm
# 82
# Images_Test\01883.ppm
# 83
# Images_Test\01884.ppm
# 84
# Images_Test\01885.ppm
# 85
# Images_Test\01886.ppm
# 86
# Images_Test\01887.ppm
# 87
# Images_Test\01888.ppm
# 88
# Images_Test\01889.ppm
# 89
# Images_Test\01890.ppm
# 90
# Images_Test\01891.ppm
# 91
# Images_Test\01892.ppm
# 92
# Images_Test\01893.ppm
# 93
# Images_Test\01894.ppm
# 94
# Images_Test\01895.ppm
# 95
# Images_Test\01896.ppm
# 96
# Images_Test\01897.ppm
# 97
# Images_Test\01898.ppm
# 98
# Images_Test\01899.ppm
# 99
# Images_Test\01900.ppm
# 0
# Images_Test\01901.ppm
# 1
# Images_Test\01902.ppm
# 2
# Images_Test\01903.ppm
# 3
# Images_Test\01904.ppm
# 4
# Images_Test\01905.ppm
# 5
# Images_Test\01906.ppm
# 6
# Images_Test\01907.ppm
# 7
# Images_Test\01908.ppm
# 8
# Images_Test\01909.ppm
# 9
# Images_Test\01910.ppm
# 10
# Images_Test\01911.ppm
# 11
# Images_Test\01912.ppm
# 12
# Images_Test\01913.ppm
# 13
# Images_Test\01914.ppm
# 14
# Images_Test\01915.ppm
# 15
# Images_Test\01916.ppm
# 16
# Images_Test\01917.ppm
# 17
# Images_Test\01918.ppm
# 18
# Images_Test\01919.ppm
# 19
# Images_Test\01920.ppm
# 20
# Images_Test\01921.ppm
# 21
# Images_Test\01922.ppm
# 22
# Images_Test\01923.ppm
# 23
# Images_Test\01924.ppm
# 24
# Images_Test\01925.ppm
# 25
# Images_Test\01926.ppm
# 26
# ...
# 87
# Images_Test\11988.ppm
# 88
# Images_Test\11989.ppm
# 89
# Images_Test\11990.ppm
# 90
# Images_Test\11991.ppm
# 91
# Images_Test\11992.ppm
# 92
# Images_Test\11993.ppm
# 93
# Images_Test\11994.ppm
# 94
# Images_Test\11995.ppm
# 95
# Images_Test\11996.ppm
# 96
# Images_Test\11997.ppm
# 97
# Images_Test\11998.ppm
# 98
# Images_Test\11999.ppm
# 99
# Images_Test\12000.ppm
# 0
# Images_Test\12001.ppm
# 1
# Images_Test\12002.ppm
# 2
# Images_Test\12003.ppm
# 3
# Images_Test\12004.ppm
# 4
# Images_Test\12005.ppm
# 5
# Images_Test\12006.ppm
# 6
# Images_Test\12007.ppm
# 7
# Images_Test\12008.ppm
# 8
# Images_Test\12009.ppm
# 9
# Images_Test\12010.ppm
# 10
# Images_Test\12011.ppm
# 11
# Images_Test\12012.ppm
# 12
# Images_Test\12013.ppm
# 13
# Images_Test\12014.ppm
# 14
# Images_Test\12015.ppm
# 15
# Images_Test\12016.ppm
# 16
# Images_Test\12017.ppm
# 17
# Images_Test\12018.ppm
# 18
# Images_Test\12019.ppm
# 19
# Images_Test\12020.ppm
# 20
# Images_Test\12021.ppm
# 21
# Images_Test\12022.ppm
# 22
# Images_Test\12023.ppm
# 23
# Images_Test\12024.ppm
# 24
# Images_Test\12025.ppm
# 25
# Images_Test\12026.ppm
# 26
# Images_Test\12027.ppm
# 27
# Images_Test\12028.ppm
# 28
# Images_Test\12029.ppm
# 29
# Images_Test\12030.ppm
# 30
# Images_Test\12031.ppm
# 31
# Images_Test\12032.ppm
# 32
# Images_Test\12033.ppm
# 33
# Images_Test\12034.ppm
# 34
# Images_Test\12035.ppm
# 35
# Images_Test\12036.ppm
# 36
# Images_Test\12037.ppm
# 37
# Images_Test\12038.ppm
# 38
# Images_Test\12039.ppm
# 39
# Images_Test\12040.ppm
# 40
# Images_Test\12041.ppm
# 41
# Images_Test\12042.ppm
# 42
# Images_Test\12043.ppm
# 43
# Images_Test\12044.ppm
# 44
# Images_Test\12045.ppm
# 45
# Images_Test\12046.ppm
# 46
# Images_Test\12047.ppm
# 47
# Images_Test\12048.ppm
# 48
# Images_Test\12049.ppm
# 49
# Images_Test\12050.ppm
# 50
# Images_Test\12051.ppm
# 51
# Images_Test\12052.ppm
# 52
# Images_Test\12053.ppm
# 53
# Images_Test\12054.ppm
# 54
# Images_Test\12055.ppm
# 55
# Images_Test\12056.ppm
# 56
# Images_Test\12057.ppm
# 57
# Images_Test\12058.ppm
# 58
# Images_Test\12059.ppm
# 59
# Images_Test\12060.ppm
# 60
# Images_Test\12061.ppm
# 61
# Images_Test\12062.ppm
# 62
# Images_Test\12063.ppm
# 63
# Images_Test\12064.ppm
# 64
# Images_Test\12065.ppm
# 65
# Images_Test\12066.ppm
# 66
# Images_Test\12067.ppm
# 67
# Images_Test\12068.ppm
# 68
# Images_Test\12069.ppm
# 69
# Images_Test\12070.ppm
# 70
# Images_Test\12071.ppm
# 71
# Images_Test\12072.ppm
# 72
# Images_Test\12073.ppm
# 73
# Images_Test\12074.ppm
# 74
# Images_Test\12075.ppm
# 75
# Images_Test\12076.ppm
# 76
# Images_Test\12077.ppm
# 77
# Images_Test\12078.ppm
# 78
# Images_Test\12079.ppm
# 79
# Images_Test\12080.ppm
# 80
# Images_Test\12081.ppm
# 81
# Images_Test\12082.ppm
# 82
# Images_Test\12083.ppm
# 83
# Images_Test\12084.ppm
# 84
# Images_Test\12085.ppm
# 85
# Images_Test\12086.ppm
# 86
# Images_Test\12087.ppm
# 87
# Images_Test\12088.ppm
# 88
# Images_Test\12089.ppm
# 89
# Images_Test\12090.ppm
# 90
# Images_Test\12091.ppm
# 91
# Images_Test\12092.ppm
# 92
# Images_Test\12093.ppm
# 93
# Images_Test\12094.ppm
# 94
# Images_Test\12095.ppm
# 95
# Images_Test\12096.ppm
# 96
# Images_Test\12097.ppm
# 97
# Images_Test\12098.ppm
# 98
# Images_Test\12099.ppm
# 99
# Images_Test\12100.ppm
# 0
# Images_Test\12101.ppm
# 1
# Images_Test\12102.ppm
# 2
# Images_Test\12103.ppm
# 3
# Images_Test\12104.ppm
# 4
# Images_Test\12105.ppm
# 5
# Images_Test\12106.ppm
# 6
# Images_Test\12107.ppm
# 7
# Images_Test\12108.ppm
# 8
# Images_Test\12109.ppm
# 9
# Images_Test\12110.ppm
# 10
# Images_Test\12111.ppm
# 11
# Images_Test\12112.ppm
# 12
# Images_Test\12113.ppm
# 13
# Images_Test\12114.ppm
# 14
# Images_Test\12115.ppm
# 15
# Images_Test\12116.ppm
# 16
# Images_Test\12117.ppm
# 17
# Images_Test\12118.ppm
# 18
# Images_Test\12119.ppm
# 19
# Images_Test\12120.ppm
# 20
# Images_Test\12121.ppm
# 21
# Images_Test\12122.ppm
# 22
# Images_Test\12123.ppm
# 23
# Images_Test\12124.ppm
# 24
# Images_Test\12125.ppm
# 25
# Images_Test\12126.ppm
# 26
# Images_Test\12127.ppm
# 27
# Images_Test\12128.ppm
# 28
# Images_Test\12129.ppm
# 29
# Images_Test\12130.ppm
# 30
# Images_Test\12131.ppm
# 31
# Images_Test\12132.ppm
# 32
# Images_Test\12133.ppm
# 33
# Images_Test\12134.ppm
# 34
# Images_Test\12135.ppm
# 35
# Images_Test\12136.ppm
# 36
# Images_Test\12137.ppm
# 37
# Images_Test\12138.ppm
# 38
# Images_Test\12139.ppm
# 39
# Images_Test\12140.ppm
# 40
# Images_Test\12141.ppm
# 41
# Images_Test\12142.ppm
# 42
# Images_Test\12143.ppm
# 43
# Images_Test\12144.ppm
# 44
# Images_Test\12145.ppm
# 45
# Images_Test\12146.ppm
# 46
# Images_Test\12147.ppm
# 47
# Images_Test\12148.ppm
# 48
# Images_Test\12149.ppm
# 49
# Images_Test\12150.ppm
# 50
# Images_Test\12151.ppm
# 51
# Images_Test\12152.ppm
# 52
# Images_Test\12153.ppm
# 53
# Images_Test\12154.ppm
# 54
# Images_Test\12155.ppm
# 55
# Images_Test\12156.ppm
# 56
# Images_Test\12157.ppm
# 57
# Images_Test\12158.ppm
# 58
# Images_Test\12159.ppm
# 59
# Images_Test\12160.ppm
# 60
# Images_Test\12161.ppm
# 61
# Images_Test\12162.ppm
# 62
# Images_Test\12163.ppm
# 63
# Images_Test\12164.ppm
# 64
# Images_Test\12165.ppm
# 65
# Images_Test\12166.ppm
# 66
# Images_Test\12167.ppm
# 67
# Images_Test\12168.ppm
# 68
# Images_Test\12169.ppm
# 69
# Images_Test\12170.ppm
# 70
# Images_Test\12171.ppm
# 71
# Images_Test\12172.ppm
# 72
# Images_Test\12173.ppm
# 73
# Images_Test\12174.ppm
# 74
# Images_Test\12175.ppm
# 75
# Images_Test\12176.ppm
# 76
# Images_Test\12177.ppm
# 77
# Images_Test\12178.ppm
# 78
# Images_Test\12179.ppm
# 79
# Images_Test\12180.ppm
# 80
# Images_Test\12181.ppm
# 81
# Images_Test\12182.ppm
# 82
# Images_Test\12183.ppm
# 83
# Images_Test\12184.ppm
# 84
# Images_Test\12185.ppm
# 85
# Images_Test\12186.ppm
# 86
# Images_Test\12187.ppm
# 87
# Images_Test\12188.ppm
# 88
# Images_Test\12189.ppm
# 89
# Images_Test\12190.ppm
# 90
# Images_Test\12191.ppm
# 91
# Images_Test\12192.ppm
# 92
# Images_Test\12193.ppm
# 93
# Images_Test\12194.ppm
# 94
# Images_Test\12195.ppm
# 95
# Images_Test\12196.ppm
# 96
# Images_Test\12197.ppm
# 97
# Images_Test\12198.ppm
# 98
# Images_Test\12199.ppm
# 99
# Images_Test\12200.ppm
# 0
# Images_Test\12201.ppm
# 1
# Images_Test\12202.ppm
# 2
# Images_Test\12203.ppm
# 3
# Images_Test\12204.ppm
# 4
# Images_Test\12205.ppm
# 5
# Images_Test\12206.ppm
# 6
# Images_Test\12207.ppm
# 7
# Images_Test\12208.ppm
# 8
# Images_Test\12209.ppm
# 9
# Images_Test\12210.ppm
# 10
# Images_Test\12211.ppm
# 11
# Images_Test\12212.ppm
# 12
# Images_Test\12213.ppm
# 13
# Images_Test\12214.ppm
# 14
# Images_Test\12215.ppm
# 15
# Images_Test\12216.ppm
# 16
# Images_Test\12217.ppm
# 17
# Images_Test\12218.ppm
# 18
# Images_Test\12219.ppm
# 19
# Images_Test\12220.ppm
# 20
# Images_Test\12221.ppm
# 21
# Images_Test\12222.ppm
# 22
# Images_Test\12223.ppm
# 23
# Images_Test\12224.ppm
# 24
# Images_Test\12225.ppm
# 25
# Images_Test\12226.ppm
# 26
# Images_Test\12227.ppm
# 27
# Images_Test\12228.ppm
# 28
# Images_Test\12229.ppm
# 29
# Images_Test\12230.ppm
# 30
# Images_Test\12231.ppm
# 31
# Images_Test\12232.ppm
# 32
# Images_Test\12233.ppm
# 33
# Images_Test\12234.ppm
# 34
# Images_Test\12235.ppm
# 35
# Images_Test\12236.ppm
# 36
# Images_Test\12237.ppm
# 37
# Images_Test\12238.ppm
# 38
# Images_Test\12239.ppm
# 39
# Images_Test\12240.ppm
# 40
# Images_Test\12241.ppm
# 41
# Images_Test\12242.ppm
# 42
# Images_Test\12243.ppm
# 43
# Images_Test\12244.ppm
# 44
# Images_Test\12245.ppm
# 45
# Images_Test\12246.ppm
# 46
# Images_Test\12247.ppm
# 47
# Images_Test\12248.ppm
# 48
# Images_Test\12249.ppm
# 49
# Images_Test\12250.ppm
# 50
# Images_Test\12251.ppm
# 51
# Images_Test\12252.ppm
# 52
# Images_Test\12253.ppm
# 53
# Images_Test\12254.ppm
# 54
# Images_Test\12255.ppm
# 55
# Images_Test\12256.ppm
# 56
# Images_Test\12257.ppm
# 57
# Images_Test\12258.ppm
# 58
# Images_Test\12259.ppm
# 59
# Images_Test\12260.ppm
# 60
# Images_Test\12261.ppm
# 61
# Images_Test\12262.ppm
# 62
# Images_Test\12263.ppm
# 63
# Images_Test\12264.ppm
# 64
# Images_Test\12265.ppm
# 65
# Images_Test\12266.ppm
# 66
# Images_Test\12267.ppm
# 67
# Images_Test\12268.ppm
# 68
# Images_Test\12269.ppm
# 69
# Images_Test\12270.ppm
# 70
# Images_Test\12271.ppm
# 71
# Images_Test\12272.ppm
# 72
# Images_Test\12273.ppm
# 73
# Images_Test\12274.ppm
# 74
# Images_Test\12275.ppm
# 75
# Images_Test\12276.ppm
# 76
# Images_Test\12277.ppm
# 77
# Images_Test\12278.ppm
# 78
# Images_Test\12279.ppm
# 79
# Images_Test\12280.ppm
# 80
# Images_Test\12281.ppm
# 81
# Images_Test\12282.ppm
# 82
# Images_Test\12283.ppm
# 83
# Images_Test\12284.ppm
# 84
# Images_Test\12285.ppm
# 85
# Images_Test\12286.ppm
# 86
# Images_Test\12287.ppm
# 87
# Images_Test\12288.ppm
# 88
# Images_Test\12289.ppm
# 89
# Images_Test\12290.ppm
# 90
# Images_Test\12291.ppm
# 91
# Images_Test\12292.ppm
# 92
# Images_Test\12293.ppm
# 93
# Images_Test\12294.ppm
# 94
# Images_Test\12295.ppm
# 95
# Images_Test\12296.ppm
# 96
# Images_Test\12297.ppm
# 97
# Images_Test\12298.ppm
# 98
# Images_Test\12299.ppm
# 99
# Images_Test\12300.ppm
# 0
# Images_Test\12301.ppm
# 1
# Images_Test\12302.ppm
# 2
# Images_Test\12303.ppm
# 3
# Images_Test\12304.ppm
# 4
# Images_Test\12305.ppm
# 5
# Images_Test\12306.ppm
# 6
# Images_Test\12307.ppm
# 7
# Images_Test\12308.ppm
# 8
# Images_Test\12309.ppm
# 9
# Images_Test\12310.ppm
# 10
# Images_Test\12311.ppm
# 11
# Images_Test\12312.ppm
# 12
# Images_Test\12313.ppm
# 13
# Images_Test\12314.ppm
# 14
# Images_Test\12315.ppm
# 15
# Images_Test\12316.ppm
# 16
# Images_Test\12317.ppm
# 17
# Images_Test\12318.ppm
# 18
# Images_Test\12319.ppm
# 19
# Images_Test\12320.ppm
# 20
# Images_Test\12321.ppm
# 21
# Images_Test\12322.ppm
# 22
# Images_Test\12323.ppm
# 23
# Images_Test\12324.ppm
# 24
# Images_Test\12325.ppm
# 25
# Images_Test\12326.ppm
# 26
# Images_Test\12327.ppm
# 27
# Images_Test\12328.ppm
# 28
# Images_Test\12329.ppm
# 29
# Images_Test\12330.ppm
# 30
# Images_Test\12331.ppm
# 31
# Images_Test\12332.ppm
# 32
# Images_Test\12333.ppm
# 33
# Images_Test\12334.ppm
# 34
# Images_Test\12335.ppm
# 35
# Images_Test\12336.ppm
# 36
# Images_Test\12337.ppm
# 37
# Images_Test\12338.ppm
# 38
# Images_Test\12339.ppm
# 39
# Images_Test\12340.ppm
# 40
# Images_Test\12341.ppm
# 41
# Images_Test\12342.ppm
# 42
# Images_Test\12343.ppm
# 43
# Images_Test\12344.ppm
# 44
# Images_Test\12345.ppm
# 45
# Images_Test\12346.ppm
# 46
# Images_Test\12347.ppm
# 47
# Images_Test\12348.ppm
# 48
# Images_Test\12349.ppm
# 49
# Images_Test\12350.ppm
# 50
# Images_Test\12351.ppm
# 51
# Images_Test\12352.ppm
# 52
# Images_Test\12353.ppm
# 53
# Images_Test\12354.ppm
# 54
# Images_Test\12355.ppm
# 55
# Images_Test\12356.ppm
# 56
# Images_Test\12357.ppm
# 57
# Images_Test\12358.ppm
# 58
# Images_Test\12359.ppm
# 59
# Images_Test\12360.ppm
# 60
# Images_Test\12361.ppm
# 61
# Images_Test\12362.ppm
# 62
# Images_Test\12363.ppm
# 63
# Images_Test\12364.ppm
# 64
# Images_Test\12365.ppm
# 65
# Images_Test\12366.ppm
# 66
# Images_Test\12367.ppm
# 67
# Images_Test\12368.ppm
# 68
# Images_Test\12369.ppm
# 69
# Images_Test\12370.ppm
# 70
# Images_Test\12371.ppm
# 71
# Images_Test\12372.ppm
# 72
# Images_Test\12373.ppm
# 73
# Images_Test\12374.ppm
# 74
# Images_Test\12375.ppm
# 75
# Images_Test\12376.ppm
# 76
# Images_Test\12377.ppm
# 77
# Images_Test\12378.ppm
# 78
# Images_Test\12379.ppm
# 79
# Images_Test\12380.ppm
# 80
# Images_Test\12381.ppm
# 81
# Images_Test\12382.ppm
# 82
# Images_Test\12383.ppm
# 83
# Images_Test\12384.ppm
# 84
# Images_Test\12385.ppm
# 85
# Images_Test\12386.ppm
# 86
# Images_Test\12387.ppm
# 87
# Images_Test\12388.ppm
# 88
# Images_Test\12389.ppm
# 89
# Images_Test\12390.ppm
# 90
# Images_Test\12391.ppm
# 91
# Images_Test\12392.ppm
# 92
# Images_Test\12393.ppm
# 93
# Images_Test\12394.ppm
# 94
# Images_Test\12395.ppm
# 95
# Images_Test\12396.ppm
# 96
# Images_Test\12397.ppm
# 97
# Images_Test\12398.ppm
# 98
# Images_Test\12399.ppm
# 99
# Images_Test\12400.ppm
# 0
# Images_Test\12401.ppm
# 1
# Images_Test\12402.ppm
# 2
# Images_Test\12403.ppm
# 3
# Images_Test\12404.ppm
# 4
# Images_Test\12405.ppm
# 5
# Images_Test\12406.ppm
# 6
# Images_Test\12407.ppm
# 7
# Images_Test\12408.ppm
# 8
# Images_Test\12409.ppm
# 9
# Images_Test\12410.ppm
# 10
# Images_Test\12411.ppm
# 11
# Images_Test\12412.ppm
# 12
# Images_Test\12413.ppm
# 13
# Images_Test\12414.ppm
# 14
# Images_Test\12415.ppm
# 15
# Images_Test\12416.ppm
# 16
# Images_Test\12417.ppm
# 17
# Images_Test\12418.ppm
# 18
# Images_Test\12419.ppm
# 19
# Images_Test\12420.ppm
# 20
# Images_Test\12421.ppm
# 21
# Images_Test\12422.ppm
# 22
# Images_Test\12423.ppm
# 23
# Images_Test\12424.ppm
# 24
# Images_Test\12425.ppm
# 25
# Images_Test\12426.ppm
# 26
# Images_Test\12427.ppm
# 27
# Images_Test\12428.ppm
# 28
# Images_Test\12429.ppm
# 29
# Images_Test\12430.ppm
# 30
# Images_Test\12431.ppm
# 31
# Images_Test\12432.ppm
# 32
# Images_Test\12433.ppm
# 33
# Images_Test\12434.ppm
# 34
# Images_Test\12435.ppm
# 35
# Images_Test\12436.ppm
# 36
# Images_Test\12437.ppm
# 37
# Images_Test\12438.ppm
# 38
# Images_Test\12439.ppm
# 39
# Images_Test\12440.ppm
# 40
# Images_Test\12441.ppm
# 41
# Images_Test\12442.ppm
# 42
# Images_Test\12443.ppm
# 43
# Images_Test\12444.ppm
# 44
# Images_Test\12445.ppm
# 45
# Images_Test\12446.ppm
# 46
# Images_Test\12447.ppm
# 47
# Images_Test\12448.ppm
# 48
# Images_Test\12449.ppm
# 49
# Images_Test\12450.ppm
# 50
# Images_Test\12451.ppm
# 51
# Images_Test\12452.ppm
# 52
# Images_Test\12453.ppm
# 53
# Images_Test\12454.ppm
# 54
# Images_Test\12455.ppm
# 55
# Images_Test\12456.ppm
# 56
# Images_Test\12457.ppm
# 57
# Images_Test\12458.ppm
# 58
# Images_Test\12459.ppm
# 59
# Images_Test\12460.ppm
# 60
# Images_Test\12461.ppm
# 61
# Images_Test\12462.ppm
# 62
# Images_Test\12463.ppm
# 63
# Images_Test\12464.ppm
# 64
# Images_Test\12465.ppm
# 65
# Images_Test\12466.ppm
# 66
# Images_Test\12467.ppm
# 67
# Images_Test\12468.ppm
# 68
# Images_Test\12469.ppm
# 69
# Images_Test\12470.ppm
# 70
# Images_Test\12471.ppm
# 71
# Images_Test\12472.ppm
# 72
# Images_Test\12473.ppm
# 73
# Images_Test\12474.ppm
# 74
# Images_Test\12475.ppm
# 75
# Images_Test\12476.ppm
# 76
# Images_Test\12477.ppm
# 77
# Images_Test\12478.ppm
# 78
# Images_Test\12479.ppm
# 79
# Images_Test\12480.ppm
# 80
# Images_Test\12481.ppm
# 81
# Images_Test\12482.ppm
# 82
# Images_Test\12483.ppm
# 83
# Images_Test\12484.ppm
# 84
# Images_Test\12485.ppm
# 85
# Images_Test\12486.ppm
# 86
# Images_Test\12487.ppm
# 87
# Images_Test\12488.ppm
# 88
# Images_Test\12489.ppm
# 89
# Images_Test\12490.ppm
# 90
# Images_Test\12491.ppm
# 91
# Images_Test\12492.ppm
# 92
# Images_Test\12493.ppm
# 93
# Images_Test\12494.ppm
# 94
# Images_Test\12495.ppm
# 95
# Images_Test\12496.ppm
# 96
# Images_Test\12497.ppm
# 97
# Images_Test\12498.ppm
# 98
# Images_Test\12499.ppm
# 99
# Images_Test\12500.ppm
# 0
# Images_Test\12501.ppm
# 1
# Images_Test\12502.ppm
# 2
# Images_Test\12503.ppm
# 3
# Images_Test\12504.ppm
# 4
# Images_Test\12505.ppm
# 5
# Images_Test\12506.ppm
# 6
# Images_Test\12507.ppm
# 7
# Images_Test\12508.ppm
# 8
# Images_Test\12509.ppm
# 9
# Images_Test\12510.ppm
# 10
# Images_Test\12511.ppm
# 11
# Images_Test\12512.ppm
# 12
# Images_Test\12513.ppm
# 13
# Images_Test\12514.ppm
# 14
# Images_Test\12515.ppm
# 15
# Images_Test\12516.ppm
# 16
# Images_Test\12517.ppm
# 17
# Images_Test\12518.ppm
# 18
# Images_Test\12519.ppm
# 19
# Images_Test\12520.ppm
# 20
# Images_Test\12521.ppm
# 21
# Images_Test\12522.ppm
# 22
# Images_Test\12523.ppm
# 23
# Images_Test\12524.ppm
# 24
# Images_Test\12525.ppm
# 25
# Images_Test\12526.ppm
# 26
# Images_Test\12527.ppm
# 27
# Images_Test\12528.ppm
# 28
# Images_Test\12529.ppm
# 29
# Images_Test\12530.ppm
# 30
# Images_Test\12531.ppm
# 31
# Images_Test\12532.ppm
# 32
# Images_Test\12533.ppm
# 33
# Images_Test\12534.ppm
# 34
# Images_Test\12535.ppm
# 35
# Images_Test\12536.ppm
# 36
# Images_Test\12537.ppm
# 37
# Images_Test\12538.ppm
# 38
# Images_Test\12539.ppm
# 39
# Images_Test\12540.ppm
# 40
# Images_Test\12541.ppm
# 41
# Images_Test\12542.ppm
# 42
# Images_Test\12543.ppm
# 43
# Images_Test\12544.ppm
# 44
# Images_Test\12545.ppm
# 45
# Images_Test\12546.ppm
# 46
# Images_Test\12547.ppm
# 47
# Images_Test\12548.ppm
# 48
# Images_Test\12549.ppm
# 49
# Images_Test\12550.ppm
# 50
# Images_Test\12551.ppm
# 51
# Images_Test\12552.ppm
# 52
# Images_Test\12553.ppm
# 53
# Images_Test\12554.ppm
# 54
# Images_Test\12555.ppm
# 55
# Images_Test\12556.ppm
# 56
# Images_Test\12557.ppm
# 57
# Images_Test\12558.ppm
# 58
# Images_Test\12559.ppm
# 59
# Images_Test\12560.ppm
# 60
# Images_Test\12561.ppm
# 61
# Images_Test\12562.ppm
# 62
# Images_Test\12563.ppm
# 63
# Images_Test\12564.ppm
# 64
# Images_Test\12565.ppm
# 65
# Images_Test\12566.ppm
# 66
# Images_Test\12567.ppm
# 67
# Images_Test\12568.ppm
# 68
# Images_Test\12569.ppm
# 69
# Images_Test\12570.ppm
# 70
# Images_Test\12571.ppm
# 71
# Images_Test\12572.ppm
# 72
# Images_Test\12573.ppm
# 73
# Images_Test\12574.ppm
# 74
# Images_Test\12575.ppm
# 75
# Images_Test\12576.ppm
# 76
# Images_Test\12577.ppm
# 77
# Images_Test\12578.ppm
# 78
# Images_Test\12579.ppm
# 79
# Images_Test\12580.ppm
# 80
# Images_Test\12581.ppm
# 81
# Images_Test\12582.ppm
# 82
# Images_Test\12583.ppm
# 83
# Images_Test\12584.ppm
# 84
# Images_Test\12585.ppm
# 85
# Images_Test\12586.ppm
# 86
# Images_Test\12587.ppm
# 87
# Images_Test\12588.ppm
# 88
# Images_Test\12589.ppm
# 89
# Images_Test\12590.ppm
# 90
# Images_Test\12591.ppm
# 91
# Images_Test\12592.ppm
# 92
# Images_Test\12593.ppm
# 93
# Images_Test\12594.ppm
# 94
# Images_Test\12595.ppm
# 95
# Images_Test\12596.ppm
# 96
# Images_Test\12597.ppm
# 97
# Images_Test\12598.ppm
# 98
# Images_Test\12599.ppm
# 99
# Images_Test\12600.ppm
# 0
# Images_Test\12601.ppm
# 1
# Images_Test\12602.ppm
# 2
# Images_Test\12603.ppm
# 3
# Images_Test\12604.ppm
# 4
# Images_Test\12605.ppm
# 5
# Images_Test\12606.ppm
# 6
# Images_Test\12607.ppm
# 7
# Images_Test\12608.ppm
# 8
# Images_Test\12609.ppm
# 9
# Images_Test\12610.ppm
# 10
# Images_Test\12611.ppm
# 11
# Images_Test\12612.ppm
# 12
# Images_Test\12613.ppm
# 13
# Images_Test\12614.ppm
# 14
# Images_Test\12615.ppm
# 15
# Images_Test\12616.ppm
# 16
# Images_Test\12617.ppm
# 17
# Images_Test\12618.ppm
# 18
# Images_Test\12619.ppm
# 19
# Images_Test\12620.ppm
# 20
# Images_Test\12621.ppm
# 21
# Images_Test\12622.ppm
# 22
# Images_Test\12623.ppm
# 23
# Images_Test\12624.ppm
# 24
# Images_Test\12625.ppm
# 25
# Images_Test\12626.ppm
# 26
# Images_Test\12627.ppm
# 27
# Images_Test\12628.ppm
# 28
# Images_Test\12629.ppm
# 29

# %%
df = pd.read_csv("Images_Test\\GT-final_test.csv", sep=';')
df.head()
print(len(df['ClassId'].to_list()))
y_test_list = df['ClassId'].to_list()
# Out:
# 12630

# %% [markdown]
# ### Function to Resize  Images

# %%
#Resize the Image
def resize_image(images):
    image_resize = [cv2.resize(image,(32,32)) for image in images]
    return (image_resize)

# %%
X_train_resize = resize_image(X_train_list)
X_test_resize = resize_image(X_test_list)

# %%
#Convert list to numpy array
X_train_data = np.array(X_train_resize)
y_train_labels = np.array(y_train_list)
test_dataset = np.array(X_test_resize)
test_labels = np.array(y_test_list)

# %%
#Split into train and Valid sets
train_dataset, valid_dataset, train_labels, valid_labels = train_test_split(X_train_data, y_train_labels, test_size=0.20, stratify=y_train_labels)

# %%
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (31367, 32, 32, 3) (31367,)
# Validation set (7842, 32, 32, 3) (7842,)
# Test set (12630, 32, 32, 3) (12630,)

# %% [markdown]
# ### Function to Convert RGB to Gray Scale Images

# %%
#Convert to Gray Scale and normalize
def rgbTogray(images):
    images_gray = np.mean(images, axis=3)
    return images_gray

# %% [markdown]
# ### Function to Normalize Data of the Images

# %%
#Normalize the data
def normalizeData(images):
    #SUbtract the mean value
    images -= np.mean(images)
    
    #Divide by the standard deviation
    images /= np.std(images)
    
    return images

train_dataset = normalizeData(rgbTogray(train_dataset))
valid_dataset = normalizeData(rgbTogray(valid_dataset))
test_dataset = normalizeData(rgbTogray(test_dataset))

# %%
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (31367, 32, 32) (31367,)
# Validation set (7842, 32, 32) (7842,)
# Test set (12630, 32, 32) (12630,)

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# #### Display images and Class labels

# %%
def display_traffic_images(images, labels):
    #Display one image from each set
    unique_labels = set(labels)
    plt.figure(figsize =(10,10))
    im_idx = 1
    for label in unique_labels:
        #Pick the image for each label.
        image = images[labels.index(label)]
        plt.subplot(8,8, im_idx)
        plt.axis("off")
        plt.title("Label {0}".format(label))
        im_idx= im_idx+1
        _=plt.imshow(image)
    plt.show()
    
display_traffic_images(X_train_list,y_train_list)

# %% [markdown]
# #### Histogram of the Images

# %%
plt.hist(y_train_labels, bins=43,facecolor='green',linewidth=2, alpha=0.75)
plt.title ("Traffic Data set Distribution")
plt.xlabel("Value")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### Basic Input Parameters

# %%
image_size = 32
num_labels = len(np.unique(y_train_labels))
num_channels = 1

# %%
#Refomat the convolutions
def reformat(features, labels):
    features = features.reshape((-1,image_size,image_size,num_channels)).astype(np.float32)
    labels = (np.arange(num_labels)==labels[:,None]).astype(np.float32)
    return features, labels

# %%
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (31367, 32, 32, 1) (31367, 43)
# Validation set (7842, 32, 32, 1) (7842, 43)
# Test set (12630, 32, 32, 1) (12630, 43)

# %% [markdown]
# ### Helper Functions for Calculating Accuracy, Loss

# %%
#Define Accuracy Function
def cal_accuracy(predictions, labels):
    accuracy = (100*np.sum(np.argmax(predictions,1)== np.argmax(labels,1))/predictions.shape[0])
    return accuracy

# %%
#Define Loss Function
def cal_loss(predictions,labels):
    loss = np.mean(np.square(predictions-labels))
    return loss

# %%
def plot_confusion_matrix(cm,title):
    cm = [row/sum(row)   for row in cm]
    fig = plt.figure(figsize=(10, 10))
    ax = fig.add_subplot(111)
    cax = ax.matshow(cm, cmap=plt.cm.Blues)
    fig.colorbar(cax)
    title = title+' '+'Confusion Matrix'
    plt.title(title)
    plt.xlabel('Predicted Class IDs')
    plt.ylabel('True Class IDs')
    plt.show()

# %% [markdown]
# ## Model 1

# %% [markdown]
# In this simple model for classification I build the model with two convolution layers and 1 fully connected layer. I used 64 hidden units for the fully connected layer.
# I used a constant output filters or depth of 16 for both the convolution layers.
# I did not use any regularization for optimizing the cost function.
# A batch size of 128 was used for training the model.

# %%
batch_size =128
patch_size =5
depth =16
num_hidden =64

# %%
graph= tf.Graph()
with graph.as_default():
    
    #Define the placeholder
    x= tf.placeholder(tf.float32, shape=(None, image_size, image_size, num_channels), name='x')
    y= tf.placeholder(tf.float32, shape=(None,num_labels))
    
    train_x = tf.constant(train_dataset)
    valid_x = tf.constant(valid_dataset)
    test_x = tf.constant(test_dataset)
    
    #Define the weight variables
    l1_weight = tf.Variable(tf.truncated_normal([patch_size,patch_size,num_channels,depth],mean=0, stddev=0.1))
    
    l1_bias = tf.Variable(tf.zeros([depth]))
    
    #Layer 2
    l2_weight = tf.Variable(tf.truncated_normal([patch_size,patch_size,depth,depth],mean=0, stddev=0.1))
    
    l2_bias = tf.Variable(tf.constant(1.0, shape=[depth]))
    
    #Layer 3
    l3_weight = tf.Variable(tf.truncated_normal([image_size//4*image_size//4 * depth,num_hidden],mean=0, stddev=0.1))
    
    l3_bias = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    
    #Layer 4
    l4_weight = tf.Variable(tf.truncated_normal([num_hidden,num_labels],mean=0, stddev=0.1))
    l4_bias = tf.Variable(tf.constant(1.0,shape=[num_labels]))
    
    #Define Model
    def model(data):
        conv1 = tf.nn.conv2d(data,l1_weight,[1,2,2,1], padding="SAME")
        
        hidden1 = tf.nn.relu(conv1+l1_bias)
       
        conv2 = tf.nn.conv2d(hidden1, l2_weight,[1,2,2,1], padding="SAME")
        hidden2 = tf.nn.relu(conv2+l2_bias)
       
        shape = hidden2.get_shape().as_list()
        
   
        reshape = tf.reshape(hidden2,[-1, shape[1]*shape[2]*shape[3]])
        
       
        hidden3 = tf.nn.relu(tf.matmul(reshape,l3_weight)+l3_bias)
       
        out_layer = tf.matmul(hidden3,l4_weight) + l4_bias
        
        return out_layer
    
    
    #Training Computation
    logits = model(x)
    cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels = y)
    #loss = tf.reduce_mean(cross_entropy) +0.0001 *(tf.nn.l2_loss(layer1_weight)+tf.nn.l2_loss(layer2_weight)+tf.nn.l2_loss(layer3_weight)+tf.nn.l2_loss(layer4_weight))
    loss = tf.reduce_mean(cross_entropy)
    #Optimizer
    optimizer = tf.train.AdamOptimizer(1e-3).minimize(loss)
    
    #Prediction
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(valid_x))
    test_prediction = tf.nn.softmax(model(test_x))

# %%
epochs = 2000

with tf.Session(graph=graph) as session:
    #tf.initialize_all_variables().run()
    session.run(tf.global_variables_initializer())
    print('Training Stared Simple Model')
    print ('---------------------------')
    train_acc_history = np.zeros(epochs)
    train_loss_history= np.zeros(epochs)
    valid_acc_history = np.zeros(epochs)
    
    for step in range(epochs):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {x : batch_data, y : batch_labels}
        model_Network1, train_loss, predictions = session.run([optimizer, loss, train_prediction], 
                                                              feed_dict=feed_dict)
        if (step % 50 == 0):
            print('Minibatch loss at step %d: %f' % (step, train_loss))
            print('Minibatch accuracy: %.1f%%' % cal_accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%%' % cal_accuracy(valid_prediction.eval(), valid_labels))
            train_acc_history[step] = cal_accuracy(predictions, batch_labels)
            valid_acc_history[step] = cal_accuracy(valid_prediction.eval(), valid_labels)
            train_loss_history[step] = train_loss
            
        
        #valid_pred = valid_prediction.eval()
    
    t_pred=(session.run([train_prediction],feed_dict={x:train_dataset,y:train_labels}))
    y_pred_train = np.argmax(t_pred[0],1)
    y_true_train = np.argmax(train_labels,1)
    cm_train = confusion_matrix(y_true_train,y_pred_train)
    
    
    y_pred_valid = (tf.argmax(valid_prediction.eval(), 1)).eval()
    y_true_valid = np.argmax(valid_labels, 1)
    cm_valid = confusion_matrix(y_true_valid, y_pred_valid)
    
    
    #test data set results
    y_pred_test = (tf.argmax(test_prediction.eval(), 1)).eval()
    y_true_test = np.argmax(test_labels, 1)
    cm_test = confusion_matrix(y_true_test, y_pred_test)
    
    
    print('Train accuracy: %.1f%%' % cal_accuracy(t_pred[0], train_labels))
    print('valid accuracy: %.1f%%' % cal_accuracy(valid_prediction.eval(), valid_labels))
    print('Test accuracy: %.1f%%' % cal_accuracy(test_prediction.eval(), test_labels))
    
    
    
x_axis = np.arange(epochs)
plt.plot(x_axis[train_acc_history > 0], train_acc_history[train_acc_history > 0], linewidth=2, label= "Train Data")
plt.plot(x_axis[valid_acc_history > 0], valid_acc_history[valid_acc_history > 0],  linewidth=2, label= "Validation Data")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()
plt.plot(x_axis[train_loss_history > 0], train_loss_history[train_loss_history > 0],  linewidth=2, label= "Train Loss")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

#Train Set Confusion Matrix
plot_confusion_matrix(cm_train,"Train Data Set")
dm_cm_train= pd.DataFrame(cm_train)
    
#Validation Set Confusion Matrix
dm_cm_valid= pd.DataFrame(cm_valid)
plot_confusion_matrix(cm_valid,"Validation Data Set")
    
#Test Set Confusion Matrix
dm_cm_test= pd.DataFrame(cm_test)
plot_confusion_matrix(cm_test,"Test Data Set")

#Calculate Precision, Recall and F1 Score for the test data
TP_test = np.diagonal(cm_test)
precision = TP_test/np.sum(cm_test, axis=1)
recall = TP_test/np.sum(cm_test, axis=0)
f1_score = 2*precision*recall/(precision+recall)
# Out:
# Training Stared Simple Model
# ---------------------------
# Minibatch loss at step 0: 4.707083
# Minibatch accuracy: 3.1%
# Validation accuracy: 2.6%
# Minibatch loss at step 50: 3.150609
# Minibatch accuracy: 18.0%
# Validation accuracy: 17.5%
# Minibatch loss at step 100: 2.429310
# Minibatch accuracy: 35.9%
# Validation accuracy: 33.5%
# Minibatch loss at step 150: 1.783210
# Minibatch accuracy: 52.3%
# Validation accuracy: 52.5%
# Minibatch loss at step 200: 1.330543
# Minibatch accuracy: 67.2%
# Validation accuracy: 62.9%
# Minibatch loss at step 250: 0.986030
# Minibatch accuracy: 70.3%
# Validation accuracy: 71.9%
# Minibatch loss at step 300: 0.759093
# Minibatch accuracy: 82.0%
# Validation accuracy: 79.3%
# Minibatch loss at step 350: 0.562837
# Minibatch accuracy: 89.8%
# Validation accuracy: 82.6%
# Minibatch loss at step 400: 0.475372
# Minibatch accuracy: 88.3%
# Validation accuracy: 84.5%
# Minibatch loss at step 450: 0.519850
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.0%
# Minibatch loss at step 500: 0.411247
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.5%
# Minibatch loss at step 550: 0.704004
# Minibatch accuracy: 85.2%
# Validation accuracy: 88.1%
# Minibatch loss at step 600: 0.355485
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.8%
# Minibatch loss at step 650: 0.342311
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.4%
# Minibatch loss at step 700: 0.279679
# Minibatch accuracy: 96.1%
# Validation accuracy: 90.0%
# Minibatch loss at step 750: 0.216341
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.2%
# Minibatch loss at step 800: 0.278784
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.2%
# Minibatch loss at step 850: 0.347336
# Minibatch accuracy: 89.8%
# Validation accuracy: 92.3%
# Minibatch loss at step 900: 0.273957
# Minibatch accuracy: 93.0%
# Validation accuracy: 92.7%
# Minibatch loss at step 950: 0.228132
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.7%
# Minibatch loss at step 1000: 0.330895
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.9%
# Minibatch loss at step 1050: 0.182332
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.9%
# Minibatch loss at step 1100: 0.158108
# Minibatch accuracy: 95.3%
# Validation accuracy: 93.7%
# Minibatch loss at step 1150: 0.211953
# Minibatch accuracy: 94.5%
# Validation accuracy: 93.4%
# Minibatch loss at step 1200: 0.232922
# Minibatch accuracy: 93.8%
# Validation accuracy: 93.9%
# Minibatch loss at step 1250: 0.297187
# Minibatch accuracy: 93.0%
# Validation accuracy: 93.3%
# Minibatch loss at step 1300: 0.124459
# Minibatch accuracy: 96.9%
# Validation accuracy: 93.9%
# Minibatch loss at step 1350: 0.153369
# Minibatch accuracy: 96.9%
# Validation accuracy: 94.8%
# Minibatch loss at step 1400: 0.130164
# Minibatch accuracy: 97.7%
# Validation accuracy: 94.3%
# Minibatch loss at step 1450: 0.087208
# Minibatch accuracy: 98.4%
# Validation accuracy: 95.0%
# Minibatch loss at step 1500: 0.169892
# Minibatch accuracy: 95.3%
# Validation accuracy: 93.8%
# Minibatch loss at step 1550: 0.084712
# Minibatch accuracy: 98.4%
# Validation accuracy: 94.2%
# Minibatch loss at step 1600: 0.103192
# Minibatch accuracy: 98.4%
# Validation accuracy: 94.7%
# Minibatch loss at step 1650: 0.088445
# Minibatch accuracy: 98.4%
# Validation accuracy: 94.3%
# Minibatch loss at step 1700: 0.134980
# Minibatch accuracy: 97.7%
# Validation accuracy: 95.4%
# Minibatch loss at step 1750: 0.178245
# Minibatch accuracy: 96.9%
# Validation accuracy: 94.5%
# Minibatch loss at step 1800: 0.137665
# Minibatch accuracy: 96.9%
# Validation accuracy: 95.7%
# Minibatch loss at step 1850: 0.076632
# Minibatch accuracy: 97.7%
# Validation accuracy: 95.3%
# Minibatch loss at step 1900: 0.072347
# Minibatch accuracy: 98.4%
# Validation accuracy: 95.2%
# Minibatch loss at step 1950: 0.143295
# Minibatch accuracy: 96.1%
# Validation accuracy: 95.7%
# Train accuracy: 97.4%
# valid accuracy: 95.2%
# Test accuracy: 86.8%

# %%
from sklearn.metrics import precision_score,recall_score, confusion_matrix

# %% [markdown]
# #### Precision, Recall and F1 Scores for all classes

# %%
report_model1 = classification_report(y_true_test, y_pred_test)
print (report_model1)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.33      0.44        60
#            1       0.77      0.93      0.84       720
#            2       0.94      0.87      0.90       750
#            3       0.81      0.93      0.86       450
#            4       0.95      0.82      0.88       660
#            5       0.83      0.87      0.85       630
#            6       0.93      0.66      0.77       150
#            7       0.94      0.74      0.83       450
#            8       0.75      0.86      0.80       450
#            9       0.91      0.94      0.93       480
#           10       0.94      0.96      0.95       660
#           11       0.78      0.92      0.84       420
#           12       0.98      0.91      0.94       690
#           13       0.98      0.98      0.98       720
#           14       0.93      0.94      0.93       270
#           15       0.92      0.92      0.92       210
#           16       0.99      0.97      0.98       150
#           17       0.97      0.97      0.97       360
#           18       0.88      0.72      0.79       390
#           19       0.62      0.80      0.70        60
#           20       0.59      0.51      0.55        90
#           21       0.84      0.59      0.69        90
#           22       0.80      0.82      0.81       120
#           23       0.66      0.54      0.60       150
#           24       0.45      0.72      0.56        90
#           25       0.90      0.88      0.89       480
#           26       0.68      0.84      0.75       180
#           27       0.56      0.25      0.34        60
#           28       0.77      0.75      0.76       150
#           29       0.87      0.69      0.77        90
#           30       0.52      0.55      0.54       150
#           31       0.94      0.87      0.90       270
#           32       0.82      0.77      0.79        60
#           33       0.84      0.94      0.89       210
#           34       0.93      0.97      0.95       120
#           35       0.93      0.96      0.95       390
#           36       0.94      0.90      0.92       120
#           37       1.00      0.82      0.90        60
#           38       0.91      0.93      0.92       690
#           39       0.85      0.87      0.86        90
#           40       0.80      0.80      0.80        90
#           41       0.95      0.63      0.76        60
#           42       0.82      0.93      0.87        90
#
#     accuracy                           0.87     12630
#    macro avg       0.83      0.80      0.81     12630
# weighted avg       0.87      0.87      0.87     12630

# %% [markdown]
# #### Macro Averaging of Precision, Recall and F1 Scores

# %%
from sklearn.metrics import f1_score
f1_score_macro = f1_score(y_true_test, y_pred_test, average="macro")
precision_macro =precision_score(y_true_test, y_pred_test, average="macro")
recall_macro =recall_score(y_true_test, y_pred_test, average="macro")
df_macro = pd.DataFrame({'Precision':[precision_macro],'Recall':[recall_macro],'f1 score':[f1_score_macro]})
df_macro.round(2)
# Out:
#    Precision  Recall  f1 score
# 0       0.83     0.8      0.81

# %% [markdown]
# #### Micro Averaging of Precision, Recall and F1 Scores

# %%
f1_score_micro = f1_score(y_true_test, y_pred_test, average="micro")
precision_micro =precision_score(y_true_test, y_pred_test, average="micro")
recall_micro =recall_score(y_true_test, y_pred_test, average="micro")
df_micro = pd.DataFrame({'Precision':[precision_micro],'Recall':[recall_micro],'f1 score':[f1_score_micro]})
df_micro.round(2)
# Out:
#    Precision  Recall  f1 score
# 0       0.87    0.87      0.87

# %% [markdown]
# #### Weighted Averaging of Precision, Recall and F1 Scores

# %%
f1_score_weighted = f1_score(y_true_test, y_pred_test, average="weighted")
precision_weighted =precision_score(y_true_test, y_pred_test, average="weighted")
recall_weighted =recall_score(y_true_test, y_pred_test, average="weighted")
df_weighted = pd.DataFrame({'Precision':[precision_weighted],'Recall':[recall_weighted],'f1 score':[f1_score_weighted]})
df_weighted.round(2)
# Out:
#    Precision  Recall  f1 score
# 0       0.87    0.87      0.87

# %% [markdown]
# ## Model 2 Architecture

# %% [markdown]
# In this model we build a more detailed CNN. This architecture is very similar to the LENET architecture. In this model I have implemented the drop out and added L2 regularization so to improve accuracy of the model and also prevent over fitting.

# %%
batch_size = 128
patch_size = 5
depth = 16
num_hidden = 256
beta_regul = 1e-4
drop_out = 0.5

graph = tf.Graph()

with graph.as_default():

    # Input data.
    x_train_dataset = tf.placeholder(tf.float32, shape=(None, image_size, image_size, num_channels))
    y_train_labels = tf.placeholder(tf.float32, shape=(None, num_labels))
    
    train_x = tf.constant(train_dataset)
    x_valid_dataset = tf.constant(valid_dataset)
    x_test_dataset = tf.constant(test_dataset)
    global_step = tf.Variable(0)
  
    # Variables.
    l1_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, num_channels, depth], stddev=0.1))
    l1_biases = tf.Variable(tf.zeros([depth]))
    
    l2_weights = tf.Variable(tf.truncated_normal([patch_size, patch_size, depth, 2*depth], stddev=0.1))
    l2_biases = tf.Variable(tf.constant(1.0, shape=[2*depth]))
  
    #Size for the next layer
    size3 = ((image_size - patch_size + 1) // 2 - patch_size + 1) // 2
  
    l3_weights = tf.Variable(tf.truncated_normal([2*size3 * size3 * depth, num_hidden], stddev=0.1))
    l3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    #print ("This is layer3", layer3_weights)
    l4_weights = tf.Variable(tf.truncated_normal([num_hidden, num_hidden], stddev=0.1))
    l4_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    
    l5_weights = tf.Variable(tf.truncated_normal([num_hidden, num_labels], stddev=0.1))
    l5_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
    # Model.
    def modelCNN(data, keep_prob):
        # C1 input 28 x 28
        conv1 = tf.nn.conv2d(data, l1_weights, [1, 1, 1, 1], padding='VALID')
        #bias1 = tf.nn.relu(conv1 + l1_biases)
        conv1 = tf.nn.relu(conv1 + l1_biases)
                     
        pool2 = tf.nn.max_pool(conv1, [1, 2, 2, 1], [1, 2, 2, 1], padding='VALID')
        
        # C3 input 12 x 12
        conv3 = tf.nn.conv2d(pool2, l2_weights, [1, 1, 1, 1], padding='VALID')
        conv3 = tf.nn.relu(conv3 + l2_biases)
        
        # S4 input 8 x 8
        pool4 = tf.nn.max_pool(conv3, [1, 2, 2, 1], [1, 2, 2, 1], padding='VALID')
        
        # F5 input 4 x 4
        shape = pool4.get_shape().as_list()
        pool_flat = tf.keras.layers.Flatten()(pool4)
        fc5 = tf.nn.relu(tf.matmul(pool_flat, l3_weights) + l3_biases)
    
        drop5 = tf.nn.dropout(fc5, keep_prob)
    
        fc6 = tf.nn.relu(tf.matmul(fc5, l4_weights) + l4_biases)
        
        drop6 = tf.nn.dropout(fc6, keep_prob)
        out_layer = tf.matmul(drop6, l5_weights) + l5_biases
        
        return out_layer
  
    # Training computation.
    logits = modelCNN(x_train_dataset, drop_out)
      
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y_train_labels)+
                       0.0001*(tf.nn.l2_loss(l1_weights)+tf.nn.l2_loss(l2_weights)+
                               tf.nn.l2_loss(l3_weights)+tf.nn.l2_loss(l4_weights)+ 
                               tf.nn.l2_loss(l5_weights)))
    
    # Optimizer.
    learning_rate = tf.train.exponential_decay(0.05, global_step, 1000, 0.90, staircase=True)
    optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
  
    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(modelCNN(x_valid_dataset, 1.0))
    test_prediction = tf.nn.softmax(modelCNN(x_test_dataset, 1.0))
# Out:
# WARNING:tensorflow:From C:\Users\diaaa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\tensorflow\python\util\dispatch.py:1096: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
epochs = 2000

with tf.Session(graph=graph) as session:
    saver = tf.train.Saver()
    session.run(tf.global_variables_initializer())
    print('Training Started')
    print ('---------------------------')
    train_acc_history = np.zeros(epochs)
    train_loss_history= np.zeros(epochs)
    valid_acc_history = np.zeros(epochs)
    for step in range(epochs):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {x_train_dataset : batch_data, y_train_labels : batch_labels}
        model3, train_loss, predictions = session.run([optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 50 == 0):
            print('Minibatch loss at step %d: %f' % (step, train_loss))
            print('Minibatch accuracy: %.1f%%' % cal_accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%%' % cal_accuracy(valid_prediction.eval(), valid_labels))
            train_acc_history[step] = cal_accuracy(predictions, batch_labels)
            valid_acc_history[step] = cal_accuracy(valid_prediction.eval(), valid_labels)
            train_loss_history[step] = train_loss
            
    t_pred=(session.run([train_prediction],feed_dict={x_train_dataset:train_dataset,y_train_labels:train_labels}))
    y_pred_train = np.argmax(t_pred[0],1)
    y_true_train = np.argmax(train_labels,1)
    cm_train = confusion_matrix(y_true_train,y_pred_train)
   
    
    #Valid Data Set Results
    y_pred_valid = (tf.argmax(valid_prediction.eval(), 1)).eval()
    y_true_valid = np.argmax(valid_labels, 1)
    cm_valid = confusion_matrix(y_true_valid, y_pred_valid)
    
    
    
    #Test Results
    y_pred_test = (tf.argmax(test_prediction.eval(), 1)).eval()
    y_true_test = np.argmax(test_labels, 1)
    cm_test = confusion_matrix(y_true_test, y_pred_test)
    
    
    print('Train accuracy: %.1f%%' % cal_accuracy(t_pred[0], train_labels))
    print('valid accuracy: %.1f%%' % cal_accuracy(valid_prediction.eval(), valid_labels))
    print('Test accuracy: %.1f%%' % cal_accuracy(test_prediction.eval(), test_labels))
    saver.save(session, 'Save_Model\model_final.ckpt')
    print("Model saved")
x_axis = np.arange(epochs)
plt.plot(x_axis[train_acc_history > 0], train_acc_history[train_acc_history > 0], linewidth=2, label= "Train Data")
plt.plot(x_axis[valid_acc_history > 0], valid_acc_history[valid_acc_history > 0],  linewidth=2, label= "Validation Data")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()
plt.plot(x_axis[train_loss_history > 0], train_loss_history[train_loss_history > 0],  linewidth=2, label= "Train Loss")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

#Train Set Confusion Matrix
plot_confusion_matrix(cm_train,"Train Data Set")
dm_cm_train= pd.DataFrame(cm_train)
    
#Validation Set Confusion Matrix
dm_cm_valid= pd.DataFrame(cm_valid)
plot_confusion_matrix(cm_valid,"Validation Data Set")
    
#Test Set Confusion Matrix
dm_cm_test= pd.DataFrame(cm_test)
plot_confusion_matrix(cm_test,"Test Data Set")

#Calculate Precision, Recall and F1 Score for the test data
TP_test = np.diagonal(cm_test)
precision = TP_test/np.sum(cm_test, axis=1)
recall = TP_test/np.sum(cm_test, axis=0)
f1_score = 2*precision*recall/(precision+recall)
# Out:
# Training Started
# ---------------------------
# Minibatch loss at step 0: 16.657789
# Minibatch accuracy: 2.3%
# Validation accuracy: 5.7%
# Minibatch loss at step 50: 3.380351
# Minibatch accuracy: 19.5%
# Validation accuracy: 16.3%
# Minibatch loss at step 100: 2.700448
# Minibatch accuracy: 32.0%
# Validation accuracy: 37.4%
# Minibatch loss at step 150: 2.109162
# Minibatch accuracy: 46.1%
# Validation accuracy: 51.7%
# Minibatch loss at step 200: 1.766791
# Minibatch accuracy: 49.2%
# Validation accuracy: 64.8%
# Minibatch loss at step 250: 1.428915
# Minibatch accuracy: 65.6%
# Validation accuracy: 69.0%
# Minibatch loss at step 300: 1.212901
# Minibatch accuracy: 68.8%
# Validation accuracy: 79.0%
# Minibatch loss at step 350: 0.823362
# Minibatch accuracy: 76.6%
# Validation accuracy: 84.7%
# Minibatch loss at step 400: 0.925393
# Minibatch accuracy: 75.8%
# Validation accuracy: 80.9%
# Minibatch loss at step 450: 0.792966
# Minibatch accuracy: 82.0%
# Validation accuracy: 89.0%
# Minibatch loss at step 500: 0.743094
# Minibatch accuracy: 81.2%
# Validation accuracy: 90.5%
# Minibatch loss at step 550: 0.748275
# Minibatch accuracy: 81.2%
# Validation accuracy: 90.8%
# Minibatch loss at step 600: 0.476838
# Minibatch accuracy: 89.1%
# Validation accuracy: 93.2%
# Minibatch loss at step 650: 0.499669
# Minibatch accuracy: 91.4%
# Validation accuracy: 93.6%
# Minibatch loss at step 700: 0.469555
# Minibatch accuracy: 89.8%
# Validation accuracy: 94.5%
# Minibatch loss at step 750: 0.345532
# Minibatch accuracy: 91.4%
# Validation accuracy: 94.8%
# Minibatch loss at step 800: 0.367412
# Minibatch accuracy: 94.5%
# Validation accuracy: 95.5%
# Minibatch loss at step 850: 0.356378
# Minibatch accuracy: 93.0%
# Validation accuracy: 96.0%
# Minibatch loss at step 900: 0.456605
# Minibatch accuracy: 89.8%
# Validation accuracy: 95.2%
# Minibatch loss at step 950: 0.379771
# Minibatch accuracy: 93.0%
# Validation accuracy: 96.3%
# Minibatch loss at step 1000: 0.548266
# Minibatch accuracy: 90.6%
# Validation accuracy: 96.1%
# Minibatch loss at step 1050: 0.320465
# Minibatch accuracy: 93.0%
# Validation accuracy: 96.7%
# Minibatch loss at step 1100: 0.364953
# Minibatch accuracy: 93.0%
# Validation accuracy: 97.2%
# Minibatch loss at step 1150: 0.371373
# Minibatch accuracy: 93.8%
# Validation accuracy: 97.0%
# Minibatch loss at step 1200: 0.314423
# Minibatch accuracy: 93.0%
# Validation accuracy: 96.6%
# Minibatch loss at step 1250: 0.391366
# Minibatch accuracy: 92.2%
# Validation accuracy: 97.4%
# Minibatch loss at step 1300: 0.355712
# Minibatch accuracy: 93.0%
# Validation accuracy: 97.3%
# Minibatch loss at step 1350: 0.265674
# Minibatch accuracy: 94.5%
# Validation accuracy: 97.6%
# Minibatch loss at step 1400: 0.320315
# Minibatch accuracy: 93.8%
# Validation accuracy: 97.4%
# Minibatch loss at step 1450: 0.252702
# Minibatch accuracy: 95.3%
# Validation accuracy: 97.8%
# Minibatch loss at step 1500: 0.254741
# Minibatch accuracy: 93.8%
# Validation accuracy: 97.9%
# Minibatch loss at step 1550: 0.286455
# Minibatch accuracy: 94.5%
# Validation accuracy: 97.9%
# Minibatch loss at step 1600: 0.218546
# Minibatch accuracy: 95.3%
# Validation accuracy: 98.0%
# Minibatch loss at step 1650: 0.231612
# Minibatch accuracy: 96.9%
# Validation accuracy: 97.8%
# Minibatch loss at step 1700: 0.261398
# Minibatch accuracy: 97.7%
# Validation accuracy: 98.1%
# Minibatch loss at step 1750: 0.233076
# Minibatch accuracy: 96.9%
# Validation accuracy: 98.2%
# Minibatch loss at step 1800: 0.259299
# Minibatch accuracy: 96.1%
# Validation accuracy: 98.2%
# Minibatch loss at step 1850: 0.191118
# Minibatch accuracy: 98.4%
# Validation accuracy: 98.3%
# Minibatch loss at step 1900: 0.243862
# Minibatch accuracy: 93.8%
# Validation accuracy: 98.3%
# Minibatch loss at step 1950: 0.255516
# Minibatch accuracy: 93.0%
# Validation accuracy: 98.3%
# Train accuracy: 96.6%
# valid accuracy: 98.3%
# Test accuracy: 93.2%
# Model saved

# %% [markdown]
# #### Precision, Recall and F1 Scores for all classes

# %%
report_model2 = classification_report(y_true_test, y_pred_test)
print (report_model2)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.83      0.88        60
#            1       0.93      0.98      0.95       720
#            2       0.97      0.96      0.96       750
#            3       0.85      0.86      0.85       450
#            4       0.96      0.95      0.95       660
#            5       0.86      0.95      0.90       630
#            6       0.96      0.87      0.91       150
#            7       0.94      0.87      0.90       450
#            8       0.94      0.92      0.93       450
#            9       0.94      0.96      0.95       480
#           10       0.95      0.98      0.97       660
#           11       0.91      0.95      0.93       420
#           12       0.95      0.98      0.97       690
#           13       0.98      0.99      0.99       720
#           14       0.97      0.94      0.96       270
#           15       0.90      0.99      0.94       210
#           16       1.00      0.98      0.99       150
#           17       0.92      1.00      0.95       360
#           18       0.95      0.79      0.86       390
#           19       0.95      0.58      0.72        60
#           20       0.84      0.93      0.88        90
#           21       0.96      0.60      0.74        90
#           22       0.98      0.88      0.93       120
#           23       0.76      0.97      0.85       150
#           24       0.97      0.72      0.83        90
#           25       0.94      0.95      0.95       480
#           26       0.76      0.85      0.80       180
#           27       0.91      0.50      0.65        60
#           28       0.92      0.93      0.93       150
#           29       0.93      0.99      0.96        90
#           30       0.81      0.81      0.81       150
#           31       0.95      0.98      0.97       270
#           32       0.90      0.78      0.84        60
#           33       0.95      0.99      0.97       210
#           34       0.86      0.97      0.91       120
#           35       0.98      0.94      0.96       390
#           36       0.98      1.00      0.99       120
#           37       0.98      0.88      0.93        60
#           38       0.96      0.91      0.93       690
#           39       0.92      0.96      0.94        90
#           40       0.91      0.82      0.87        90
#           41       0.93      0.63      0.75        60
#           42       0.98      0.96      0.97        90
#
#     accuracy                           0.93     12630
#    macro avg       0.93      0.89      0.90     12630
# weighted avg       0.93      0.93      0.93     12630

# %% [markdown]
# #### Macro Averaging of Precision, Recall and F1 Scores

# %%
from sklearn.metrics import f1_score
f1_score_macro = f1_score(y_true_test, y_pred_test, average="macro")
precision_macro =precision_score(y_true_test, y_pred_test, average="macro")
recall_macro =recall_score(y_true_test, y_pred_test, average="macro")
df_macro = pd.DataFrame({'Precision':[precision_macro],'Recall':[recall_macro],'f1 score':[f1_score_macro]})
df_macro.round(2)
# Out:
#    Precision  Recall  f1 score
# 0       0.93    0.89       0.9

# %% [markdown]
# #### Micro Averaging of Precision, Recall and F1 Scores

# %%
from sklearn.metrics import f1_score
f1_score_micro = f1_score(y_true_test, y_pred_test, average="micro")
precision_micro =precision_score(y_true_test, y_pred_test, average="micro")
recall_micro =recall_score(y_true_test, y_pred_test, average="micro")
df_micro = pd.DataFrame({'Precision':[precision_micro],'Recall':[recall_micro],'f1 score':[f1_score_micro]})
df_micro.round(2)
# Out:
#    Precision  Recall  f1 score
# 0       0.93    0.93      0.93

# %% [markdown]
# #### Weighted Averaging of Precision, Recall and F1 Scores

# %%
f1_score_weighted = f1_score(y_true_test, y_pred_test, average="weighted")
precision_weighted =precision_score(y_true_test, y_pred_test, average="weighted")
recall_weighted =recall_score(y_true_test, y_pred_test, average="weighted")
df_weighted = pd.DataFrame({'Precision':[precision_weighted],'Recall':[recall_weighted],'f1 score':[f1_score_weighted]})
df_weighted.round(2)
# Out:
#    Precision  Recall  f1 score
# 0       0.93    0.93      0.93

# %% [markdown]
# # Test Model on New Images

# %% [markdown]
# After training the model I used the model to classify new images downloaded from the internet.

# %% [markdown]
# import os
# new_data_dir = "New_Data"
# directories =os.listdir(new_data_dir)
# file_names = directories[:6]
#
# images_new=[]
#
# file_path = new_data_dir+ '/*.png'
# #for i in traffic_classes:
# for file_name in glob.glob(file_path):
#
#     images_new.append(skimage.data.imread(file_name))

# %%
new_data= [file for file in glob.glob("New_Data/*.png")]

# %%
images_test=[]
for file in new_data:
    image = plt.imread(file)
    image = image.astype(np.float32)
    images_test.append(image)

# %%
for image in images_test:
    plt.imshow(image)
    plt.show()

# %%
#Resize and normalize
image_resize=[]
for image in images_test:
    image = cv2.resize(image,(32,32))
    image = np.mean(image,axis=2)
    image -=np.mean(image)
    image /= np.std(image)
    
    image_resize.append(image)

image_norm = np.array(image_resize)

# %%
for image in image_norm:
    plt.imshow(image)
    plt.show()

# %%
#Manually Label the images
y_collected = np.array([2,22, 18, 33,11, 23, 14])

# %%
x_new_cnn, y_new = reformat(image_norm, y_collected)

# %%
with tf.Session(graph=graph) as session:
    saver.restore(session, 'Save_Model\model_final.ckpt')
    classes = session.run(logits, feed_dict={x_train_dataset:x_new_cnn})
    print (classes.shape)
    output = session.run(tf.nn.top_k(tf.constant(classes), k=5))
    for i in range(len(output[0])):
        print('Image', i, output[0][i], 'and output', output[1][i])
# Out:
# (7, 43)
# Image 0 [ 29.49888229  21.80272102  19.48609161  17.92178917  16.32008553] and output [2 1 7 3 5]
# Image 1 [ 20.69504166  20.18960762  19.14031219  17.33232689  15.21952629] and output [22 26 18 29 25]
# Image 2 [ 28.65303802  19.96107101  15.46544266  15.22623634  14.03529072] and output [18 26 27 24 40]
# Image 3 [ 38.10641861  18.90814781  18.72649193  16.5335598   11.5761776 ] and output [33 11 16 32 35]
# Image 4 [ 23.640131    18.19000244  16.04700279  13.67135715  13.56851292] and output [11 30 28  1 24]
# Image 5 [ 30.04604912  20.33771706  18.88495827  17.43384552  15.70975876] and output [23 30 11 21 19]
# Image 6 [ 10.43318748  10.14661407   8.40258884   8.34756756   7.91613865] and output [13  2 15 25 38]

# %%
y_collected
# Out:
# array([ 2, 22, 18, 33, 11, 23, 14])

# %%
y_predicted =output[1][:,0]

# %%
y_predicted
# Out:
# array([ 2, 22, 18, 33, 11, 23, 13])

# %%
output[1]
# Out:
# array([[ 2,  1,  7,  3,  5],
#        [22, 26, 18, 29, 25],
#        [18, 26, 27, 24, 40],
#        [33, 11, 16, 32, 35],
#        [11, 30, 28,  1, 24],
#        [23, 30, 11, 21, 19],
#        [13,  2, 15, 25, 38]])

# %%
new_data_accuracy= accuracy_score(y_collected,y_predicted)

# %%
print ("New Test Data Accuracy: %0.2f"%new_data_accuracy)
# Out:
# New Test Data Accuracy 0.86
